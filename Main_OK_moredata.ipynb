# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from collections import deque
import random
import gymnasium as gym
from gymnasium import spaces
import datetime
import my_library as mylib
# import importlib
# importlib.reload(my_library)
import statsmodels.api as sm
import matplotlib.pyplot as plt
import pickle
pd.options.mode.chained_assignment = None

# %% [markdown]
# # Data manipulation

# %%
data = pd.read_csv('AAPL (2).csv', sep=',')
data['Date'] = pd.to_datetime(data['Date'],format='%Y-%m-%d')
adj_close = data['AAPL']
df = pd.DataFrame({'Date': data['Date'], 'log_ret': np.log(adj_close/adj_close.shift(1)).dropna(), 'AAPL_VOL': data['AAPL_VOL']}).dropna().set_index('Date')
sp500 = pd.read_csv('sp500_joined_closes (3).csv', sep=',').dropna(axis=1)
sp500.drop('AAPL ', axis=1, inplace=True)
sp500.drop('AAPL _VOL', axis=1, inplace=True)
data.set_index('Date', inplace=True)
new_cols = list([])
for i, col in enumerate(sp500.columns):
    if col.endswith(' '):
        new_cols.append(col[:-1])
    elif col.endswith(' _VOL'):
        new_cols.append(col[:-5]+'_VOL')
    else:
        new_cols.append(col)
sp500.columns = new_cols
sp500['Date'] = pd.to_datetime(sp500['Date'])
sp500 = sp500.set_index('Date')
col_stocks = [col for col in new_cols if not col.endswith('VOL')]
col_vols = [col for col in new_cols if col.endswith('VOL')]
any(col == 'Date' for col in col_stocks)
col_stocks = col_stocks[1:]
any(col == 'Date' for col in col_stocks)
# Out:
# False

# %%
sp500_lr = np.log(sp500[col_stocks]/sp500[col_stocks].shift(1))
sp500_lr = sp500_lr.drop(sp500_lr.index[0])
sp500_lr = sp500_lr.drop([col for col in sp500_lr.columns if sp500_lr[col].count() < 3633], axis=1)
df = df.join(sp500[col_vols],how='inner').dropna()
df = df.join(sp500_lr,how='inner').dropna()
df.describe()
# Out:
#            log_ret      AAPL_VOL       MMM_VOL       AOS_VOL       ABT_VOL  \
# count  3638.000000  3.638000e+03  3.638000e+03  3.638000e+03  3.638000e+03
# mean      0.000962  2.364617e+08  3.672072e+06  1.363582e+06  8.361895e+06
# std       0.017704  2.192065e+08  2.911937e+06  1.103023e+06  5.976096e+06
# min      -0.137708  2.404830e+07  7.785960e+05  2.042000e+05  1.067700e+06
# 25%      -0.007537  8.900225e+07  2.380937e+06  8.305000e+05  4.614210e+06
# 50%       0.000903  1.461266e+08  3.098058e+06  1.113950e+06  6.282250e+06
# 75%       0.010319  3.192147e+08  4.108499e+06  1.586875e+06  1.024750e+07
# max       0.113157  1.880998e+09  6.043675e+07  3.248830e+07  7.810838e+07
#
#             ACN_VOL      ADBE_VOL       AMD_VOL       AES_VOL       AFL_VOL  \
# count  3.638000e+03  3.638000e+03  3.638000e+03  3.638000e+03  3.638000e+03
# mean   2.772958e+06  3.756350e+06  4.659924e+07  5.907124e+06  4.438843e+06
# std    2.315021e+06  3.470823e+06  3.549588e+07  2.840392e+06  2.835895e+06
# min    5.281000e+05  5.892000e+05  0.000000e+00  9.862000e+05  8.789000e+05
# 25%    1.813925e+06  2.136200e+06  1.889980e+07  4.110050e+06  2.677625e+06
# 50%    2.333400e+06  2.906300e+06  3.877410e+07  5.336600e+06  3.640550e+06
# 75%    3.150400e+06  4.277000e+06  6.321760e+07  7.026075e+06  5.307400e+06
# max    8.965590e+07  1.087524e+08  3.250584e+08  4.606760e+07  3.669320e+07
#
#        ...          WST          WDC           WY          WMB          WTW  \
# count  ...  3638.000000  3638.000000  3638.000000  3638.000000  3638.000000
# mean   ...     0.000799     0.000218     0.000296     0.000441     0.000433
# std    ...     0.017123     0.027057     0.019391     0.024196     0.014200
# min    ...    -0.151802    -0.228719    -0.257132    -0.427912    -0.113525
# 25%    ...    -0.007562    -0.013190    -0.009073    -0.009434    -0.005715
# 50%    ...     0.000930     0.000462     0.000681     0.000740     0.000695
# 75%    ...     0.009358     0.014244     0.009957     0.010422     0.007123
# max    ...     0.135745     0.190144     0.225664     0.295550     0.140681
#
#               WYNN          XEL          YUM         ZBRA          ZBH
# count  3638.000000  3638.000000  3638.000000  3638.000000  3638.000000
# mean      0.000211     0.000391     0.000539     0.000641     0.000194
# std       0.028792     0.012314     0.015034     0.022864     0.016214
# min      -0.280172    -0.135726    -0.208654    -0.272411    -0.150757
# 25%      -0.013317    -0.005615    -0.006247    -0.009777    -0.007351
# 50%      -0.000104     0.000632     0.000839     0.000930     0.000163
# 75%       0.013625     0.007141     0.007597     0.011237     0.008326
# max       0.244422     0.106679     0.209032     0.158833     0.144790
#
# [8 rows x 860 columns]

# %% [markdown]
# Performing PCA on AAPL and SP500 stocks

# %%
cum_var_exp, PCs, regr_PCs, eig_vecs = mylib.PCA(df['log_ret'], sp500_lr, plot=False)

# %%
regr_PCs.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   AAPL   R-squared:                       0.461
# Model:                            OLS   Adj. R-squared:                  0.460
# Method:                 Least Squares   F-statistic:                     310.6
# Date:                Fri, 16 Aug 2024   Prob (F-statistic):               0.00
# Time:                        13:40:06   Log-Likelihood:                 10639.
# No. Observations:                3638   AIC:                        -2.126e+04
# Df Residuals:                    3627   BIC:                        -2.119e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0003      0.000      1.384      0.166      -0.000       0.001
# PC0            0.0416      0.001     36.015      0.000       0.039       0.044
# PC1            0.0038      0.003      1.182      0.237      -0.003       0.010
# PC2           -0.0669      0.003    -22.483      0.000      -0.073      -0.061
# PC3            0.0037      0.005      0.809      0.419      -0.005       0.012
# PC4            0.0286      0.004      6.665      0.000       0.020       0.037
# PC5            0.0045      0.005      0.840      0.401      -0.006       0.015
# PC6            0.0124      0.006      2.142      0.032       0.001       0.024
# PC7           -0.0606      0.006    -10.537      0.000      -0.072      -0.049
# PC8            0.0152      0.006      2.348      0.019       0.003       0.028
# PC9            0.0277      0.007      4.146      0.000       0.015       0.041
# ==============================================================================
# Omnibus:                      577.011   Durbin-Watson:                   1.928
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10422.390
# Skew:                          -0.033   Prob(JB):                         0.00
# Kurtosis:                      11.292   Cond. No.                         33.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
Y = PCs['AAPL']

# %%
[i-1 for i,p in enumerate(regr_PCs.tvalues) if abs(p) > 1.96]
# Out:
# [0, 2, 4, 6, 7, 8, 9]

# %%
t_vals = regr_PCs.tvalues.drop('const')

# %%
t_vals.drop([p for p in t_vals.index if abs(t_vals[p]) == abs(t_vals).min()], inplace=True)
list(t_vals.index)
# Out:
# ['PC0', 'PC1', 'PC2', 'PC4', 'PC5', 'PC6', 'PC7', 'PC8', 'PC9']

# %%
X = PCs[list(t_vals.index)]
X
# Out:
#                  PC0       PC1       PC2       PC4       PC5       PC6  \
# Date
# 2010-01-05  0.077616  0.106817  0.077500 -0.054376 -0.000260  0.025579
# 2010-01-06  0.046104  0.026022  0.032150  0.053552 -0.018836  0.024003
# 2010-01-07  0.119045  0.058188  0.074514 -0.133750  0.015196  0.014245
# 2010-01-08  0.056234  0.054203 -0.034621  0.064576 -0.060854 -0.019069
# 2010-01-11  0.059334 -0.041982  0.015663  0.001116  0.002717 -0.004994
# ...              ...       ...       ...       ...       ...       ...
# 2024-06-12  0.112613  0.110088 -0.074268 -0.032677 -0.050849 -0.080531
# 2024-06-13 -0.053387 -0.051662 -0.025688 -0.036519 -0.002940  0.011562
# 2024-06-14 -0.126917 -0.086623 -0.062926 -0.009177  0.060976 -0.016470
# 2024-06-17  0.146218  0.081919 -0.007522 -0.055556 -0.052291  0.045627
# 2024-06-18  0.058779  0.021141  0.014830  0.011469 -0.008826 -0.053113
#
#                  PC7       PC8       PC9
# Date
# 2010-01-05 -0.019749  0.070622 -0.003594
# 2010-01-06  0.056333 -0.046954  0.009634
# 2010-01-07  0.049853 -0.027073 -0.019580
# 2010-01-08 -0.005648 -0.041529 -0.015592
# 2010-01-11  0.009890 -0.006846 -0.061461
# ...              ...       ...       ...
# 2024-06-12  0.019911 -0.005482 -0.013693
# 2024-06-13 -0.003649  0.000200  0.013916
# 2024-06-14 -0.006781  0.005812  0.071929
# 2024-06-17 -0.068626 -0.028992  0.052491
# 2024-06-18 -0.022793  0.027428  0.013870
#
# [3638 rows x 9 columns]

# %%
regr_PCs = sm.OLS(Y, X).fit()
regr_PCs.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   AAPL   R-squared (uncentered):                   0.463
# Model:                            OLS   Adj. R-squared (uncentered):              0.461
# Method:                 Least Squares   F-statistic:                              347.0
# Date:                Fri, 16 Aug 2024   Prob (F-statistic):                        0.00
# Time:                        13:40:06   Log-Likelihood:                          10638.
# No. Observations:                3638   AIC:                                 -2.126e+04
# Df Residuals:                    3629   BIC:                                 -2.120e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# PC0            0.0420      0.001     37.553      0.000       0.040       0.044
# PC1            0.0037      0.003      1.156      0.248      -0.003       0.010
# PC2           -0.0673      0.003    -22.760      0.000      -0.073      -0.061
# PC4            0.0281      0.004      6.593      0.000       0.020       0.036
# PC5            0.0045      0.005      0.836      0.403      -0.006       0.015
# PC6            0.0135      0.006      2.371      0.018       0.002       0.025
# PC7           -0.0614      0.006    -10.796      0.000      -0.073      -0.050
# PC8            0.0150      0.006      2.330      0.020       0.002       0.028
# PC9            0.0280      0.007      4.193      0.000       0.015       0.041
# ==============================================================================
# Omnibus:                      577.562   Durbin-Watson:                   1.926
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10457.001
# Skew:                          -0.033   Prob(JB):                         0.00
# Kurtosis:                      11.305   Cond. No.                         8.03
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
t_vals = regr_PCs.tvalues
t_vals.drop([p for p in t_vals.index if abs(t_vals[p]) == abs(t_vals).min()], inplace=True)
list(t_vals.index)
X = PCs[list(t_vals.index)]
X = sm.add_constant(X)
regr_PCs = sm.OLS(Y, X).fit()
regr_PCs.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   AAPL   R-squared:                       0.461
# Model:                            OLS   Adj. R-squared:                  0.460
# Method:                 Least Squares   F-statistic:                     388.2
# Date:                Fri, 16 Aug 2024   Prob (F-statistic):               0.00
# Time:                        13:40:06   Log-Likelihood:                 10639.
# No. Observations:                3638   AIC:                        -2.126e+04
# Df Residuals:                    3629   BIC:                        -2.120e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0003      0.000      1.383      0.167      -0.000       0.001
# PC0            0.0419      0.001     37.415      0.000       0.040       0.044
# PC1            0.0036      0.003      1.123      0.261      -0.003       0.010
# PC2           -0.0670      0.003    -22.657      0.000      -0.073      -0.061
# PC4            0.0285      0.004      6.704      0.000       0.020       0.037
# PC6            0.0136      0.006      2.395      0.017       0.002       0.025
# PC7           -0.0613      0.006    -10.794      0.000      -0.072      -0.050
# PC8            0.0157      0.006      2.439      0.015       0.003       0.028
# PC9            0.0280      0.007      4.193      0.000       0.015       0.041
# ==============================================================================
# Omnibus:                      577.002   Durbin-Watson:                   1.928
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10419.159
# Skew:                          -0.035   Prob(JB):                         0.00
# Kurtosis:                      11.290   Cond. No.                         32.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
t_vals = regr_PCs.tvalues
any(abs(t_vals) < 1.96)
# Out:
# True

# %%
t_vals = regr_PCs.tvalues
t_vals = regr_PCs.tvalues.drop('const')
t_vals.drop([p for p in t_vals.index if abs(t_vals[p]) == abs(t_vals).min()], inplace=True)
list(t_vals.index)
X = PCs[list(t_vals.index)]
regr_PCs = sm.OLS(Y, X).fit()
regr_PCs.summary()
t_vals = regr_PCs.tvalues
any(abs(t_vals) < 1.96)
# Out:
# False

# %%
regr_PCs.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   AAPL   R-squared (uncentered):                   0.462
# Model:                            OLS   Adj. R-squared (uncentered):              0.461
# Method:                 Least Squares   F-statistic:                              445.9
# Date:                Fri, 16 Aug 2024   Prob (F-statistic):                        0.00
# Time:                        13:40:07   Log-Likelihood:                          10637.
# No. Observations:                3638   AIC:                                 -2.126e+04
# Df Residuals:                    3631   BIC:                                 -2.122e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# PC0            0.0425      0.001     41.636      0.000       0.040       0.044
# PC2           -0.0669      0.003    -22.738      0.000      -0.073      -0.061
# PC4            0.0292      0.004      7.014      0.000       0.021       0.037
# PC6            0.0140      0.006      2.466      0.014       0.003       0.025
# PC7           -0.0627      0.006    -11.249      0.000      -0.074      -0.052
# PC8            0.0158      0.006      2.466      0.014       0.003       0.028
# PC9            0.0278      0.007      4.181      0.000       0.015       0.041
# ==============================================================================
# Omnibus:                      576.686   Durbin-Watson:                   1.928
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10400.402
# Skew:                          -0.035   Prob(JB):                         0.00
# Kurtosis:                      11.283   Cond. No.                         7.87
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# Add the relevant PCs to the df

# %%
PCs['AAPL']
# Out:
# Date
# 2010-01-05    0.001727
# 2010-01-06   -0.016034
# 2010-01-07   -0.001850
# 2010-01-08    0.006626
# 2010-01-11   -0.008861
#                 ...
# 2024-06-12    0.028178
# 2024-06-13    0.005476
# 2024-06-14   -0.008202
# 2024-06-17    0.019480
# 2024-06-18   -0.011045
# Name: AAPL, Length: 3638, dtype: float64

# %%
dataframe = pd.DataFrame(PCs[list(t_vals.index)])
dataframe['log_ret'] = df['log_ret']
dataframe
# Out:
#                  PC0       PC2       PC4       PC6       PC7       PC8  \
# Date
# 2010-01-05  0.077616  0.077500 -0.054376  0.025579 -0.019749  0.070622
# 2010-01-06  0.046104  0.032150  0.053552  0.024003  0.056333 -0.046954
# 2010-01-07  0.119045  0.074514 -0.133750  0.014245  0.049853 -0.027073
# 2010-01-08  0.056234 -0.034621  0.064576 -0.019069 -0.005648 -0.041529
# 2010-01-11  0.059334  0.015663  0.001116 -0.004994  0.009890 -0.006846
# ...              ...       ...       ...       ...       ...       ...
# 2024-06-12  0.112613 -0.074268 -0.032677 -0.080531  0.019911 -0.005482
# 2024-06-13 -0.053387 -0.025688 -0.036519  0.011562 -0.003649  0.000200
# 2024-06-14 -0.126917 -0.062926 -0.009177 -0.016470 -0.006781  0.005812
# 2024-06-17  0.146218 -0.007522 -0.055556  0.045627 -0.068626 -0.028992
# 2024-06-18  0.058779  0.014830  0.011469 -0.053113 -0.022793  0.027428
#
#                  PC9   log_ret
# Date
# 2010-01-05 -0.003594  0.001727
# 2010-01-06  0.009634 -0.016034
# 2010-01-07 -0.019580 -0.001850
# 2010-01-08 -0.015592  0.006626
# 2010-01-11 -0.061461 -0.008861
# ...              ...       ...
# 2024-06-12 -0.013693  0.028178
# 2024-06-13  0.013916  0.005476
# 2024-06-14  0.071929 -0.008202
# 2024-06-17  0.052491  0.019480
# 2024-06-18  0.013870 -0.011045
#
# [3638 rows x 8 columns]

# %%
oil = pd.read_csv('Crude Oil WTI Futures Historical Data.csv')
oil['Date'] = pd.to_datetime(oil['Date'],format='%m/%d/%Y')
oil = oil[['Date','Price']]
oil = oil.rename(columns={'Price':'Oil'})

gold = pd.read_csv('Gold Futures Historical Data.csv')
gold['Date'] = pd.to_datetime(gold['Date'],format='%m/%d/%Y')
gold = gold[['Date','Price']]
gold = gold.rename(columns={'Price':'Gold'})
gold['Gold'] = gold['Gold'].str.replace(',', '').astype(float)

semiconductor = pd.read_csv('Philadelphia Semiconductor Index Historical Data.csv')
semiconductor['Date'] = pd.to_datetime(semiconductor['Date'],format='%m/%d/%Y')
semiconductor = semiconductor[['Date','Price']]
semiconductor = semiconductor.rename(columns={'Price':'Semiconductor'})
semiconductor['Semiconductor'] = semiconductor['Semiconductor'].str.replace(',', '').astype(float)

wheat = pd.read_csv('US Wheat Futures Historical Data.csv')
wheat['Date'] = pd.to_datetime(wheat['Date'],format='%m/%d/%Y')
wheat = wheat[['Date','Price']]
wheat = wheat.rename(columns={'Price':'Wheat'})
wheat['Wheat'] = wheat['Wheat'].str.replace(',', '').astype(float)

yuan = pd.read_csv('USD_CNY Historical Data.csv')
yuan['Date'] = pd.to_datetime(yuan['Date'],format='%m/%d/%Y')
yuan = yuan[['Date','Price']]
yuan = yuan.rename(columns={'Price':'Yuan'})

dataframe = pd.merge(dataframe, oil, on='Date')
dataframe = pd.merge(dataframe, gold, on='Date')
dataframe = pd.merge(dataframe, semiconductor, on='Date')
dataframe = pd.merge(dataframe, wheat, on='Date')
dataframe = pd.merge(dataframe, yuan, on='Date')
dataframe.set_index('Date', inplace=True)
dataframe
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 oil = pd.read_csv('Crude Oil WTI Futures Historical Data.csv')
#       2 oil['Date'] = pd.to_datetime(oil['Date'],format='%m/%d/%Y')
#       3 oil = oil[['Date','Price']]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\debugpy\_vendored\pydevd\_pydevd_bundle\pydevd_frame.py:988, in PyDBFrame.trace_dispatch(self, frame, event, arg)
#     986 # if thread has a suspend flag, we suspend with a busy wait
#     987 if info.pydev_state == STATE_SUSPEND:
# --> 988     self.do_wait_suspend(thread, frame, event, arg)
#     989     return self.trace_dispatch
#     990 else:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\debugpy\_vendored\pydevd\_pydevd_bundle\pydevd_frame.py:165, in PyDBFrame.do_wait_suspend(self, *args, **kwargs)
#     164 def do_wait_suspend(self, *args, **kwargs):
# --> 165     self._args[0].do_wait_suspend(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\debugpy\_vendored\pydevd\pydevd.py:2070, in PyDB.do_wait_suspend(self, thread, frame, event, arg, exception_type)
#    2067             from_this_thread.append(frame_custom_thread_id)
#    2069     with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, thread, stop_reason):
# -> 2070         keep_suspended = self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread, frames_tracker)
#    2072 frames_list = None
#    2074 if keep_suspended:
#    2075     # This means that we should pause again after a set next statement.
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\debugpy\_vendored\pydevd\pydevd.py:2106, in PyDB._do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread, frames_tracker)
#    2103         self._call_input_hook()
#    2105     self.process_internal_commands()
# -> 2106     time.sleep(0.01)
#    2108 self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#    2110 # process any stepping instructions
#
# KeyboardInterrupt:

# %%
dataframe.shape
# Out:
# (3531, 13)

# %% [markdown]
# # Create the environment and agent, training, and backtesting

# %% [markdown]
# ## Define the environment and agent

# %%
class TradingEnv(gym.Env):
    def __init__(self, df, rf):
        super(TradingEnv, self).__init__()

        self.current_step = 0
        self.data = df.iloc[:,df.columns != 'log_ret']
        self.y = df['log_ret']
        self.initial_position = pd.DataFrame({'0': [0], '1': [1]}) # Initial position is 1000 in risk_free asset
        self.position = self.initial_position.copy()
        self.initial_portfolio_value = list([1000])
        self.money = pd.DataFrame(self.initial_portfolio_value[0] * self.position)
        self.rf = rf
        self.pos_sup = 2
        self.pos_inf = -1
        # Define action and observation space
        
        # Only one stock, the rest is in cash
        self.action_space = np.arange(self.pos_inf, self.pos_sup, 0.15).round(2)
        # If two stocks, then self.action_space = spaces.Box(low=np.array([0,0]), high=np.array([1,1]), dtype=np.float32)
        
        # observation_space is a dataframe with historical data
        self.observation_space = spaces.Box(low=0, high=np.inf, shape=(1,df.shape[1]+5), dtype=np.float32)
           
    def step(self, state, action):
        # Execute one time step within the environment
        self.current_step += 1
        self.flag = 0

        # End the episode if we've run out of data
        if self.current_step >= days_train:
            return self.position, 0, True

        # Take the action (<0: short stock, ==0: hold positions, >0: buy stock)
        # action = action[0][0]
        if (action > self.pos_sup) or (action < self.pos_inf):
            reward = - 1000
            self.flag = 1
            new_row_pos = pd.DataFrame([[self.position.iloc[self.current_step-1,0], self.position.iloc[self.current_step-1,1]]])
            self.position = pd.concat([self.position, new_row_pos], axis=0, ignore_index=True)    
            pv = np.exp(state[0]) * self.money.iloc[self.current_step-1,0] + self.money.iloc[self.current_step-1,1] * (1+self.rf)
            new_row_money = pd.DataFrame([[self.position.iloc[self.current_step,0]*self.portfolio_value[self.current_step], self.position.iloc[self.current_step,1]*self.portfolio_value[self.current_step]]])
            self.money = pd.concat([self.money, new_row_money], axis=0, ignore_index=True)
            observation = np.concatenate(([self.y_train.iloc[self.current_step]], self.df_train.iloc[self.current_step], [self.position.iloc[self.current_step,0], self.position.iloc[self.current_step,1], self.money.iloc[self.current_step,0], self.money.iloc[self.current_step,1], self.portfolio_value[self.current_step]]))
            return new_row_pos, reward, True
        new_port_value = np.exp(state[0]) * self.money.iloc[self.current_step-1,0] + self.money.iloc[self.current_step-1,1] * (1+self.rf)
        self.portfolio_value.append(new_port_value)
        
        if abs(action - self.position.iloc[self.current_step-1,0]) >= tol:
            new_row_pos = pd.DataFrame([[action, (1 - action)]])
        else:
            new_row_pos = pd.DataFrame([[self.position.iloc[self.current_step-1,0], self.position.iloc[self.current_step-1,1]]])
        self.position = pd.concat([self.position, new_row_pos], axis=0, ignore_index=True)    
        new_row_money = pd.DataFrame([[self.position.iloc[self.current_step,0]*self.portfolio_value[self.current_step], self.position.iloc[self.current_step,1]*self.portfolio_value[self.current_step]]])
        self.money = pd.concat([self.money, new_row_money], axis=0, ignore_index=True)

        if self.flag == 0:
            reward = (self.portfolio_value[self.current_step] - self.portfolio_value[self.current_step-1])/self.portfolio_value[self.current_step-1]
        
        done = self.current_step >= days_train - 1
        
        observation = np.concatenate(([self.y_train.iloc[self.current_step]], self.df_train.iloc[self.current_step], [self.position.iloc[self.current_step,0], self.position.iloc[self.current_step,1], self.money.iloc[self.current_step,0], self.money.iloc[self.current_step,1], self.portfolio_value[self.current_step]]))

        return observation, reward, done

    def reset(self, noise=True):
        # Reset the state of the environment to an initial state
        self.current_step = 0
        a = (3 * np.random.rand(1) - 1)[0].round(5)
        self.position = pd.DataFrame([a,1-a]).T
        self.portfolio_value = self.initial_portfolio_value.copy()
        self.money = pd.DataFrame(self.portfolio_value[0] * self.position)
        starting_point = np.random.randint(0, self.data.shape[0]-days_train)
        self.df_train = self.data.iloc[starting_point:starting_point+days_train,].copy()
        self.y_train = self.y.iloc[starting_point:starting_point+days_train,].copy()
        if noise:
            for i in range(days_train):
                b = np.log((0.05 * np.random.rand(1) + 0.975)[0]).round(5)
                self.y_train.iloc[i] += b
                for j in range(len(self.df_train.columns)):
                    c = np.log((0.05 * np.random.rand(1) + 0.975)[0]).round(5)
                    self.df_train.iloc[i,j] += c

        # The first observation is the returns of the first day, the initial position, and the initial portfolio value
        observation = np.insert(self.df_train.iloc[self.current_step].values.flatten(),0,self.y_train.iloc[self.current_step])
        observation = np.concatenate((observation, [self.position.iloc[self.current_step,0], self.position.iloc[self.current_step,1], self.money.iloc[self.current_step,0], self.money.iloc[self.current_step,1], self.portfolio_value[self.current_step]]))

        return observation

    def render(self, mode='human'):
        # Render the environment to the screen
        if mode == 'human':
            print(f"Current Step: {self.current_step}")
            print(f"Current Position:\n Stock: {self.position.iloc[self.current_step,0]}\n R_f: {self.position.iloc[self.current_step,1]}")
            print(f"env.money:\n Stock: {self.money.iloc[self.current_step,0]}\n R_f: {self.money.iloc[self.current_step,1]}")
            print(f"Portfolio Value: {self.portfolio_value[self.current_step]}")
    
    def train(self, episodes, days):
        self.days_train = days
        for e in range(episodes):
            print(f"Episode: {e+1}/{episodes}")
            state = env.reset()
            # state = np.reshape(state, [1, state_size])
            for time in range(days):
                print(f"Port. Value: {env.portfolio_value[env.current_step]}") 
                action = agent.act(state)*0.15-1
                print(f"condition: {state[0]}")
                print(f"Action: {action}")
                next_state, reward, done = env.step(state,action)
                if agent.flag == 1:
                    agent.reward_pred *= (1+reward)
                    agent.flag = 0
                # next_state = np.reshape(next_state, [1, state_size])
                agent.remember(state, action, reward, next_state, done)
                self.render()
                print(f"Reward: {reward}\n")
                state = next_state
                if done:
                    print(f"Episode: {e+1}/{episodes}, Score: {time}, Epsilon: {agent.epsilon:.2}\n\n\n")
                    break
            if len(agent.memory) > 32:
                agent.replay(32)
    
    def backtest(self, agent, days_test):
        state = self.reset(noise=False)
        total_reward = 1
        for time in range(days_test):
            action = agent.act(state, train=False) * 0.15 - 1
            next_state, reward, done = self.step(state,action)
            total_reward *= (1 + reward)
            state = next_state
            if done:
                break
        annualized_return = (total_reward ** (252 / days_test) - 1) * 100
        return annualized_return
        





class DQN:
    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.memory = deque(maxlen=3000)
        self.gamma = 0.95  # discount rate
        self.epsilon = 1.0  # exploration rate
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995
        self.learning_rate = 0.001
        self.model = self._build_model()
        self.reward_pred = 1
        self.n_exploit = 0
        self.flag = 0

    def _build_model(self):
        model = Sequential()
        model.add(Dense(64, input_dim=self.state_size, activation='sigmoid'))
        model.add(Dense(64, activation='sigmoid'))
        model.add(Dense(self.action_size, activation='linear'))
        model.compile(loss='mse', optimizer=Adam(learning_rate=self.learning_rate))
        return model

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state, train=True):
        if train and np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        act_values = self.model.predict(state)
        print("EXPLOITATION")
        self.flag = 1
        self.n_exploit += 1
        return np.argmax(act_values[0])

    def replay(self, batch_size):
        minibatch = random.sample(self.memory, batch_size)
        for state, action, reward, next_state, done in minibatch:
            target = reward
            if not done:
                target = (reward + self.gamma * np.amax(self.model.predict(next_state)[0]))
            target_f = self.model.predict(state)
            target_f[0][int(action)] = target
            self.model.fit(state, target_f, epochs=1, verbose=0)
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

# %% [markdown]
# ## Short Training

# %%
rf = (1+0.02)**(1/252) - 1
tol = 0.01
episodes = 5
days_train = 252

env = TradingEnv(dataframe, rf)
state_size = env.observation_space.shape[0]
action_size = len(env.action_space)
agent = DQN(state_size, action_size)

env.train(episodes, days_train)
print(f"Annualized rewards predicted: {(agent.reward_pred**(252/agent.n_exploit)-1)*100:.2f}%")
# Out:
# C:\Users\pietr\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Episode: 1/5
# Port. Value: 1000
# condition: 0.02418057596621845
# Action: 0.7999999999999998
# Current Step: 1
# Current Position:
#  Stock: 0.7999999999999998
#  R_f: 0.20000000000000018
# env.money:
#  Stock: 821.0372090767454
#  R_f: 205.25930226918658
# Portfolio Value: 1026.296511345932
# Reward: 0.026296511345932003
#
# Port. Value: 1026.296511345932
# condition: -0.0034263788815134338
# Action: 0.5
# Current Step: 2
# Current Position:
#  Stock: 0.5
#  R_f: 0.5
# env.money:
#  Stock: 511.75213555023095
#  R_f: 511.75213555023095
# Portfolio Value: 1023.5042711004619
# Reward: -0.0027206954467849064
#
# Port. Value: 1023.5042711004619
# condition: 0.01939544568787658
# Action: -0.7
# Current Step: 3
# Current Position:
#  Stock: -0.7
#  R_f: 1.7
# env.money:
#  Stock: -723.4969206574458
#  R_f: 1757.0639501680828
# Portfolio Value: 1033.567029510637
# Reward: 0.009831672123220074
#
# Port. Value: 1033.567029510637
# condition: -0.01141033346427963
# Action: -0.55
# Current Step: 4
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money:
#  Stock: -573.0524414625571
#  R_f: 1614.9659713944789
# Portfolio Value: 1041.9135299319219
# Reward: 0.008075432151929894
#
# Port. Value: 1041.9135299319219
# condition: -0.003719062435792387
# Action: -0.25
# Current Step: 5
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money:
#  Stock: -261.0419253975562
#  R_f: 1305.2096269877811
# Portfolio Value: 1044.1677015902249
# Reward: 0.002163492068723093
#
# Port. Value: 1044.1677015902249
# condition: 0.02255963211393211
# Action: 1.4
# Current Step: 6
# Current Position:
#  Stock: 1.4
#  R_f: -0.3999999999999999
# env.money:
#  Stock: 1453.6400652338616
#  R_f: -415.32573292396035
# Portfolio Value: 1038.3143323099011
# Reward: -0.0056057750794333725
#
# Port. Value: 1038.3143323099011
# condition: 0.019172580901386984
# Action: -0.4
# Current Step: 7
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money:
#  Stock: -426.56824463831566
#  R_f: 1492.9888562341046
# Portfolio Value: 1066.420611595789
# Reward: 0.027069143140267433
#
# Port. Value: 1066.420611595789
# condition: 0.010763659495009091
# Action: -0.55
# Current Step: 8
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money:
#  Stock: -584.0569369148636
#  R_f: 1645.9786403964338
# Portfolio Value: 1061.9217034815701
# Reward: -0.004218699512462317
#
# Port. Value: 1061.9217034815701
# condition: -0.019931056921260647
# Action: -1.0
# Current Step: 9
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money:
#  Stock: -1073.576684122603
#  R_f: 2147.153368245206
# Portfolio Value: 1073.576684122603
# Reward: 0.010975367207225632
#
# Port. Value: 1073.576684122603
# condition: 0.01833086205637695
# Action: -1.0
# Current Step: 10
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money:
#  Stock: -1053.8843528594216
#  R_f: 2107.768705718843
# Portfolio Value: 1053.8843528594216
# Reward: -0.01834273373706436
#
# Port. Value: 1053.8843528594216
# condition: 0.010803467982168066
# Action: -0.4
# Current Step: 11
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money:
#  Stock: -417.0410647143312
#  R_f: 1459.643726500159
# Portfolio Value: 1042.6026617858279
# Reward: -0.01070486628156495
#
# Port. Value: 1042.6026617858279
# condition: 0.028430618108573183
# Action: 1.25
# Current Step: 12
# Current Position:
#  Stock: 1.25
#  R_f: -0.25
# env.money:
#  Stock: 1288.3630958539306
#  R_f: -257.6726191707861
# Portfolio Value: 1030.6904766831444
# Reward: -0.011425431316547378
#
# Port. Value: 1030.6904766831444
# condition: -0.022534706475492744
# Action: 1.5499999999999998
# Current Step: 13
# Current Position:
#  Stock: 1.5499999999999998
#  R_f: -0.5499999999999998
# env.money:
#  Stock: 1553.0411366210815
#  R_f: -551.0791129945773
# Portfolio Value: 1001.9620236265043
# Reward: -0.02787301688193614
#
# Port. Value: 1001.9620236265043
# condition: -0.010060018605825734
# Action: 0.050000000000000044
# Current Step: 14
# Current Position:
#  Stock: 0.050000000000000044
#  R_f: 0.95
# env.money:
#  Stock: 49.318670923834844
#  R_f: 937.0547475528612
# Portfolio Value: 986.373418476696
# Reward: -0.015558079829599643
#
# Port. Value: 986.373418476696
# condition: -0.005255235323068503
# Action: 1.25
# Current Step: 15
# Current Position:
#  Stock: 1.25
#  R_f: -0.25
# env.money:
#  Stock: 1232.7356943573432
#  R_f: -246.54713887146863
# Portfolio Value: 986.1885554858745
# Reward: -0.0001874168416936217
#
# Port. Value: 986.1885554858745
# condition: -0.031253063316810895
# Action: -0.55
# Current Step: 16
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money:
#  Stock: -521.5310267536994
#  R_f: 1469.7692572149708
# Portfolio Value: 948.2382304612715
# Reward: -0.03848181446995768
#
# Port. Value: 948.2382304612715
# condition: 0.05181704199088357
# Action: 0.95
# Current Step: 17
# Current Position:
#  Stock: 0.95
#  R_f: 0.050000000000000044
# env.money:
#  Stock: 874.5862720769329
#  R_f: 46.030856425101774
# Portfolio Value: 920.6171285020347
# Reward: -0.029128863477483436
#
# Port. Value: 920.6171285020347
# condition: -0.021475075192581777
# Action: -0.55
# Current Step: 18
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money:
#  Stock: -496.12154587338625
#  R_f: 1398.160720188634
# Portfolio Value: 902.0391743152477
# Reward: -0.02017989195683962
#
# Port. Value: 902.0391743152477
# condition: -0.010667744507400245
# Action: 1.25
# Current Step: 19
# Current Position:
#  Stock: 1.25
#  R_f: -0.25
# env.money:
#  Stock: 1134.2667714965328
#  R_f: -226.85335429930655
# Portfolio Value: 907.4134171972262
# Reward: 0.005957881913563413
#
# Port. Value: 907.4134171972262
# condition: 0.010379453545609513
# Action: 0.19999999999999996
# Current Step: 20
# Current Position:
#  Stock: 0.19999999999999996
#  R_f: 0.8
# env.money:
#  Stock: 183.84599403129923
#  R_f: 735.3839761251971
# Portfolio Value: 919.2299701564964
# Reward: 0.013022237422682813
#
# Port. Value: 919.2299701564964
# condition: 0.025300386686923464
# Action: 1.1
# Current Step: 21
# Current Position:
#  Stock: 1.1
#  R_f: -0.10000000000000009
# env.money:
#  Stock: 1016.3983226973866
#  R_f: -92.39984751794431
# Portfolio Value: 923.9984751794423
# Reward: 0.005187499513461304
#
# Port. Value: 923.9984751794423
# condition: -0.01954502539795756
# Action: -0.4
# Current Step: 22
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money:
#  Stock: -361.7274241691456
#  R_f: 1266.0459845920095
# Portfolio Value: 904.3185604228639
# Reward: -0.021298644191762833
#
# Port. Value: 904.3185604228639
# condition: -0.013618352812384625
# Action: 1.4
# Current Step: 23
# Current Position:
#  Stock: 1.4
#  R_f: -0.3999999999999999
# env.money:
#  Stock: 1273.0351103499079
#  R_f: -363.72431724283075
# Portfolio Value: 909.3107931070771
# Reward: 0.005520435942262156
#
# Port. Value: 909.3107931070771
# condition: 0.028889449292976717
# Action: -0.4
# Current Step: 24
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money:
#  Stock: -378.6383534941326
#  R_f: 1325.234237229464
# Portfolio Value: 946.5958837353315
# Reward: 0.04100368203136891
#
# Port. Value: 946.5958837353315
# condition: -0.004011024752954676
# Action: 0.19999999999999996
# Current Step: 25
# Current Position:
#  Stock: 0.19999999999999996
#  R_f: 0.8
# env.money:
#  Stock: 189.6431426480126
#  R_f: 758.5725705920506
# Portfolio Value: 948.2157132400632
# Reward: 0.0017112154537792055
#
# Port. Value: 948.2157132400632
# condition: 0.01985061988549354
# Action: -0.4
# Current Step: 26
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money:
#  Stock: -380.8309888768073
#  R_f: 1332.9084610688253
# Portfolio Value: 952.0774721920181
# Reward: 0.0040726586767469335
#
# Port. Value: 952.0774721920181
# condition: 0.040935068149600004
# Action: 0.5
# Current Step: 27
# Current Position:
#  Stock: 0.5
#  R_f: 0.5
# env.money:
#  Stock: 468.1347010652237
#  R_f: 468.1347010652237
# Portfolio Value: 936.2694021304474
# Reward: -0.01660376442389193
#
# Port. Value: 936.2694021304474
# condition: 0.019368292904712314
# Action: -0.85
# Current Step: 28
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money:
#  Stock: -803.6423055847914
#  R_f: 1749.103841566899
# Portfolio Value: 945.4615359821075
# Reward: 0.009817830029202923
#
# Port. Value: 945.4615359821075
# condition: 0.018217220670236983
# Action: 1.4
# Current Step: 29
# Current Position:
#  Stock: 1.4
#  R_f: -0.3999999999999999
# env.money:
#  Stock: 1303.1545734040276
#  R_f: -372.32987811543643
# Portfolio Value: 930.8246952885912
# Reward: -0.015481159345432446
#
# Port. Value: 930.8246952885912
# condition: 0.025563608157348094
# Action: -0.7
# Current Step: 30
# Current Position:
#  Stock: -0.7
#  R_f: 1.7
# env.money:
#  Stock: -675.1767573724638
#  R_f: 1639.7149821902694
# Portfolio Value: 964.5382248178056
# Reward: 0.03621898913926204
#
# Port. Value: 964.5382248178056
# condition: 0.013176980999959181
# Action: -0.7
# Current Step: 31
# Current Position:
#  Stock: -0.7
#  R_f: 1.7
# env.money:
#  Stock: -668.9979909782168
#  R_f: 1624.7094066613838
# Portfolio Value: 955.7114156831669
# Reward: -0.009151331598398794
#
# Port. Value: 955.7114156831669
# condition: -0.003954584761630766
# Action: 1.6999999999999997
# Current Step: 32
# Current Position:
#  Stock: 1.6999999999999997
#  R_f: -0.6999999999999997
# env.money:
#  Stock: 1629.415113253031
#  R_f: -670.9356348688949
# Portfolio Value: 958.479478384136
# Reward: 0.002896337383382993
#
# Port. Value: 958.479478384136
# condition: 0.01803139892910901
# Action: 1.4
# Current Step: 33
# Current Position:
#  Stock: 1.4
#  R_f: -0.3999999999999999
# env.money:
#  Stock: 1383.3034223918244
#  R_f: -395.2295492548069
# Portfolio Value: 988.0738731370175
# Reward: 0.030876398942597666
#
# Port. Value: 988.0738731370175
# condition: -0.0015691904314462557
# Action: 0.5
# Current Step: 34
# Current Position:
#  Stock: 0.5
#  R_f: 0.5
# env.money:
#  Stock: 492.9369248778419
#  R_f: 492.9369248778419
# Portfolio Value: 985.8738497556838
# Reward: -0.002226577831016732
#
# Port. Value: 985.8738497556838
# condition: 0.016457744703433266
# Action: 1.85
# Current Step: 35
# Current Position:
#  Stock: 1.85
#  R_f: -0.8500000000000001
# env.money:
#  Stock: 1839.0708341365034
#  R_f: -844.9784913600151
# Portfolio Value: 994.0923427764883
# Reward: 0.008336252171452996
#
# Port. Value: 994.0923427764883
# condition: 0.005638360031764301
# Action: 1.4
# Current Step: 36
# Current Position:
#  Stock: 1.4
#  R_f: -0.3999999999999999
# env.money:
#  Stock: 1406.1944004404238
#  R_f: -401.7698286972639
# Portfolio Value: 1004.42457174316
# Reward: 0.010393630975784272
#
# Port. Value: 1004.42457174316
# condition: 0.00644078494945345
# Action: 0.6499999999999999
# Current Step: 37
# Current Position:
#  Stock: 0.6499999999999999
#  R_f: 0.3500000000000001
# env.money:
#  Stock: 658.7614957406134
#  R_f: 354.71772847571503
# Portfolio Value: 1013.4792242163285
# Reward: 0.00901476599427903
#
# Port. Value: 1013.4792242163285
# condition: -0.0061180038334373195
# Action: 1.4
# Current Step: 38
# Current Position:
#  Stock: 1.4
#  R_f: -0.3999999999999999
# env.money:
#  Stock: 1413.2847371160406
#  R_f: -403.79563917601155
# Portfolio Value: 1009.4890979400291
# Reward: -0.003937057791574136
#
# Port. Value: 1009.4890979400291
# condition: 0.03741766180113049
# Action: -0.4
# Current Step: 39
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money:
#  Stock: -425.3363955839422
#  R_f: 1488.6773845437974
# Portfolio Value: 1063.3409889598554
# Reward: 0.05334568855643602
#
# Port. Value: 1063.3409889598554
# condition: 0.006495012966228956
# Action: -0.25
# Current Step: 40
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money:
#  Stock:
# Current Position:
#  Stock: 0.19999999999999996
#  R_f: 0.8
# env.money:
#  Stock: 248.53857901253477
#  R_f: 994.1543160501393
# Portfolio Value: 1242.692895062674
# Reward: -0.012359134373475756
#
# Port. Value: 1242.692895062674
# condition: 0.0018169325924714199
# Action: 0.050000000000000044
# Current Step: 83
# Current Position:
#  Stock: 0.050000000000000044
#  R_f: 0.95
# env.money:
#  Stock: 62.16115044792233
#  R_f: 1181.061858510523
# Portfolio Value: 1243.2230089584455
# Reward: 0.00042658479651533604
#
# Port. Value: 1243.2230089584455
# condition: 0.025691723163436417
# Action: 1.25
# Current Step: 84
# Current Position:
#  Stock: 1.25
#  R_f: -0.25
# env.money:
#  Stock: 1556.166927147532
#  R_f: -311.2333854295064
# Portfolio Value: 1244.9335417180257
# Reward: 0.0013758856997131241
#
# Port. Value: 1244.9335417180257
# condition: 0.010955556820535218
# Action: 0.050000000000000044
# Current Step: 85
# Current Position:
#  Stock: 0.050000000000000044
#  R_f: 0.95
# env.money:
#  Stock: 63.102574474822575
#  R_f: 1198.9489150216277
# Portfolio Value: 1262.0514894964504
# Reward: 0.013750089627115068
#
# Port. Value: 1262.0514894964504
# condition: -0.047102970421502854
# Action: 1.4
# Current Step: 86
# Current Position:
#  Stock: 1.4
#  R_f: -0.3999999999999999
# env.money:
#  Stock: 1762.9392289057128
#  R_f: -503.69692254448927
# Portfolio Value: 1259.2423063612234
# Reward: -0.002225886311776214
#
# Port. Value: 1259.2423063612234
# condition: -0.0017943400182062483
# Action: 0.050000000000000044
# Current Step: 87
# Current Position:
#  Stock: 0.050000000000000044
#  R_f: 0.95
# env.money:
#  Stock: 62.80211236460088
#  R_f: 1193.2401349274157
# Portfolio Value: 1256.0422472920166
# Reward: -0.002541257590410809
#
# Port. Value: 1256.0422472920166
# condition: 0.00910460225739928
# Action: -0.7
# Current Step: 88
# Current Position:
#  Stock: -0.7
#  R_f: 1.7
# env.money:
#  Stock: -879.6972919859182
#  R_f: 2136.4077091086588
# Portfolio Value: 1256.7104171227404
# Reward: 0.0005319644559443807
#
# Port. Value: 1256.7104171227404
# condition: 0.01795837628695385
# Action: -0.85
# Current Step: 89
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money:
#  Stock: -1054.7970161053393
#  R_f: 2295.7346821116207
# Portfolio Value: 1240.9376660062815
# Reward: -0.012550823882379306
#
# Port. Value: 1240.9376660062815
# condition: -0.01551874566975481
# Action: 0.5
# Current Step: 90
# Current Position:
#  Stock: 0.5
#  R_f: 0.5
# env.money:
#  Stock: 628.6804215725198
#  R_f: 628.6804215725198
# Portfolio Value: 1257.3608431450396
# Reward: 0.01323449000594278
#
# Port. Value: 1257.3608431450396
# condition: -0.0007201702396370819
# Action: 1.4
# Current Step: 91
# Current Position:
#  Stock: 1.4
#  R_f: -0.3999999999999999
# env.money:
#  Stock: 1759.7407156301563
#  R_f: -502.783061608616
# Portfolio Value: 1256.9576540215403
# Reward: -0.0003206630186532309
#
# Port. Value: 1256.9576540215403
# condition: 0.0032047622041563514
# Action: 0.34999999999999987
# Current Step: 92
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money:
#  Stock: 441.8983589120872
#  R_f: 820.6683808367338
# Portfolio Value: 1262.566739748821
# Reward: 0.004462430145784808
#
# Port. Value: 1262.566739748821
# condition: -0.024897188334790123
# Action: -1.0
# Current Step: 93
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money:
#  Stock: -1251.7650354262412
#  R_f: 2503.5300708524824
# Portfolio Value: 1251.7650354262412
# Reward: -0.008555353140958477
#
# Port. Value: 1251.7650354262412
# condition: -0.008380004258005275
# Action: -0.4
# Current Step: 94
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money:
#  Stock: -504.9630967064752
#  R_f: 1767.3708384726629
# Portfolio Value: 1262.4077417661879
# Reward: 0.008502159781386392
#
# Port. Value: 1262.4077417661879
# condition: -0.0464121373085326
# Action: -0.10000000000000009
# Current Step: 95
# Current Position:
#  Stock: -0.10000000000000009
#  R_f: 1.1
# env.money:
#  Stock:
# Current Position:
#  Stock: 1.1
#  R_f: -0.10000000000000009
# env.money:
#  Stock: 724.7055122444433
#  R_f: -65.88231929494945
# Portfolio Value: 658.8231929494939
# Reward: -0.0029722009037998656
#
# Port. Value: 658.8231929494939
# condition: 0.02580598044192607
# Action: 0.19999999999999996
# Current Step: 241
# Current Position:
#  Stock: 0.19999999999999996
#  R_f: 0.8
# env.money:
#  Stock: 135.55262987605096
#  R_f: 542.210519504204
# Portfolio Value: 677.763149380255
# Reward: 0.028748162835568282
#
# Port. Value: 677.763149380255
# condition: -0.03490548135960743
# Action: 1.1
# Current Step: 242
# Current Position:
#  Stock: 1.1
#  R_f: -0.10000000000000009
# env.money:
#  Stock: 740.4714403302127
#  R_f: -67.31558548456483
# Portfolio Value: 673.1558548456478
# Reward: -0.006797794390001948
#
# Port. Value: 673.1558548456478
# condition: 0.0013357816944976767
# Action: -0.7
# Current Step: 243
# Current Position:
#  Stock: -0.7
#  R_f: 1.7
# env.money:
#  Stock: -471.8982337720801
#  R_f: 1146.0385677321947
# Portfolio Value: 674.1403339601145
# Reward: 0.0014624831788656607
#
# Port. Value: 674.1403339601145
# condition: 0.01671072753495666
# Action: -0.4
# Current Step: 244
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money:
#  Stock: -266.5113502223836
#  R_f: 932.7897257783425
# Portfolio Value: 666.278375555959
# Reward: -0.011662198518774107
#
# Port. Value: 666.278375555959
# condition: -0.014802814966699435
# Action: -0.4
# Current Step: 245
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money:
#  Stock: -268.1070964420822
#  R_f: 938.3748375472876
# Portfolio Value: 670.2677411052055
# Reward: 0.005987535684191554
#
# Port. Value: 670.2677411052055
# condition: 0.013462087431742684
# Action: -0.10000000000000009
# Current Step: 246
# Current Position:
#  Stock: -0.10000000000000009
#  R_f: 1.1
# env.money:
#  Stock: -66.67077984497372
#  R_f: 733.3785782947103
# Portfolio Value: 666.7077984497366
# Reward: -0.00531122480935579
#
# Port. Value: 666.7077984497366
# condition: -0.00928710157722371
# Action: 0.5
# Current Step: 247
# Current Position:
#  Stock: 0.5
#  R_f: 0.5
# env.money:
#  Stock: 333.6908714808001
#  R_f: 333.6908714808001
# Portfolio Value: 667.3817429616003
# Reward: 0.0010108544004295654
#
# Port. Value: 667.3817429616003
# condition: -0.016568285680596307
# Action: 0.050000000000000044
# Current Step: 248
# Current Position:
#  Stock: 0.050000000000000044
#  R_f: 0.95
# env.money:
#  Stock: 33.09624144365301
#  R_f: 628.8285874294066
# Portfolio Value: 661.9248288730596
# Reward: -0.008176600792710981
#
# Port. Value: 661.9248288730596
# condition: 0.0014263136975120223
# Action: 1.5499999999999998
# Current Step: 249
# Current Position:
#  Stock: 1.5499999999999998
#  R_f: -0.5499999999999998
# env.money:
#  Stock: 1026.1333011837114
#  R_f: -364.1118165490588
# Portfolio Value: 662.0214846346526
# Reward: 0.00014602226321909446
#
# Port. Value: 662.0214846346526
# condition: -0.014568002769877887
# Action: -0.55
# Current Step: 250
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money:
#  Stock: -355.93388477171715
#  R_f: 1003.0864025384755
# Portfolio Value: 647.1525177667584
# Reward: -0.022459946108999575
#
# Port. Value: 647.1525177667584
# condition: 0.029512668988379006
# Action: 1.1
# Current Step: 251
# Current Position:
#  Stock: 1.1
#  R_f: -0.10000000000000009
# env.money:
#  Stock: 700.2272654518822
#  R_f: -63.65702413198934
# Portfolio Value: 636.5702413198928
# Reward: -0.016352059454830887
#
# Episode: 5/5, Score: 250, Epsilon: 0.98
#
#
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Annualized rewards predicted: -77.00%

# %%
annualized_return = env.backtest(agent, days_test=252)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION

# %%
print(f"Annualized Return on backtesting: {annualized_return:.2f}%")
# Out:
# Annualized Return on backtesting: 88.54%

# %% [markdown]
# ## Longer Training

# %%
rf = (1+0.02)**(1/252) - 1
tol = 0.01
episodes = 20
days_train = 100

env = TradingEnv(dataframe, rf)
state_size = env.observation_space.shape[0]
action_size = len(env.action_space)
agent = DQN(state_size, action_size)

env.train(episodes, days_train)
print(f"Annualized rewards predicted: {(agent.reward_pred**(252/agent.n_exploit)-1)*100:.2f}%")
# Out:
# C:\Users\pietr\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
#
# Current Position:
#  Stock: 0.7999999999999998
#  R_f: 0.20000000000000018
# env.money:
#  Stock: 804.3751529439116
#  R_f: 201.0937882359781
# Portfolio Value: 1005.4689411798897
# Reward: 0.000930743223771984
#
# Port. Value: 1005.4689411798897
# condition: 0.04405323735177419
# Action: 1.1
# Current Step: 14
# Current Position:
#  Stock: 1.1
#  R_f: -0.10000000000000009
# env.money:
#  Stock: 1145.883401279562
#  R_f: -104.17121829814208
# Portfolio Value: 1041.7121829814198
# Reward: 0.036046107758435225
#
# Port. Value: 1041.7121829814198
# condition: 0.011854758090725278
# Action: -0.85
# Current Step: 15
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money:
#  Stock: -897.0636541339128
#  R_f: 1952.4326589973398
# Portfolio Value: 1055.3690048634269
# Reward: 0.013109976157637647
#
# Port. Value: 1055.3690048634269
# condition: 0.011783697025104527
# Action: 0.34999999999999987
# Current Step: 16
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money:
#  Stock: 365.71121435929416
#  R_f: 679.1779695244038
# Portfolio Value: 1044.889183883698
# Reward: -0.009930006406702297
#
# Port. Value: 1044.889183883698
# condition: -0.027583053168709938
# Action: 1.1
# Current Step: 17
# Current Position:
#  Stock: 1.1
#  R_f: -0.10000000000000009
# env.money:
#  Stock: 1138.4922734941833
#  R_f: -103.4992975903804
# Portfolio Value: 1034.992975903803
# Reward: -0.009471059833457474
#
# Port. Value: 1034.992975903803
# condition: 0.009241204569980259
# Action: -0.25
# Current Step: 18
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money:
#  Stock: -261.3886615138773
#  R_f: 1306.9433075693864
# Portfolio Value: 1045.5546460555092
# Reward: 0.010204581477940308
#
# Port. Value: 1045.5546460555092
# condition: 0.004325753224005538
# Action: 0.050000000000000044
# Current Step: 19
# Current Position:
#  Stock: 0.050000000000000044
#  R_f: 0.95
# env.money:
#  Stock: 52.226210008669135
#  R_f: 992.2979901647127
# Portfolio Value: 1044.5242001733818
# Reward: -0.0009855495224615133
#
# Port. Value: 1044.5242001733818
# condition: -0.01066454888269627
# Action: 1.6999999999999997
# Current Step: 20
# Current Position:
#  Stock: 1.6999999999999997
#  R_f: -0.6999999999999997
# env.money:
#  Stock: 1774.8818894516487
#  R_f: -730.8337191859729
# Portfolio Value: 1044.048170265676
# Reward: -0.0004557385148442345
#
# Port. Value: 1044.048170265676
# condition: -0.007398672756877712
# Action: -0.4
# Current Step: 21
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money:
#  Stock: -412.36297068343265
#  R_f: 1443.2703973920143
# Portfolio Value: 1030.9074267085816
# Reward: -0.012586338381063801
#
# Port. Value: 1030.9074267085816
# condition: -0.011088951239947594
# Action: 0.19999999999999996
# Current Step: 22
# Current Position:
#  Stock: 0.19999999999999996
#  R_f: 0.8
# env.money:
#  Stock: 207.11365185692028
#  R_f: 828.4546074276814
# Portfolio Value: 1035.5682592846017
# Reward: 0.004521097098796646
#
# Port. Value: 1035.5682592846017
# condition: -0.01586942536767093
# Action: -0.25
# Current Step: 23
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money:
#  Stock: -258.09313272573985
#  R_f: 1290.4656636286993
# Portfolio Value: 1032.3725309029594
# Reward: -0.0030859659447750997
#
# Port. Value: 1032.3725309029594
# condition: -0.00014945984059740874
# Action: 1.25
# Current Step: 24
# Current Position:
#  Stock: 1.25
#  R_f: -0.25
# env.money:
#  Stock: 1290.6406421852691
#  R_f: -258.1281284370538
# Portfolio Value: 1032.5125137482153
# Reward: 0.0001355933454888004
#
# Port. Value: 1032.5125137482153
# condition: -0.0030538310406957128
# Action: 1.4
# Current Step: 25
# Current Position:
#  Stock: 1.4
#  R_f: -0.3999999999999999
# env.money:
#  Stock: 1439.9795793175879
#  R_f: -411.4227369478822
# Portfolio Value: 1028.5568423697057
# Reward: -0.003831112287588404
#
# Port. Value: 1028.5568423697057
# condition: 0.0006218855067668177
# Action: 0.95
# Current Step: 26
# Current Position:
#  Stock: 0.95
#  R_f: 0.050000000000000044
# env.money:
#  Stock: 977.9492770921344
#  R_f: 51.47101458379659
# Portfolio Value: 1029.420291675931
# Reward: 0.0008394765079156036
#
# Port. Value: 1029.420291675931
# condition: 0.0004861305915062619
# Action: -1.0
# Current Step: 27
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money:
#  Stock: -
# Current Position:
#  Stock: 1.4
#  R_f: -0.3999999999999999
# env.money:
#  Stock: 1813.2858668766846
#  R_f: -518.0816762504812
# Portfolio Value: 1295.2041906262034
# Reward: 0.011490631429966914
#
# Port. Value: 1295.2041906262034
# condition: -0.01027688283444818
# Action: 0.34999999999999987
# Current Step: 70
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money:
#  Stock: 446.8183923377783
#  R_f: 829.8055857701602
# Portfolio Value: 1276.6239781079385
# Reward: -0.014345392527862197
#
# Port. Value: 1276.6239781079385
# condition: 0.02978783502951093
# Action: -0.4
# Current Step: 71
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money:
#  Stock: -516.0796633270065
#  R_f: 1806.2788216445226
# Portfolio Value: 1290.1991583175163
# Reward: 0.010633655988271032
#
# Port. Value: 1290.1991583175163
# condition: -0.01710462245730895
# Action: 0.6499999999999999
# Current Step: 72
# Current Position:
#  Stock: 0.6499999999999999
#  R_f: 0.3500000000000001
# env.money:
#  Stock: 844.4107014241683
#  R_f: 454.6826853822447
# Portfolio Value: 1299.093386806413
# Reward: 0.006893686475888909
#
# Port. Value: 1299.093386806413
# condition: -0.003785648670724554
# Action: -0.4
# Current Step: 73
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money:
#  Stock: -518.375407529473
#  R_f: 1814.3139263531552
# Portfolio Value: 1295.9385188236824
# Reward: -0.0024285151589342377
#
# Port. Value: 1295.9385188236824
# condition: -0.0028293465175962757
# Action: 0.5
# Current Step: 74
# Current Position:
#  Stock: 0.5
#  R_f: 0.5
# env.money:
#  Stock: 648.7728436690081
#  R_f: 648.7728436690081
# Portfolio Value: 1297.5456873380163
# Reward: 0.0012401579943720068
#
# Port. Value: 1297.5456873380163
# condition: 0.010988740435812666
# Action: 1.1
# Current Step: 75
# Current Position:
#  Stock: 1.1
#  R_f: -0.10000000000000009
# env.money:
#  Stock: 1435.2416999936727
#  R_f: -130.47651818124308
# Portfolio Value: 1304.7651818124295
# Reward: 0.005563961673846315
#
# Port. Value: 1304.7651818124295
# condition: 0.011760665287008913
# Action: 1.4
# Current Step: 76
# Current Position:
#  Stock: 1.4
#  R_f: -0.3999999999999999
# env.money:
#  Stock: 1850.4275612019458
#  R_f: -528.6935889148416
# Portfolio Value: 1321.7339722871043
# Reward: 0.01300524470702356
#
# Port. Value: 1321.7339722871043
# condition: 0.017285148844396876
# Action: 0.7999999999999998
# Current Step: 77
# Current Position:
#  Stock: 0.7999999999999998
#  R_f: 0.20000000000000018
# env.money:
#  Stock: 1083.1642979183455
#  R_f: 270.7910744795867
# Portfolio Value: 1353.9553723979323
# Reward: 0.024378128115351873
#
# Port. Value: 1353.9553723979323
# condition: 0.03911087085386247
# Action: -0.7
# Current Step: 78
# Current Position:
#  Stock: -0.7
#  R_f: 1.7
# env.money:
#  Stock: -978.0256464045344
#  R_f: 2375.205141268155
# Portfolio Value: 1397.1794948636207
# Reward: 0.03192433321427429
#
# Port. Value: 1397.1794948636207
# condition: 0.009963596881675111
# Action: -0.25
# Current Step: 79
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money:
#  Stock: -346.8931973524038
#  R_f: 1734.465986762019
# Portfolio Value: 1387.572789409615
# Reward: -0.0068757847429927335
#
# Port. Value: 1387.572789409615
# condition: -0.01058745564843325
# Action: 0.19999999999999996
# Current Step: 80
# Current Position:
#  Stock: 0.19999999999999996
#  R_f: 0.8
# env.money:
#  Stock: 278.27248694667907
#  R_f: 1113.0899477867165
# Portfolio Value: 1391.3624347333955
# Reward: 0.002731132631530505
#
# Port. Value: 1391.3624347333955
# condition: -0.0014507268516183464
# Action: 0.6499999999999999
# Current Step: 81
# Current Position:
#  Stock: 0.6499999999999999
#  R_f: 0.3500000000000001
# env.money:
#  Stock: 904.1802264035057
#  R_f: 486.866275755734
# Portfolio Value: 1391.0465021592397
# Reward: -0.0002270670576328533
#
# Port. Value: 1391.0465021592397
# condition: 0.006270675795288075
# Action: 1.4
# Current Step: 82
# Current Position:
#  Stock: 1.4
#  R_f: -0.3999999999999999
# env.money:
#  Stock: 1955.481356637556
#  R_f: -558.7089590393017
# Portfolio Value: 1396.7723975982544
# Reward: 0.004116250197334704
#
# Port. Value: 1396.7723975982544
# condition: -0.06470849954824716
# Action: 1.5499999999999998
# Current Step: 83
# Current Position:
#  Stock: 1.5499999999999998
#  R_f: -0.5499999999999998
# env.money:
#  Stock: 
# Current Position:
#  Stock: 1.6999999999999997
#  R_f: -0.6999999999999997
# env.money:
#  Stock: 2064.9722459745512
#  R_f: -850.2826895189326
# Portfolio Value: 1214.6895564556185
# Reward: -0.008544189694952693
#
# Port. Value: 1214.6895564556185
# condition: -0.004263146600246534
# Action: 1.6999999999999997
# Current Step: 97
# Current Position:
#  Stock: 1.6999999999999997
#  R_f: -0.6999999999999997
# env.money:
#  Stock: 2049.9249329071818
#  R_f: -844.0867370794276
# Portfolio Value: 1205.8381958277541
# Reward: -0.007286932353063109
#
# Port. Value: 1205.8381958277541
# condition: 0.01990392973242317
# Action: -0.55
# Current Step: 98
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money:
#  Stock: -685.8402035899334
#  R_f: 1932.8223919352665
# Portfolio Value: 1246.9821883453333
# Reward: 0.034120657862670885
#
# Port. Value: 1246.9821883453333
# condition: -0.0016873404907736778
# Action: 0.34999999999999987
# Current Step: 99
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money:
#  Stock: 436.9016222345322
#  R_f: 811.3887270069889
# Portfolio Value: 1248.2903492415212
# Reward: 0.001049061412756645
#
# Episode: 1/20, Score: 98, Epsilon: 1.0
#
#
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Episode: 2/20
# Port. Value: 1000
# condition: -0.009479915633814728
# Action: 1.5499999999999998
# Current Step: 1
# Current Position:
#  Stock: 1.5499999999999998
#  R_f: -0.5499999999999998
# env.money:
#  Stock: 1553.0756274243447
#  R_f: -551.0913516667028
# Portfolio Value: 1001.9842757576419
# Reward: 0.0019842757576418535
#
# Port. Value: 1001.9842757576419
# condition: -0.023793092933255284
# Action: 1.85
# Current Step: 2
# Current Position:
#  Stock: 1.85
#  R_f: -0.8500000000000001
# env.money:
#  Stock: 1786.0355774405746
#  R_f: -820.6109409862099
# Portfolio Value: 965.4246364543645
# Reward: -0.036487238560338746
#
# Port. Value: 965.4246364543645
# condition: -0.0015960867254755469
# Action: 1.4
# Current Step: 3
# Current Position:
#  Stock: 1.4
#  R_f: -0.3999999999999999
# env.money:
#  Stock: 1347.5164568058956
#  R_f: -385.0047019445415
# Portfolio Value: 962.511754861354
# Reward: -0.003017202465133296
#
# Port. Value: 962.511754861354
# condition: -0.007081105997486089
# Action: 1.85
# Current Step: 4
# Current Position:
#  Stock: 1.85
#  R_f: -0.8500000000000001
# env.money:
#  Stock: 1763.0005984349057
#  R_f: -810.0273019836053
# Portfolio Value: 952.9732964513003
# Reward: -0.009909965630942062
#
# Port. Value: 952.9732964513003
# condition: 0.0286675102705839
# Action: 1.4
# Current Step: 5
# Current Position:
#  Stock: 1.4
#  R_f: -0.3999999999999999
# env.money:
#  Stock: 1405.8546471032687
#  R_f: -401.67275631521954
# Portfolio Value: 1004.1818907880491
# Reward: 0.053735602589747695
#
# Port. Value: 1004.1818907880491
# condition: 0.022661770472273586
# Action: 1.4
# Current Step: 6
# Current Position:
#  Stock: 1.4
#  R_f: -0.3999999999999999
# env.money:
#  Stock: 1450.9225017689464
#  R_f: -414.54928621969896
# Portfolio Value: 1036.3732155492476
# Reward: 0.03205726478092103
#
# Port. Value: 1036.3732155492476
# condition: -0.017306819014703295
# Action: 1.5499999999999998
# Current Step: 7
# Current Position:
#  Stock: 1.5499999999999998
#  R_f: -0.5499999999999998
# env.money:
#  Stock: 1567.7410386959004
#  R_f: -556.2952072791903
# Portfolio Value: 1011.44583141671
# Reward: -0.024052516756067233
#
# Port. Value: 1011.44583141671
# condition: 0.01786205406344148
# Action: -0.4
# Current Step: 8
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money:
#  Stock: -415.86271286120467
#  R_f: 1455.519495014216
# Portfolio Value: 1039.6567821530116
# Reward: 0.02789170696050734
#
# Port. Value: 1039.6567821530116
# condition: 0.014472505919923679
# Action: -0.10000000000000009
# Current Step: 9
# Current Position:
#  Stock: -0.10000000000000009
#  R_f: 1.1
# env.money:
#  Stock: -103.37088256947546
#  R_f: 1137.079708264229
# Portfolio Value: 1033.7088256947536
# Reward: -0.005721076955743445
#
# Port. Value: 1033.7088256947536
# condition: -0.019384774109453516
# Action: -0.55
# Current Step: 10
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money:
#  Stock: -569.6804890287525
#  R_f: 1605.4631963537568
# Portfolio Value: 1035.7827073250044
# Reward: 0.002006253191131363
#
# Port. Value: 1035.7827073250044
# condition: 0.01069057596621845
# Action: 1.4
# Current Step: 11
# Current Position:
#  Stock: 1.4
#  R_f: -0.3999999999999999
# env.money:
#  Stock: 1441.700385657402
#  R_f: -411.91439590211473
# Portfolio Value: 1029.7859897552871
# Reward: -0.005789551734460091
#
# Port. Value: 1029.7859897552871
# condition: 0.023703621118486565
# Action: 0.6499999999999999
# Current Step: 12
# Current Position:
#  Stock: 0.6499999999999999
#  R_f: 0.3500000000000001
# env.money:
#  Stock: 691.8179947001421
#  R_f: 372.5173817616151
# Portfolio Value: 1064.3353764617573
# Reward: 0.03355006481946826
#
# Port. Value: 1064.3353764617573
# condition: 0.03780544568787658
# Action: -0.25
# Current Step: 13
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money:
#  Stock: -272.75495473259645
#  R_f: 1363.7747736629822
# Portfolio Value: 1091.0198189303858
# Reward: 0.025071460611726933
#
# Port. Value: 1091.0198189303858
# condition: -0.01621033346427963
# Action: 1.6999999999999997
# Current Step: 14
# Current Position:
#  Stock: 1.6999999999999997
#  R_f: -0.6999999999999997
# env.money:
#  Stock: 1862.3717534403504
#  R_f: -766.8589572989677
# Portfolio Value: 1095.5127961413828
# Reward: 0.004118144448926505
#
# Port. Value: 1095.5127961413828
# condition: 0.026010937564207616
# Action: 1.25
# Current Step: 15
# Current Position:
#  Stock: 1.25
#  R_f: -0.25
# env.money:
#  Stock: 1430.6625968194699
#  R_f: -286.13251936389395
# Portfolio Value: 1144.5300774555758
# Reward: 0.044743686688865525
#
# Port. Value: 1144.5300774555758
# condition: 0.012699632113932107
# Action: -0.25
# Current Step: 16
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money:
#  Stock: -290.69808486102033
#  R_f: 1453.4904243051017
# Portfolio Value: 1162.7923394440813
# Reward: 0.01595612238439787
#
# Port. Value: 1162.7923394440813
# condition: 0.012142580901386984
# Action: -0.10000000000000009
# Current Step: 17
# Current Position:
#  Stock: -0.10000000000000009
#  R_f: 1.1
# env.money:
#  Stock: -115.93552192936944
#  R_f: 1275.290741223063
# Portfolio Value: 1159.3552192936934
# Reward: -0.002955919155806621
#
# Port. Value: 1159.3552192936934
# condition: 0.01397365949500909
# Action: -0.25
# Current Step: 18
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money:
#  Stock: -289.45600564011426
#  R_f: 1447.2800282005712
# Portfolio Value: 1157.824022560457
# Reward: -0.0013207313062938535
#
# Port. Value: 1157.824022560457
# condition: 0.003208943078739355
# Action: 0.34999999999999987
# Current Step: 19
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money:
#  Stock: 404.9525960292017
#  R_f: 752.0548211970893
# Portfolio Value: 1157.007417226291
# Reward: -0.0007052931345820561
#
# Port. Value: 1157.007417226291
# condition: -0.02802913794362305
# Action: 0.7999999999999998
# Current Step: 20
# Current Position:
#  Stock: 0.7999999999999998
#  R_f: 0.20000000000000018
# env.money:
#  Stock: 916.6989130805317
#  R_f: 229.1747282701332
# Portfolio Value: 1145.873641350665
# Reward: -0.009622907951892988
#
# Port. Value: 1145.873641350665
# condition: 0.014463467982168066
# Action: -0.7
# Current Step: 21
# Current Position:
#  Stock: -0.7
#  R_f: 1.7
# env.money:
#  Stock: -811.4726503461933
#  R_f: 1970.719293697898
# Portfolio Value: 1159.2466433517047
# Reward: 0.011670573018222836
#
# Port. Value: 1159.2466433517047
# condition: 0.02593061810857318
# Action: -0.10000000000000009
# Current Step: 22
# Current Position:
#  Stock: -0.10000000000000009
#  R_f: 1.1
# env.money:
#  Stock: -113.80843354805637
#  R_f: 1251.892769028619
# Portfolio Value: 1138.0843354805627
# Reward: -0.018255224625844873
#
# Port. Value: 1138.0843354805627
# condition: -0.013104706475492747
# Action: -0.85
# Current Step: 23
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money:
#  Stock: -968.7147499577263
#  R_f: 2108.3791616726985
# Portfolio Value: 1139.6644117149722
# Reward: 0.001388364803160473
#
# Port. Value: 1139.6644117149722
# condition: -0.007330018605825732
# Action: 0.7999999999999998
# Current Step: 24
# Current Position:
#  Stock: 0.7999999999999998
#  R_f: 0.20000000000000018
# env.money:
#  Stock: 917.5238680466691
#  R_f: 229.38096701166754
# Portfolio Value: 1146.9048350583366
# Reward: 0.006353118750518
#
# Port. Value: 1146.9048350583366
# condition: 0.0319247646769315
# Action: 0.050000000000000044
# Current Step: 25
# Current Position:
#  Stock: 0.050000000000000044
#  R_f: 0.95
# env.money:
#  Stock: 58.83435879907748
#  R_f: 1117.852817182471
# Portfolio Value: 1176.6871759815485
# Reward: 0.02596757813973035
#
# Port. Value: 1176.6871759815485
# condition: -0.004453063316810899
# Action: -0.85
# Current Step: 26
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money:
#  Stock: -1000.0365699675
#  R_f: 2176.5501816939704
# Portfolio Value: 1176.5136117264706
# Reward: -0.0001475024616743887
#
# Port. Value: 1176.5136117264706
# condition: 0.07443704199088358
# Action: 0.19999999999999996
# Current Step: 27
# Current Position:
#  Stock: 0.19999999999999996
#  R_f: 0.8
# env.money:
#  Stock: 219.88086232410095
#  R_f: 879.5234492964041
# Portfolio Value: 1099.404311620505
# Reward: -0.06554050827581312
#
# Port. Value: 1099.404311620505
# condition: 0.004064924807418223
# Action: 1.5499999999999998
# Current Step: 28
# Current Position:
#  Stock: 1.5499999999999998
#  R_f: -0.5499999999999998
# env.money:
#  Stock: 1705.5720231117361
#  R_f: -605.202975942874
# Portfolio Value: 1100.3690471688622
# Reward: 0.0008775075176257099
#
# Port. Value: 1100.3690471688622
# condition: 0.023542255492599758
# Action: 0.6499999999999999
# Current Step: 29
# Current Position:
#  Stock: 0.6499999999999999
#  R_f: 0.3500000000000001
# env.money:
#  Stock: 741.6180699724187
#  R_f: 399.3328069082256
# Portfolio Value: 1140.9508768806443
# Reward: 0.036880199253327826
#
# Port. Value: 1140.9508768806443
# condition: 0.027499453545609513
# Action: 1.6999999999999997
# Current Step: 30
# Current Position:
#  Stock: 1.6999999999999997
#  R_f: -0.6999999999999997
# env.money:
#  Stock: 1974.8208974650163
#  R_f: -813.1615460150066
# Portfolio Value: 1161.6593514500098
# Reward: 0.018150189450734665
#
# Port. Value: 1161.6593514500098
# condition: -0.016249613313076536
# Action: 1.6999999999999997
# Current Step: 31
# Current Position:
#  Stock: 1.6999999999999997
#  R_f: -0.6999999999999997
# env.money:
#  Stock: 1920.5999770824067
#  R_f: -790.8352846809909
# Portfolio Value: 1129.764692401416
# Reward: -0.027456120427027296
#
# Port. Value: 1129.764692401416
# condition: 0.006074974602042439
# Action: -0.55
# Current Step: 32
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money:
#  Stock: -627.7731090334114
#  R_f: 1769.178761821432
# Portfolio Value: 1141.4056527880207
# Reward: 0.010303880502638892
#
# Port. Value: 1141.4056527880207
# condition: -0.00044835281238462415
# Action: 0.7999999999999998
# Current Step: 33
# Current Position:
#  Stock: 0.7999999999999998
#  R_f: 0.20000000000000018
# env.money:
#  Stock: 913.4608674793842
#  R_f: 228.3652168698463
# Portfolio Value: 1141.8260843492305
# Reward: 0.0003683454345813847
#
# Port. Value: 1141.8260843492305
# condition: 0.012909449292976717
# Action: -0.25
# Current Step: 34
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money:
#  Stock: -288.4281879159256
#  R_f: 1442.1409395796281
# Portfolio Value: 1153.7127516637024
# Reward: 0.010410225758020352
#
# Port. Value: 1153.7127516637024
# condition: 0.019118975247045325
# Action: 1.4
# Current Step: 35
# Current Position:
#  Stock: 1.4
#  R_f: -0.3999999999999999
# env.money:
#  Stock: 1607.5620091221497
#  R_f: -459.303431177757
# Portfolio Value: 1148.2585779443928
# Reward: -0.004727497127378125
#
# Port. Value: 1148.2585779443928
# condition: 0.025640619885493536
# Action: 1.5499999999999998
# Current Step: 36
# Current Position:
#  Stock: 1.5499999999999998
#  R_f: -0.5499999999999998
# env.money:
#  Stock: 1844.4602495206102
#  R_f: -654.4858949911842
# Portfolio Value: 1189.9743545294261
# Reward: 0.036329601525566455
#
# Port. Value: 1189.9743545294261
# condition: 0.033985068149600006
# Action: -0.4
# Current Step: 37
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money:
#  Stock: -501.4737442620577
#  R_f: 1755.1581049172019
# Portfolio Value: 1253.6843606551442
# Reward: 0.053538974082271
#
# Port. Value: 1253.6843606551442
# condition: 0.019808292904712314
# Action: 0.7999999999999998
# Current Step: 38
# Current Position:
#  Stock: 0.7999999999999998
#  R_f: 0.20000000000000018
# env.money:
#  Stock:
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money:
#  Stock: 472.20938777529193
#  R_f: 876.9602915826855
# Portfolio Value: 1349.1696793579774
# Reward: 0.019537460328645503
#
# Port. Value: 1349.1696793579774
# condition: -0.04182439479320656
# Action: 1.85
# Current Step: 53
# Current Position:
#  Stock: 1.85
#  R_f: -0.8500000000000001
# env.money:
#  Stock: 2460.3076708328013
#  R_f: -1130.4116325448008
# Portfolio Value: 1329.8960382880007
# Reward: -0.014285557528352102
#
# Port. Value: 1329.8960382880007
# condition: -0.026743383153424914
# Action: -1.0
# Current Step: 54
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money:
#  Stock: -1264.882279838975
#  R_f: 2529.76455967795
# Portfolio Value: 1264.882279838975
# Reward: -0.048886346434055976
#
# Port. Value: 1264.882279838975
# condition: -0.002640027265205747
# Action: 0.5
# Current Step: 55
# Current Position:
#  Stock: 0.5
#  R_f: 0.5
# env.money:
#  Stock: 634.2080004349233
#  R_f: 634.2080004349233
# Portfolio Value: 1268.4160008698466
# Reward: 0.0027937153418905775
#
# Port. Value: 1268.4160008698466
# condition: -0.002029720864761147
# Action: 1.4
# Current Step: 56
# Current Position:
#  Stock: 1.4
#  R_f: -0.3999999999999999
# env.money:
#  Stock: 1774.0518325163068
#  R_f: -506.87195214751614
# Portfolio Value: 1267.1798803687907
# Reward: -0.0009745387161689809
#
# Port. Value: 1267.1798803687907
# condition: 0.028549682432341607
# Action: 0.050000000000000044
# Current Step: 57
# Current Position:
#  Stock: 0.050000000000000044
#  R_f: 0.95
# env.money:
#  Stock: 65.9259297566686
#  R_f: 1252.5926653767021
# Portfolio Value: 1318.5185951333708
# Reward: 0.04051414922216006
#
# Port. Value: 1318.5185951333708
# condition: 0.011130260906095438
# Action: 1.85
# Current Step: 58
# Current Position:
#  Stock: 1.85
#  R_f: -0.8500000000000001
# env.money:
#  Stock: 2440.80656793756
#  R_f: -1121.4516663496897
# Portfolio Value: 1319.3549015878702
# Reward: 0.0006342773303207315
#
# Port. Value: 1319.3549015878702
# condition: 0.01918930672688777
# Action: 0.6499999999999999
# Current Step: 59
# Current Position:
#  Stock: 0.6499999999999999
#  R_f: 0.3500000000000001
# env.money:
#  Stock: 888.2616827996537
#  R_f: 478.2947522767368
# Portfolio Value: 1366.5564350763905
# Reward: 0.035776221721473295
#
# Port. Value: 1366.5564350763905
# condition: 0.01904313963329633
# Action: 1.25
# Current Step: 60
# Current Position:
#  Stock: 1.25
#  R_f: -0.25
# env.money:
#  Stock: 1729.589250592776
#  R_f: -345.9178501185552
# Portfolio Value: 1383.6714004742207
# Reward: 0.012524155577133936
#
# ...
#  Stock: 1125.4747274736578
#  R_f: -225.09494549473155
# Portfolio Value: 900.3797819789262
# Reward: -0.011171242985351323
#
# Port. Value: 900.3797819789262
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# EXPLOITATION
# condition: -0.006141110705455494
# Action: -1.0
# Current Step: 54
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money:
#  Stock: -893.4716072808021
#  R_f: 1786.9432145616042
# Portfolio Value: 893.4716072808021
# Reward: -0.0076725120181405405
#
# Port. Value: 893.4716072808021
# condition: -0.0028453326697119655
# Action: -0.10000000000000009
# Current Step: 55
# Current Position:
#  Stock: -0.10000000000000009
#  R_f: 1.1
# env.money:
#  Stock: -89.61506447547046
#  R_f: 985.7657092301744
# Portfolio Value: 896.1506447547039
# Reward: 0.00299845843121435
#
# Port. Value: 896.1506447547039
# condition: -0.02941512330610966
# Action: -0.55
# Current Step: 56
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money:
#  Stock: -494.3541663130561
#  R_f: 1393.1799232458854
# Portfolio Value: 898.8257569328292
# Reward: 0.0029851143820329258
#
# Port. Value: 898.8257569328292
# condition: 0.045990071244285904
# Action: -0.55
# Current Step: 57
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money:
#  Stock: -481.6179214360646
#  R_f: 1357.2868695016366
# Portfolio Value: 875.668948065572
# Reward: -0.02576340151430242
#
# Port. Value: 875.668948065572
# condition: -0.014070085227032935
# Action: -0.55
# Current Step: 58
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money:
#  Stock: -485.37751134277056
#  R_f: 1367.882077420535
# Portfolio Value: 882.5045660777646
# Reward: 0.007806166962175727
#
# Port. Value: 882.5045660777646
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# condition: 0.018382805972415033
# Action: -1.0
# Current Step: 59
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money:
#  Stock: -873.606944329034
#  R_f: 1747.213888658068
# Portfolio Value: 873.606944329034
# Reward: -0.01008223876764227
#
# Port. Value: 873.606944329034
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# EXPLOITATION
# condition: 0.01483480374768788
# Action: -1.0
# Current Step: 60
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money:
#  Stock: -860.6878563921529
#  R_f: 1721.3757127843057
# Portfolio Value: 860.6878563921529
# Reward: -0.01478821570815644
#
# Port. Value: 860.6878563921529
# condition: -0.04672735869569711
# Action: 0.6499999999999999
# Current Step: 61
# Current Position:
#  Stock: 0.6499999999999999
#  R_f: 0.3500000000000001
# env.money:
#  Stock: 585.0751622153069
#  R_f: 315.0404719620885
# Portfolio Value: 900.1156341773955
# Reward: 0.045809613197654114
#
# Port. Value: 900.1156341773955
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# EXPLOITATION
# condition: -0.004020685255760293
# Action: -1.0
# Current Step: 62
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money:
#  Stock: -897.7927113408059
#  R_f: 1795.5854226816118
# Portfolio Value: 897.7927113408059
# Reward: -0.0025806938002053987
#
# Port. Value: 897.7927113408059
# condition: 0.028079607700864605
# Action: 1.6999999999999997
# Current Step: 63
# Current Position:
#  Stock: 1.6999999999999997
#  R_f: -0.6999999999999997
# env.money:
#  Stock: 1483.0236878343376
#  R_f: -610.6568126376683
# Portfolio Value: 872.3668751966693
# Reward: -0.028320386012228225
#
# Port. Value: 872.3668751966693
# condition: -0.012040759200539798
# Action: 0.050000000000000044
# Current Step: 64
# Current Position:
#  Stock: 0.050000000000000044
#  R_f: 0.95
# env.money:
#  Stock: 42.72846148851028
#  R_f: 811.8407682816945
# Portfolio Value: 854.5692297702047
# Reward: -0.02040156032111168
#
# Port. Value: 854.5692297702047
# condition: 0.020817097985331455
# Action: 0.7999999999999998
# Current Step: 65
# Current Position:
#  Stock: 0.7999999999999998
#  R_f: 0.20000000000000018
# env.money:
#  Stock: 684.4254668809598
#  R_f: 171.10636672024015
# Portfolio Value: 855.5318336012
# Reward: 0.0011264199522537162
#
# Port. Value: 855.5318336012
# condition: 0.02479973793160966
# Action: 0.7999999999999998
# Current Step: 66
# Current Position:
#  Stock: 0.7999999999999998
#  R_f: 0.20000000000000018
# env.money:
#  Stock: 698.1848583816887
#  R_f: 174.54621459542238
# Portfolio Value: 872.7310729771111
# Reward: 0.020103564473473976
#
# Port. Value: 872.7310729771111
# condition: -0.03084799240142134
# Action: -1.0
# Current Step: 67
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money:
#  Stock: -851.5359946770379
#  R_f: 1703.0719893540759
# Portfolio Value: 851.5359946770379
# Reward: -0.02428592146693174
#
# Port. Value: 851.5359946770379
# condition: -0.024297427768719928
# Action: -0.25
# Current Step: 68
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money:
#  Stock: -218.0276574434457
#  R_f: 1090.1382872172285
# Portfolio Value: 872.1106297737828
# Reward: 0.02416179142791042
#
# Port. Value: 872.1106297737828
# condition: -0.02186618260019004
# Action: -0.55
# Current Step: 69
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money:
#  Stock: -482.3015922245453
#  R_f: 1359.2135780873548
# Portfolio Value: 876.9119858628095
# Reward: 0.005505443833739495
#
# Port. Value: 876.9119858628095
# condition: -0.011537506330681943
# Action: 0.19999999999999996
# Current Step: 70
# Current Position:
#  Stock: 0.19999999999999996
#  R_f: 0.8
# env.money:
#  Stock: 176.51027595901752
#  R_f: 706.0411038360703
# Portfolio Value: 882.5513797950878
# Reward: 0.006430969154480841
#
# Port. Value: 882.5513797950878
# condition: -0.01268884026124165
# Action: 0.19999999999999996
# Current Step: 71
# Current Position:
#  Stock: 0.19999999999999996
#  R_f: 0.8
# env.money:
#  Stock: 176.07626061051317
#  R_f: 704.3050424420529
# Portfolio Value: 880.3813030525661
# Reward: -0.002458867316059891
#
# Port. Value: 880.3813030525661
# condition: 0.010110543383302856
# Action: 1.25
# Current Step: 72
# Current Position:
#  Stock: 1.25
#  R_f: -0.25
# env.money:
#  Stock: 1102.782384289374
#  R_f: -220.55647685787483
# Portfolio Value: 882.2259074314993
# Reward: 0.0020952334772869462
#
# Port. Value: 882.2259074314993
# condition: -0.032589663464552936
# Action: -0.4
# Current Step: 73
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money:
#  Stock: -338.7394331656206
#  R_f: 1185.588016079672
# Portfolio Value: 846.8485829140515
# Reward: -0.04010007439074751
#
# Port. Value: 846.8485829140515
# condition: -0.02115228802958965
# Action: 1.5499999999999998
# Current Step: 74
# Current Position:
#  Stock: 1.5499999999999998
#  R_f: -0.5499999999999998
# env.money:
#  Stock: 1323.7490087476178
#  R_f: -469.7173902007675
# Portfolio Value: 854.0316185468503
# Reward: 0.008482077879945898
#
# Port. Value: 854.0316185468503
# condition: -0.03441545224878262
# Action: 0.34999999999999987
# Current Step: 75
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money:
#  Stock: 283.2243079007141
#  R_f: 525.9880003870408
# Portfolio Value: 809.2123082877549
# Reward: -0.05247968492707118
#
# Port. Value: 809.2123082877549
# condition: -0.021225995155613284
# Action: 1.5499999999999998
# Current Step: 76
# Current Position:
#  Stock: 1.5499999999999998
#  R_f: -0.5499999999999998
# env.money:
#  Stock: 1245.1231817458201
#  R_f: -441.81790320012965
# Portfolio Value: 803.3052785456905
# Reward: -0.00729972799667784
#
# Port. Value: 803.3052785456905
# condition: 0.044270768831972625
# Action: 0.34999999999999987
# Current Step: 77
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money:
#  Stock: 300.87101967264556
#  R_f: 558.760465106342
# Portfolio Value: 859.6314847789877
# Reward: 0.07011805815003548
#
# Port. Value: 859.6314847789877
# condition: -0.0017943536470299624
# Action: 0.19999999999999996
# Current Step: 78
# Current Position:
#  Stock: 0.19999999999999996
#  R_f: 0.8
# env.money:
#  Stock: 171.8272019989355
#  R_f: 687.3088079957422
# Portfolio Value: 859.1360099946777
# Reward: -0.0005763804526510147
#
# Port. Value: 859.1360099946777
# condition: -0.053192153377240925
# Action: 0.5
# Current Step: 79
# Current Position:
#  Stock: 0.5
#  R_f: 0.5
# env.money:
#  Stock: 425.14449713622025
#  R_f: 425.14449713622025
# Portfolio Value: 850.2889942724405
# Reward: -0.010297572932942242
#
# Port. Value: 850.2889942724405
# condition: 0.03483143863873964
# Action: 1.25
# Current Step: 80
# Current Position:
#  Stock: 1.25
#  R_f: -0.25
# env.money:
#  Stock: 1081.7396476504634
#  R_f: -216.3479295300927
# Portfolio Value: 865.3917181203708
# Reward: 0.017761871492707148
#
# Port. Value: 865.3917181203708
# condition: 0.010208708378796812
# Action: -0.4
# Current Step: 81
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money:
#  Stock: -350.5897766260696
#  R_f: 1227.0642181912433
# Portfolio Value: 876.4744415651738
# Reward: 0.01280659753582423
#
# Port. Value: 876.4744415651738
# condition: 0.04795339227741849
# Action: 0.34999999999999987
# Current Step: 82
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money:
#  Stock: 300.7722495813881
#  R_f: 558.5770349368639
# Portfolio Value: 859.349284518252
# Reward: -0.019538683884883584
#
# Port. Value: 859.349284518252
# condition: 0.025630507024610307
# Action: 1.1
# Current Step: 83
# Current Position:
#  Stock: 1.1
#  R_f: -0.10000000000000009
# env.money:
#  Stock: 953.9219437793228
#  R_f: -86.72017670721124
# Portfolio Value: 867.2017670721116
# Reward: 0.00913770767640962
#
# Port. Value: 867.2017670721116
# condition: 0.01576657972635955
# Action: 0.34999999999999987
# Current Step: 84
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money:
#  Stock: 308.82398032471
#  R_f: 573.5302491744618
# Portfolio Value: 882.3542294991718
# Reward: 0.01747282236084304
#
# Port. Value: 882.3542294991718
# condition: 0.012632395754467906
# Action: 0.050000000000000044
# Current Step: 85
# Current Position:
#  Stock: 0.050000000000000044
#  R_f: 0.95
# env.money:
#  Stock: 44.31626159156233
#  R_f: 842.0089702396834
# Portfolio Value: 886.3252318312458
# Reward: 0.004500462738562472
#
# Port. Value: 886.3252318312458
# condition: 0.0035604138359702103
# Action: 0.34999999999999987
# Current Step: 86
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money:
#  Stock: 310.29231327867063
#  R_f: 576.2571532318173
# Portfolio Value: 886.5494665104878
# Reward: 0.00025299367680050276
#
# Port. Value: 886.5494665104878
# condition: 0.025718477426978772
# Action: 0.34999999999999987
# Current Step: 87
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money:
#  Stock: 313.1374759851605
#  R_f: 581.5410268295841
# Portfolio Value: 894.6785028147447
# Reward: 0.009169298061001837
#
# Port. Value: 894.6785028147447
# condition: 0.012175441829798971
# Action: -1.0
# Current Step: 88
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money:
#  Stock: -898.5600947571804
#  R_f: 1797.1201895143608
# Portfolio Value: 898.5600947571804
# Reward: 0.0043385327022208535
#
# Port. Value: 898.5600947571804
# condition: -0.0028362339696897847
# Action: -0.85
# Current Step: 89
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money:
#  Stock: -766.0593017160667
#  R_f: 1667.3055390290863
# Portfolio Value: 901.2462373130196
# Reward: 0.0029893855419487153
#
# Port. Value: 901.2462373130196
# condition: 0.013618283091729709
# Action: 0.34999999999999987
# Current Step: 90
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money:
#  Stock: 311.80572172775067
#  R_f: 579.0677689229658
# Portfolio Value: 890.8734906507165
# Reward: -0.011509336996766284
#
# Port. Value: 890.8734906507165
# condition: 0.0060785571490364135
# Action: 0.7999999999999998
# Current Step: 91
# Current Position:
#  Stock: 0.7999999999999998
#  R_f: 0.20000000000000018
# env.money:
#  Stock: 714.2560781429116
#  R_f: 178.5640195357281
# Portfolio Value: 892.8200976786397
# Reward: 0.002185054385782012
#
# Port. Value: 892.8200976786397
# condition: 0.03131269867746687
# Action: 0.95
# Current Step: 92
# Current Position:
#  Stock: 0.95
#  R_f: 0.050000000000000044
# env.money:
#  Stock: 869.7755949015896
#  R_f: 45.77766288955739
# Portfolio Value: 915.553257791147
# Reward: 0.025462195767785863
#
# Port. Value: 915.553257791147
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# EXPLOITATION
# condition: 0.013648296550580273
# Action: -1.0
# Current Step: 93
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money:
#  Stock: -927.5091894432301
#  R_f: 1855.0183788864601
# Portfolio Value: 927.5091894432301
# Reward: 0.01305869598555943
#
# Port. Value: 927.5091894432301
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# EXPLOITATION
# condition: 0.002284820400848594
# Action: -1.0
# Current Step: 94
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money:
#  Stock: -925.5333512055437
#  R_f: 1851.0667024110874
# Portfolio Value: 925.5333512055437
# Reward: -0.00213026270809506
#
# Port. Value: 925.5333512055437
# condition: 0.025981360731046007
# Action: 0.050000000000000044
# Current Step: 95
# Current Position:
#  Stock: 0.050000000000000044
#  R_f: 0.95
# env.money:
#  Stock: 45.06585481875696
#  R_f: 856.2512415563815
# Portfolio Value: 901.3170963751385
# Reward: -0.02616464852278157
#
# Port. Value: 901.3170963751385
# condition: -0.004922268893816044
# Action: 0.050000000000000044
# Current Step: 96
# Current Position:
#  Stock: 0.050000000000000044
#  R_f: 0.95
# env.money:
#  Stock: 45.058155181175586
#  R_f: 856.1049484423353
# Portfolio Value: 901.1631036235109
# Reward: -0.00017085302414311502
#
# Port. Value: 901.1631036235109
# condition: 0.01089046379711204
# Action: 1.4
# Current Step: 97
# Current Position:
#  Stock: 1.4
#  R_f: -0.3999999999999999
# env.money:
#  Stock: 1262.413273118788
#  R_f: -360.68950660536797
# Portfolio Value: 901.7237665134201
# Reward: 0.0006221547327612316
#
# Port. Value: 901.7237665134201
# condition: 0.00693964770346835
# Action: 0.6499999999999999
# Current Step: 98
# Current Position:
#  Stock: 0.6499999999999999
#  R_f: 0.3500000000000001
# env.money:
#  Stock: 591.8162858777903
#  R_f: 318.67030778034876
# Portfolio Value: 910.4865936581391
# Reward: 0.009717862021759883
#
# Port. Value: 910.4865936581391
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# EXPLOITATION
# condition: 0.03702243941108906
# Action: -1.0
# Current Step: 99
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money:
#  Stock: -932.832760668937
#  R_f: 1865.665521337874
# Portfolio Value: 932.832760668937
# Reward: 0.024543103837493984
#
# Episode: 20/20, Score: 98, Epsilon: 0.91
#
#
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Annualized rewards predicted: -33.26%

# %%
random.seed(123456789)
annualized_return = env.backtest(agent, days_test=252)
print(f"Annualized Return on backtesting: {annualized_return:.2f}%")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# EXPLOITATION
# Annualized Return on backtesting: 14.27%

# %%
# Serialize the classifier to a file named 'my_classifier.pkl'
with open('agent.pkl', 'wb') as file:
    pickle.dump(agent, file)

# To later deserialize the classifier from the file
# with open('agent.pkl', 'rb') as file:
#     loaded_agent = pickle.load(file)

# %% [markdown]
# ## Test with new data

# %%
# Data manipulation
data_NEW = pd.read_csv('AAPL_NEW.csv', sep=',')
data_NEW['Date'] = pd.to_datetime(data_NEW['Date'],format='%Y-%m-%d')
adj_close_NEW = data_NEW['AAPL']
df1 = pd.DataFrame({'Date': data_NEW['Date'], 'log_ret': np.log(adj_close_NEW/adj_close_NEW.shift(1)).dropna(), 'AAPL_VOL': data_NEW['AAPL_VOL']}).dropna().set_index('Date')
sp500_NEW = pd.read_csv('sp500_joined_closes_NEW.csv', sep=',').dropna(axis=1)
sp500_NEW.drop('AAPL ', axis=1, inplace=True)
sp500_NEW.drop('AAPL _VOL', axis=1, inplace=True)
data_NEW.set_index('Date', inplace=True)
new_cols = list([])
for i, col in enumerate(sp500_NEW.columns):
    if col.endswith(' '):
        new_cols.append(col[:-1])
    elif col.endswith(' _VOL'):
        new_cols.append(col[:-5]+'_VOL')
    else:
        new_cols.append(col)
sp500_NEW.columns = new_cols
sp500_NEW['Date'] = pd.to_datetime(sp500_NEW['Date'])
sp500_NEW = sp500_NEW.set_index('Date')
sp500_NEW = sp500_NEW[[col for col in sp500.columns]]
new_cols = sp500_NEW.columns
col_stocks = [col for col in new_cols if not col.endswith('VOL')]
col_vols = [col for col in new_cols if col.endswith('VOL')]
any(col == 'Date' for col in col_stocks)
# Out:
# False

# %%
[i for i,col in enumerate(sp500_NEW.columns) if col=='MMM']
# Out:
# [0]

# %%
sp500_lr_NEW = np.log(sp500_NEW[col_stocks]/sp500_NEW[col_stocks].shift(1))
sp500_lr_NEW = sp500_lr_NEW.drop(sp500_lr_NEW.index[0])
# sp500_lr_NEW = sp500_lr_NEW.drop([col for col in sp500_lr_NEW.columns if sp500_lr_NEW[col].count() < 3633], axis=1)
df1 = df1.join(sp500_NEW[col_vols],how='inner').dropna()
df1 = df1.join(sp500_lr_NEW,how='inner').dropna()
df1.describe()
# Out:
#          log_ret      AAPL_VOL       MMM_VOL       AOS_VOL       ABT_VOL  \
# count  37.000000  3.700000e+01  3.700000e+01  3.700000e+01  3.700000e+01
# mean    0.001485  6.291276e+07  4.808686e+06  1.102470e+06  7.180724e+06
# std     0.016457  3.559902e+07  5.087143e+06  4.212829e+05  3.317233e+06
# min    -0.049366  3.631180e+07  1.230800e+06  5.398000e+05  2.017800e+06
# 25%    -0.004816  4.716110e+07  2.884900e+06  8.747000e+05  4.970800e+06
# 50%     0.003978  5.734590e+07  3.381000e+06  1.025900e+06  6.356600e+06
# 75%     0.013642  6.351640e+07  4.598100e+06  1.190100e+06  8.611600e+06
# max     0.028689  2.464214e+08  3.274890e+07  2.721300e+06  1.945270e+07
#
#             ACN_VOL      ADBE_VOL       AMD_VOL       AES_VOL       AFL_VOL  \
# count  3.700000e+01  3.700000e+01  3.700000e+01  3.700000e+01  3.700000e+01
# mean   3.404114e+06  2.619322e+06  5.564599e+07  8.377762e+06  2.296111e+06
# std    2.325463e+06  1.055446e+06  1.849204e+07  4.929767e+06  1.388765e+06
# min    1.629200e+06  1.272600e+06  2.698090e+07  3.243100e+06  1.040000e+06
# 25%    2.283500e+06  2.075400e+06  4.220270e+07  5.224700e+06  1.515000e+06
# 50%    2.682700e+06  2.368400e+06  5.043670e+07  7.055500e+06  1.898600e+06
# 75%    3.640500e+06  3.054500e+06  6.185710e+07  9.712200e+06  2.212000e+06
# max    1.490550e+07  6.614100e+06  1.143068e+08  2.844530e+07  7.552800e+06
#
#        ...        WST        WDC         WY        WMB        WTW       WYNN  \
# count  ...  37.000000  37.000000  37.000000  37.000000  37.000000  37.000000
# mean   ...  -0.002862  -0.005789   0.001550   0.000455   0.001581  -0.005127
# std    ...   0.031343   0.033936   0.017124   0.014376   0.012160   0.017542
# min    ...  -0.155438  -0.102300  -0.029672  -0.036737  -0.031149  -0.050899
# 25%    ...  -0.008031  -0.019890  -0.011173  -0.007505  -0.004725  -0.015403
# 50%    ...   0.000247  -0.003337   0.000000   0.000466   0.002202  -0.005169
# 75%    ...   0.011730   0.015123   0.013181   0.007239   0.008741   0.004030
# max    ...   0.038771   0.059451   0.048825   0.037830   0.038933   0.036576
#
#              XEL        YUM       ZBRA        ZBH
# count  37.000000  37.000000  37.000000  37.000000
# mean    0.002930   0.000684   0.003053   0.000827
# std     0.012876   0.011661   0.019387   0.014313
# min    -0.029899  -0.026390  -0.061022  -0.034919
# 25%    -0.003605  -0.007918  -0.006052  -0.005720
# 50%     0.002284   0.001043   0.004828   0.001383
# 75%     0.010769   0.008022   0.013832   0.005858
# max     0.027938   0.026133   0.038148   0.032862
#
# [8 rows x 860 columns]

# %%
eig_vecs.shape
# Out:
# (429, 429)

# %%
sp500_lr_NEW.shape
# Out:
# (37, 429)

# %%
# Applying PCA trasformation on new data
PCs = mylib.apply_PCA(df1['log_ret'], sp500_lr_NEW, eig_vecs)

# Add the relevant PCs to the df
dataframe1 = pd.DataFrame(PCs[['PC0','PC2','PC4','PC6','PC7','PC8','PC9']])
dataframe1['log_ret'] = df1['log_ret']
dataframe1
# Out:
#                  PC0       PC2       PC4       PC6       PC7       PC8  \
# Date
# 2024-06-21  0.032098 -0.044725 -0.026946  0.025829  0.017120  0.024109
# 2024-06-24  0.108855  0.164992  0.035454  0.025630  0.054299  0.013245
# 2024-06-25 -0.168156 -0.050005  0.059747 -0.025795 -0.101840  0.024897
# 2024-06-26 -0.067611 -0.022626 -0.008002 -0.005133  0.009854  0.006941
# 2024-06-27  0.007897 -0.003758  0.004374 -0.028408  0.002168 -0.048445
# 2024-06-28  0.025145  0.058401 -0.019290 -0.039767  0.014498  0.056693
# 2024-07-01 -0.166925  0.015846  0.015614 -0.066021 -0.056684  0.025330
# 2024-07-02  0.084907 -0.013881 -0.004463 -0.036978 -0.045228 -0.006042
# 2024-07-03  0.005339 -0.021784  0.067656 -0.024119 -0.008778 -0.012386
# 2024-07-05 -0.029148 -0.117566 -0.013889  0.017159 -0.005398 -0.005674
# 2024-07-08  0.043645  0.002638 -0.002341 -0.003961 -0.014899  0.028226
# 2024-07-09 -0.032184  0.049827 -0.044527 -0.049399 -0.033534  0.053733
# 2024-07-10  0.195841 -0.012132  0.022839 -0.024883  0.010347  0.024281
# 2024-07-11  0.246333  0.067059 -0.027132  0.003854  0.221205 -0.055913
# 2024-07-12  0.155994 -0.044528  0.011456  0.016301  0.003149 -0.013565
# 2024-07-15  0.022256  0.063767 -0.011035 -0.060907  0.004251  0.014296
# 2024-07-16  0.357199  0.001807 -0.059808  0.080377  0.090335 -0.005053
# 2024-07-17 -0.061218  0.184284 -0.076544  0.043197  0.083875  0.016113
# 2024-07-18 -0.181452  0.062625  0.036303 -0.016822 -0.030485 -0.034186
# 2024-07-19 -0.145646 -0.003132 -0.030596  0.021049  0.046521  0.002287
# 2024-07-22  0.171904 -0.106663  0.004849 -0.069981 -0.032078 -0.010473
# 2024-07-23 -0.075129  0.016776 -0.065512 -0.049255  0.008829 -0.036209
# 2024-07-24 -0.226713  0.069254 -0.006201 -0.025746  0.054053  0.019168
# 2024-07-25  0.019826  0.095688 -0.036408 -0.012992  0.079899 -0.045418
# 2024-07-26  0.290118  0.031354 -0.026742  0.027531  0.013777 -0.008185
# 2024-07-29  0.030046 -0.052163 -0.009794  0.037232  0.010460 -0.022586
# 2024-07-30  0.088907  0.080579 -0.074420  0.023191  0.083738 -0.046196
# 2024-07-31  0.088067 -0.128039  0.148519 -0.030263 -0.117509  0.005666
# 2024-08-01 -0.212310 -0.007083 -0.058343 -0.006303  0.174773 -0.040968
# 2024-08-02 -0.375950 -0.034747 -0.106441  0.058728  0.123666 -0.108224
# 2024-08-05 -0.502911  0.014776 -0.010045  0.012397  0.006942 -0.039000
# 2024-08-06  0.196460 -0.004879 -0.017554 -0.011948  0.010192  0.027438
# 2024-08-07 -0.167012  0.086340  0.015406 -0.024517 -0.046887 -0.048296
# 2024-08-08  0.375709 -0.091666  0.089488  0.009697 -0.063539  0.045670
# 2024-08-09  0.032493  0.014589 -0.016224 -0.019149 -0.016954  0.008690
# 2024-08-12 -0.095302 -0.001105  0.079333 -0.019540 -0.015653 -0.028579
# 2024-08-13  0.235017 -0.106761 -0.027511  0.007354 -0.058504  0.051591
#
#                  PC9   log_ret
# Date
# 2024-06-21 -0.000856 -0.010499
# 2024-06-24  0.027070  0.003128
# 2024-06-25  0.018127  0.004458
# 2024-06-26 -0.028319  0.019796
# 2024-06-27  0.058184  0.003978
# 2024-06-28  0.015417 -0.016388
# 2024-07-01  0.058815  0.028689
# 2024-07-02  0.031049  0.016109
# 2024-07-03 -0.011366  0.005794
# 2024-07-05  0.017846  0.021390
# 2024-07-08 -0.034018  0.006518
# 2024-07-09 -0.022458  0.003768
# 2024-07-10 -0.043860  0.018629
# 2024-07-11 -0.025060 -0.023495
# 2024-07-12 -0.001110  0.012966
# 2024-07-15  0.101883  0.016605
# 2024-07-16 -0.114550  0.001790
# 2024-07-17  0.057725 -0.025621
# 2024-07-18  0.038172 -0.020749
# 2024-07-19 -0.033542  0.000580
# 2024-07-22 -0.033893 -0.001561
# 2024-07-23  0.012932  0.004677
# 2024-07-24 -0.078317 -0.029176
# 2024-07-25  0.028386 -0.004816
# 2024-07-26 -0.026183  0.002159
# 2024-07-29 -0.020752  0.001284
# 2024-07-30 -0.013115  0.002563
# 2024-07-31 -0.009054  0.014880
# 2024-08-01  0.005197 -0.016893
# 2024-08-02  0.076131  0.006846
# 2024-08-05  0.031504 -0.049366
# 2024-08-06  0.054746 -0.009796
# 2024-08-07  0.073425  0.012421
# 2024-08-08 -0.033666  0.016496
# 2024-08-09  0.027966  0.013642
# 2024-08-12  0.019918  0.007105
# 2024-08-13 -0.051866  0.017047

# %%
with open('agent.pkl', 'rb') as file:
    loaded_agent = pickle.load(file)

rf = (1+0.02)**(1/252) - 1
tol = 0.01
episodes = 20
days_train = 36

env1 = TradingEnv(dataframe1, rf)
agent1 = loaded_agent
random.seed(123456789)
annualized_return1 = env1.backtest(agent1, days_test=252)
print(f"Annualized Return on NEW DATA: {annualized_return1:.2f}%")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# EXPLOITATION
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# EXPLOITATION
# Annualized Return on NEW DATA: 3.34%
