# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from collections import deque
import random
import gymnasium as gym
from gymnasium import spaces
import datetime
import my_library as mylib
import statsmodels.api as sm
import matplotlib.pyplot as plt
pd.options.mode.chained_assignment = None

# %% [markdown]
# Environment Definition

# %%
class TradingEnv(gym.Env):
    def __init__(self, df, rf):
        super(TradingEnv, self).__init__()

        self.current_step = 0
        self.data = df.iloc[:,df.columns != 'log_ret']
        self.y = df['log_ret']
        self.initial_position = pd.DataFrame({'0': [0], '1': [1]}) # Initial position is 1000 in risk_free asset
        self.position = self.initial_position
        self.initial_portfolio_value = list([1000])
        self.money = pd.DataFrame(self.initial_portfolio_value[0] * self.position)
        self.rf = rf
        self.pos_sup = 2
        self.pos_inf = -1
        # Define action and observation space
        
        # Only one stock, the rest is in cash
        self.action_space = np.arange(self.pos_inf, self.pos_sup, 0.15).round(2)
        # If two stocks, then self.action_space = spaces.Box(low=np.array([0,0]), high=np.array([1,1]), dtype=np.float32)
        
        # observation_space is a dataframe with historical data
        self.observation_space = spaces.Box(low=0, high=np.inf, shape=(1,df.shape[1]+5), dtype=np.float32)
           
    def step(self, state, action):
        # Execute one time step within the environment
        self.current_step += 1
        self.flag = 0

        # End the episode if we've run out of data
        if self.current_step >= days_train:
            return self.position, 0, True

        # Take the action (<0: short stock, ==0: hold positions, >0: buy stock)
        # action = action[0][0]
        if (action > self.pos_sup) or (action < self.pos_inf):
            reward = - 1000
            self.flag = 1
        new_port_value = np.exp(state[0]) * self.money.iloc[self.current_step-1,0] + self.money.iloc[self.current_step-1,1] * (1+self.rf)
        self.portfolio_value.append(new_port_value)
        
        if abs(action - self.position.iloc[self.current_step-1,0]) >= tol:
            new_row_pos = pd.DataFrame([[action, (1 - action)]])
        else:
            new_row_pos = pd.DataFrame([[self.position.iloc[self.current_step-1,0], self.position.iloc[self.current_step-1,1]]])
        self.position = pd.concat([self.position, new_row_pos], axis=0, ignore_index=True)    
        new_row_money = pd.DataFrame([[self.position.iloc[self.current_step,0]*self.portfolio_value[self.current_step], self.position.iloc[self.current_step,1]*self.portfolio_value[self.current_step]]])
        self.money = pd.concat([self.money, new_row_money], axis=0, ignore_index=True)

        if self.flag == 0:
            reward = (self.portfolio_value[self.current_step] - self.portfolio_value[self.current_step-1])/self.portfolio_value[self.current_step-1]
        
        done = self.current_step >= days_train - 1
        
        observation = np.concatenate(([self.y_train.iloc[self.current_step]], self.df_train.iloc[self.current_step], [self.position.iloc[self.current_step,0], self.position.iloc[self.current_step,1], self.money.iloc[self.current_step,0], self.money.iloc[self.current_step,1], self.portfolio_value[self.current_step]]))

        return observation, reward, done

    def reset(self):
        # Reset the state of the environment to an initial state
        self.current_step = 0
        a = (3 * np.random.rand(1) - 1)[0].round(5)
        self.position = pd.DataFrame([a,1-a]).T
        self.portfolio_value = self.initial_portfolio_value
        self.money = pd.DataFrame(self.portfolio_value[0] * self.position)
        starting_point = np.random.randint(0, self.data.shape[0]-days_train)
        self.df_train = self.data.iloc[starting_point:starting_point+days_train,]
        self.y_train = self.y.iloc[starting_point:starting_point+days_train,]
        for i in range(days_train):
            b = (0.05 * np.random.rand(1) - 0.025)[0].round(5)
            self.y_train.iloc[i] *= (1+b)
            for j in range(len(self.df_train.columns)):
                c = (0.05 * np.random.rand(1) - 0.025)[0].round(5)
                self.df_train.iloc[i,j] *= (1+c)

        # The first observation is the returns of the first day, the initial position, and the initial portfolio value
        observation = np.insert(self.df_train.iloc[self.current_step].values.flatten(),0,self.y_train.iloc[self.current_step])
        observation = np.concatenate((observation, [self.position.iloc[self.current_step,0], self.position.iloc[self.current_step,1], self.money.iloc[self.current_step,0], self.money.iloc[self.current_step,1], self.portfolio_value[self.current_step]]))

        return observation

    def render(self, mode='human'):
        # Render the environment to the screen
        if mode == 'human':
            print(f"Current Step: {self.current_step}")
            # print(f"Current Price: {self.df_train.iloc[self.current_step]}")
            print(f"Current Position:\n Stock: {self.position.iloc[self.current_step,0]}\n R_f: {self.position.iloc[self.current_step,1]}")
            print(f"env.money = {self.money.iloc[self.current_step]}")
            print(f"Portfolio Value: {self.portfolio_value[self.current_step]}")
    
    def train(self, episodes, days):
        self.days_train = days
        for e in range(episodes):
            print(f"Episode: {e+1}/{episodes}")
            state = env.reset()
            # state = np.reshape(state, [1, state_size])
            for time in range(days): 
                action = agent.act(state)*0.15-1
                print(f"log_return: {state[0]}")
                next_state, reward, done = env.step(state,action)
                if agent.flag == 1:
                    agent.reward_pred *= (1+reward)
                    agent.flag = 0
                # next_state = np.reshape(next_state, [1, state_size])
                agent.remember(state, action, reward, next_state, done)
                self.render()
                print(f"Reward: {reward}\n")
                state = next_state
                if done:
                    print(f"Episode: {e+1}/{episodes}, Score: {time}, Epsilon: {agent.epsilon:.2}\n\n\n")
                    break
            if len(agent.memory) > 32:
                agent.replay(32)

# %% [markdown]
# Agent Definition

# %%
class DQN:
    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.memory = deque(maxlen=3000)
        self.gamma = 0.95  # discount rate
        self.epsilon = 1.0  # exploration rate
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995
        self.learning_rate = 0.001
        self.model = self._build_model()
        self.reward_pred = 1
        self.n_exploit = 0
        self.flag = 0

    def _build_model(self):
        model = Sequential()
        model.add(Dense(64, input_dim=self.state_size, activation='sigmoid'))
        model.add(Dense(64, activation='sigmoid'))
        model.add(Dense(self.action_size, activation='linear'))
        model.compile(loss='mse', optimizer=Adam(learning_rate=self.learning_rate))
        return model

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        act_values = self.model.predict(state)
        print("EXPLOITATION")
        self.flag = 1
        self.n_exploit += 1
        return np.argmax(act_values[0])

    def replay(self, batch_size):
        minibatch = random.sample(self.memory, batch_size)
        for state, action, reward, next_state, done in minibatch:
            target = reward
            if not done:
                target = (reward + self.gamma * np.amax(self.model.predict(next_state)[0]))
            target_f = self.model.predict(state)
            target_f[0][int(action)] = target
            self.model.fit(state, target_f, epochs=1, verbose=0)
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

# %% [markdown]
# Global variables setting

# %%
rf = (1+0.02)**(1/252) - 1
tol = 0.01
episodes = 10
days_train = 100

# %% [markdown]
# Data manipulation

# %%
data = pd.read_csv('AAPL.csv', sep=';')
data['Date'] = pd.to_datetime(data['Date'],format='%d/%m/%Y')
adj_close = data['Adj Close']
df = pd.DataFrame({'Date': data['Date'], 'log_ret': np.log(adj_close/adj_close.shift(1)).dropna()}).dropna().set_index('Date')
sp500 = pd.read_csv('sp500_joined_closes.csv', sep=',')
data.set_index('Date', inplace=True)
new_cols = list([])
for i, col in enumerate(sp500.columns):
    if col.endswith(' '):
        new_cols.append(col[:-1])
    else:
        new_cols.append(col)
sp500.columns = new_cols
sp500['Date'] = pd.to_datetime(sp500['Date'])
sp500 = sp500.set_index('Date')
sp500.drop('AAPL', axis=1, inplace=True)

# %%
sp500_lr = np.log(sp500/sp500.shift(1))
sp500_lr = sp500_lr.drop(sp500_lr.index[0])
sp500_lr = sp500_lr.drop([col for col in sp500_lr.columns if sp500_lr[col].count() < 3633], axis=1)
df = df.join(sp500_lr,how='inner').dropna()

# %% [markdown]
# Performing PCA on AAPL and SP500 stocks

# %%
cum_var_exp, PCs, regr_PCs = mylib.PCA(df['log_ret'], sp500_lr, plot=False)

# %%
regr_PCs.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   AAPL   R-squared:                       0.464
# Model:                            OLS   Adj. R-squared:                  0.463
# Method:                 Least Squares   F-statistic:                     314.1
# Date:                Sun, 07 Jul 2024   Prob (F-statistic):               0.00
# Time:                        13:16:34   Log-Likelihood:                -4020.1
# No. Observations:                3633   AIC:                             8062.
# Df Residuals:                    3622   BIC:                             8130.
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.395e-17      0.012   1.97e-15      1.000      -0.024       0.024
# PC0            0.0456      0.001     48.614      0.000       0.044       0.047
# PC1            0.0156      0.003      5.676      0.000       0.010       0.021
# PC2           -0.0751      0.003    -22.826      0.000      -0.082      -0.069
# PC3            0.0145      0.004      3.290      0.001       0.006       0.023
# PC4            0.0389      0.005      7.646      0.000       0.029       0.049
# PC5           -0.0080      0.006     -1.451      0.147      -0.019       0.003
# PC6           -0.0074      0.006     -1.266      0.206      -0.019       0.004
# PC7           -0.0679      0.006    -11.232      0.000      -0.080      -0.056
# PC8           -0.0212      0.006     -3.314      0.001      -0.034      -0.009
# PC9            0.0253      0.007      3.841      0.000       0.012       0.038
# ==============================================================================
# Omnibus:                      573.429   Durbin-Watson:                   1.928
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10155.212
# Skew:                          -0.061   Prob(JB):                         0.00
# Kurtosis:                      11.190   Cond. No.                         13.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
Y = PCs['AAPL']

# %%
[i-1 for i,p in enumerate(regr_PCs.tvalues) if abs(p) > 1.96]
# Out:
# [0, 1, 2, 3, 4, 7, 8, 9]

# %%
t_vals = regr_PCs.tvalues.drop('const')

# %%
t_vals.drop([p for p in t_vals.index if abs(t_vals[p]) == abs(t_vals).min()], inplace=True)
list(t_vals.index)
# Out:
# ['PC0', 'PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC7', 'PC8', 'PC9']

# %%
X = PCs[list(t_vals.index)]

# %%
regr_PCs = sm.OLS(Y, X).fit()
regr_PCs.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   AAPL   R-squared (uncentered):                   0.464
# Model:                            OLS   Adj. R-squared (uncentered):              0.463
# Method:                 Least Squares   F-statistic:                              348.9
# Date:                Sun, 07 Jul 2024   Prob (F-statistic):                        0.00
# Time:                        13:49:08   Log-Likelihood:                         -4020.9
# No. Observations:                3633   AIC:                                      8060.
# Df Residuals:                    3624   BIC:                                      8116.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# PC0            0.0456      0.001     48.617      0.000       0.044       0.047
# PC1            0.0156      0.003      5.677      0.000       0.010       0.021
# PC2           -0.0751      0.003    -22.828      0.000      -0.082      -0.069
# PC3            0.0145      0.004      3.290      0.001       0.006       0.023
# PC4            0.0389      0.005      7.647      0.000       0.029       0.049
# PC5           -0.0080      0.006     -1.451      0.147      -0.019       0.003
# PC7           -0.0679      0.006    -11.232      0.000      -0.080      -0.056
# PC8           -0.0212      0.006     -3.314      0.001      -0.034      -0.009
# PC9            0.0253      0.007      3.841      0.000       0.012       0.038
# ==============================================================================
# Omnibus:                      571.772   Durbin-Watson:                   1.928
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10041.479
# Skew:                          -0.066   Prob(JB):                         0.00
# Kurtosis:                      11.144   Cond. No.                         7.02
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
t_vals = regr_PCs.tvalues
t_vals.drop([p for p in t_vals.index if abs(t_vals[p]) == abs(t_vals).min()], inplace=True)
list(t_vals.index)
X = PCs[list(t_vals.index)]
X = sm.add_constant(X)
regr_PCs = sm.OLS(Y, X).fit()
regr_PCs.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   AAPL   R-squared:                       0.464
# Model:                            OLS   Adj. R-squared:                  0.463
# Method:                 Least Squares   F-statistic:                     392.0
# Date:                Sun, 07 Jul 2024   Prob (F-statistic):               0.00
# Time:                        15:28:55   Log-Likelihood:                -4021.9
# No. Observations:                3633   AIC:                             8062.
# Df Residuals:                    3624   BIC:                             8118.
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.395e-17      0.012   1.97e-15      1.000      -0.024       0.024
# PC0            0.0456      0.001     48.603      0.000       0.044       0.047
# PC1            0.0156      0.003      5.675      0.000       0.010       0.021
# PC2           -0.0751      0.003    -22.821      0.000      -0.082      -0.069
# PC3            0.0145      0.004      3.289      0.001       0.006       0.023
# PC4            0.0389      0.005      7.644      0.000       0.029       0.049
# PC7           -0.0679      0.006    -11.229      0.000      -0.080      -0.056
# PC8           -0.0212      0.006     -3.314      0.001      -0.034      -0.009
# PC9            0.0253      0.007      3.840      0.000       0.012       0.038
# ==============================================================================
# Omnibus:                      571.083   Durbin-Watson:                   1.931
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9984.148
# Skew:                          -0.070   Prob(JB):                         0.00
# Kurtosis:                      11.120   Cond. No.                         13.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
t_vals = regr_PCs.tvalues
any(abs(t_vals) < 1.96)
# Out:
# True

# %%
t_vals = regr_PCs.tvalues
t_vals.drop([p for p in t_vals.index if abs(t_vals[p]) == abs(t_vals).min()], inplace=True)
list(t_vals.index)
X = PCs[list(t_vals.index)]
regr_PCs = sm.OLS(Y, X).fit()
regr_PCs.summary()
t_vals = regr_PCs.tvalues
any(abs(t_vals) < 1.96)
# Out:
# False

# %%
regr_PCs.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   AAPL   R-squared (uncentered):                   0.464
# Model:                            OLS   Adj. R-squared (uncentered):              0.463
# Method:                 Least Squares   F-statistic:                              392.1
# Date:                Sun, 07 Jul 2024   Prob (F-statistic):                        0.00
# Time:                        15:30:54   Log-Likelihood:                         -4021.9
# No. Observations:                3633   AIC:                                      8060.
# Df Residuals:                    3625   BIC:                                      8109.
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# PC0            0.0456      0.001     48.610      0.000       0.044       0.047
# PC1            0.0156      0.003      5.676      0.000       0.010       0.021
# PC2           -0.0751      0.003    -22.824      0.000      -0.082      -0.069
# PC3            0.0145      0.004      3.290      0.001       0.006       0.023
# PC4            0.0389      0.005      7.646      0.000       0.029       0.049
# PC7           -0.0679      0.006    -11.230      0.000      -0.080      -0.056
# PC8           -0.0212      0.006     -3.314      0.001      -0.034      -0.009
# PC9            0.0253      0.007      3.840      0.000       0.012       0.038
# ==============================================================================
# Omnibus:                      571.083   Durbin-Watson:                   1.931
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9984.148
# Skew:                          -0.070   Prob(JB):                         0.00
# Kurtosis:                      11.120   Cond. No.                         7.02
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# Add the relevant PCs to the df

# %%
PCs['AAPL']
# Out:
# Date
# 2010-01-05    0.044287
# 2010-01-06   -0.960478
# 2010-01-07   -0.158106
# 2010-01-08    0.321426
# 2010-01-11   -0.554678
#                 ...
# 2024-06-05    0.387274
# 2024-06-06   -0.456310
# 2024-06-07    0.643276
# 2024-06-10   -1.147117
# 2024-06-11    1.867397
# Name: AAPL, Length: 3633, dtype: float64

# %%
dataframe = pd.DataFrame(PCs[list(t_vals.index)])
dataframe['log_ret'] = df['log_ret']
dataframe
# Out:
#                  PC0       PC1       PC2       PC3       PC4       PC7  \
# Date
# 2010-01-05  2.277725  5.598344  3.573229  1.501416 -2.727350 -0.331074
# 2010-01-06  1.487877  0.917696  1.890682 -0.739696  2.193443  2.344322
# 2010-01-07  5.457933  3.292415  3.593552  1.434769 -6.515021  2.830913
# 2010-01-08  2.347663  3.042308 -1.758965 -1.573010  3.061445  0.025891
# 2010-01-11  3.132203 -3.110919  1.425089  0.095026  0.606712  0.379562
# ...              ...       ...       ...       ...       ...       ...
# 2024-06-05  4.370851  7.734809 -5.675138  2.531673  0.669577  0.257385
# 2024-06-06 -3.327944 -0.154414 -0.253791 -1.452974  0.201252  0.250025
# 2024-06-07 -3.678136  3.166701  1.440477 -2.540191 -2.242545 -1.479271
# 2024-06-10  0.940698  1.386533 -0.699183  2.503593  3.738634  0.322610
# 2024-06-11 -5.742519 -1.431239 -3.595270 -0.203016  3.279811 -0.138426
#
#                  PC8       PC9   log_ret
# Date
# 2010-01-05 -3.486098  0.800556  0.001727
# 2010-01-06  2.210504 -0.477584 -0.016034
# 2010-01-07  1.448740 -0.823186 -0.001850
# 2010-01-08  2.377851 -1.518725  0.006626
# 2010-01-11  0.458655 -3.778597 -0.008861
# ...              ...       ...       ...
# 2024-06-05  0.070731 -0.569867  0.007790
# 2024-06-06 -2.509249  2.491141 -0.007122
# 2024-06-07  0.525229 -0.008270  0.012316
# 2024-06-10  0.032548 -1.317276 -0.019333
# 2024-06-11  1.466820  1.157794  0.033955
#
# [3633 rows x 9 columns]

# %% [markdown]
# Create the environment and agent, training

# %%
dataframe.shape
# Out:
# (3633, 8)

# %%
env = TradingEnv(dataframe, rf)
state_size = env.observation_space.shape[0]
action_size = len(env.action_space)
agent = DQN(state_size, action_size)

env.train(episodes, days_train)
print(f"Annualized rewards predicted: {(agent.reward_pred**(252/agent.n_exploit)-1)*100:.2f}%")
# Out:
# C:\Users\pietr\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Episode: 1/10
# log_return: -0.0023758004599861797
# Current Step: 1
# Current Position:
#  Stock: 1.25
#  R_f: -0.25
# env.money = 0    1244.012281
# 1    -248.802456
# Name: 1, dtype: float64
# Portfolio Value: 995.2098250457236
# Reward: -0.004790174954276381
#
# log_return: -0.003964988783018263
# Current Step: 2
# Current Position:
#  Stock: 0.19999999999999996
#  R_f: 0.8
# env.money = 0    198.053509
# 1    792.214035
# Name: 2, dtype: float64
# Portfolio Value: 990.2675439097043
# Reward: -0.004966069477652393
#
# log_return: 0.003855229557842808
# Current Step: 3
# Current Position:
#  Stock: 0.19999999999999996
#  R_f: 0.8
# env.money = 0    198.218963
# 1    792.875852
# Name: 3, dtype: float64
# Portfolio Value: 991.0948154523478
# Reward: 0.0008354020564759245
#
# log_return: 0.004673887197891421
# Current Step: 4
# Current Position:
#  Stock: 0.95
#  R_f: 0.050000000000000044
# env.money = 0    942.481458
# 1     49.604287
# Name: 4, dtype: float64
# Portfolio Value: 992.085745074796
# Reward: 0.00099983332270379
#
# log_return: 0.01737637046160955
# Current Step: 5
# Current Position:
#  Stock: 1.25
#  R_f: -0.25
# env.money = 0    1260.762079
# 1    -252.152416
# Name: 5, dtype: float64
# Portfolio Value: 1008.6096635187149
# Reward: 0.01665573618606233
#
# log_return: -0.00228612200755152
# Current Step: 6
# Current Position:
#  Stock: -0.7
#  R_f: 1.7
# env.money = 0    -703.997619
# 1    1709.708503
# Name: 6, dtype: float64
# Portfolio Value: 1005.7108842849251
# Reward: -0.0028740347615517593
#
# log_return: 0.01319202361767032
# Current Step: 7
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money = 0    -249.12414
# 1    1245.62070
# Name: 7, dtype: float64
# Portfolio Value: 996.4965599757263
# Reward: -0.009162001180637817
#
# log_return: 0.0016624647530121787
# Current Step: 8
# Current Position:
#  Stock: 1.85
#  R_f: -0.8500000000000001
# env.money = 0    1842.932894
# 1    -846.752951
# Name: 8, dtype: float64
# Portfolio Value: 996.1799424501637
# Reward: -0.0003177306759295971
#
# log_return: 0.01219515320181864
# Current Step: 9
# Current Position:
#  Stock: 0.5
#  R_f: 0.5
# env.money = 0    509.362925
# 1    509.362925
# Name: 9, dtype: float64
# Portfolio Value: 1018.7258502949321
# Reward: 0.022632364780719644
#
# log_return: 0.009846079977623044
# Current Step: 10
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money = 0    -563.093233
# 1    1586.899111
# Name: 10, dtype: float64
# Portfolio Value: 1023.8058780516255
# Reward: 0.004986648522978683
#
# log_return: -0.02371875492718506
# Current Step: 11
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money = 0    -881.559911
# 1    1918.689219
# Name: 11, dtype: float64
# Portfolio Value: 1037.1293074096852
# Reward: 0.01301362850486374
#
# log_return: -0.00012284865413011347
# Current Step: 12
# Current Position:
#  Stock: 0.6499999999999999
#  R_f: 0.3500000000000001
# env.money = 0    674.302447
# 1    363.085933
# Name: 12, dtype: float64
# Portfolio Value: 1037.3883792873753
# Reward: 0.0002497970849335353
#
# log_return: 0.02242040698879581
# Current Step: 13
# Current Position:
#  Stock: 0.5
#  R_f: 0.5
# env.money = 0    526.352899
# 1    526.352899
# Name: 13, dtype: float64
# Portfolio Value: 1052.7057987474086
# Reward: 0.014765366342888352
#
# log_return: 0.027808420498180914
# Current Step: 14
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money = 0    373.656367
# 1    693.933254
# Name: 14, dtype: float64
# Portfolio Value: 1067.5896211149504
# Reward: 0.014138634350881089
#
# log_return: 0.006433769219896847
# Current Step: 15
# Current Position:
#  Stock: 0.95
#  R_f: 0.050000000000000044
# env.money = 0    1016.553127
# 1      53.502796
# Name: 15, dtype: float64
# Portfolio Value: 1070.0559227177532
# Reward: 0.0023101588419593986
#
# log_return: -0.0014655840047599867
# Current Step: 16
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money = 0    -908.285668
# 1    1976.857043
# Name: 16, dtype: float64
# Portfolio Value: 1068.571374442193
# Reward: -0.0013873557858450146
#
# log_return: 0.0004295186023864887
# Current Step: 17
# Current Position:
#  Stock: -0.10000000000000009
#  R_f: 1.1
# env.money = 0    -106.833652
# 1    1175.170168
# Name: 17, dtype: float64
# Portfolio Value: 1068.3365162523055
# Reward: -0.00021978708723141395
#
# log_return: 0.011345464327889439
# Current Step: 18
# Current Position:
#  Stock: -0.10000000000000009
#  R_f: 1.1
# env.money = 0    -106.720989
# 1    1173.930876
# Name: 18, dtype: float64
# Portfolio Value: 1067.2098876809462
# Reward: -0.0010545633835596247
#
# log_return: 0.0027869939272604847
# Current Step: 19
# Current Position:
#  Stock: 1.6999999999999997
#  R_f: -0.6999999999999997
# env.money = 0    1813.907302
# 1    -746.903007
# Name: 19, dtype: float64
# Portfolio Value: 1067.0042953690051
# Reward: -0.0001926446843439312
#
# log_return: 0.007738693952185646
# Current Step: 20
# Current Position:
#  Stock: -0.10000000000000009
#  R_f: 1.1
# env.money = 0    -108.103733
# 1    1189.141062
# Name: 20, dtype: float64
# Portfolio Value: 1081.0373289707481
# Reward: 0.013151806101108447
#
# log_return: -0.0009190762630918709
# Current Step: 21
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money = 0    -919.045574
# 1    2000.275662
# Name: 21, dtype: float64
# Portfolio Value: 1081.230087483273
# Reward: 0.00017830884036954152
#
# log_return: 0.009671090052345324
# Current Step: 22
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money = 0    -428.982395
# 1    1501.438384
# Name: 22, dtype: float64
# Portfolio Value: 1072.4559884724727
# Reward: -0.008114923097657687
#
# log_return: -0.006970190044243873
# Current Step: 23
# Current Position:
#  Stock: 0.5
#  R_f: 0.5
# env.money = 0    537.776836
# 1    537.776836
# Name: 23, dtype: float64
# Portfolio Value: 1075.5536711679808
# Reward: 0.0028884007631122415
#
# log_return: 0.01205476172850518
# Current Step: 24
# Current Position:
#  Stock: -0.10000000000000009
#  R_f: 1.1
# env.money = 0    -108.211794
# 1    1190.329729
# Name: 24, dtype: float64
# Portfolio Value: 1082.1179355631784
# Reward: 0.006103149076762702
#
# log_return: 0.005085788189433859
# Current Step: 25
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money = 0    -432.663893
# 1    1514.323627
# Name: 25, dtype: float64
# Portfolio Value: 1081.659733456695
# Reward: -0.00042343084004515055
#
# log_return: -0.0029638678184869646
# Current Step: 26
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money = 0    379.070719
# 1    703.988478
# Name: 26, dtype: float64
# Portfolio Value: 1083.0591965862884
# Reward: 0.0012938108781410439
#
# log_return: -0.011447285579115939
# Current Step: 27
# Current Position:
#  Stock: 0.050000000000000044
#  R_f: 0.95
# env.money = 0      53.939997
# 1    1024.859934
# Name: 27, dtype: float64
# Portfolio Value: 1078.7999309857817
# Reward: -0.003932624933089159
#
# log_return: -0.00447405445685689
# Current Step: 28
# Current Position:
#  Stock: 1.1
#  R_f: -0.10000000000000009
# env.money = 0    1186.503646
# 1    -107.863968
# Name: 28, dtype: float64
# Portfolio Value: 1078.6396781209412
# Reward: -0.00014854734435700546
#
# log_return: -0.0008719289002562053
# Current Step: 29
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money = 0    377.158987
# 1    700.438119
# Name: 29, dtype: float64
# Portfolio Value: 1077.5971057127163
# Reward: -0.0009665622629803207
#
# log_return: 0.017267605717740508
# Current Step: 30
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money = 0    -433.688534
# 1    1517.909871
# Name: 30, dtype: float64
# Portfolio Value: 1084.2213361161937
# Reward: 0.006147223640783829
#
# log_return: -0.007998236623911551
# Current Step: 31
# Current Position:
#  Stock: -0.10000000000000009
#  R_f: 1.1
# env.money = 0    -108.779553
# 1    1196.575082
# Name: 31, dtype: float64
# Portfolio Value: 1087.7955294889503
# Reward: 0.0032965532531943416
#
# log_return: 0.013629478983618179
# Current Step: 32
# Current Position:
#  Stock: 0.5
#  R_f: 0.5
# env.money = 0    543.198402
# 1    543.198402
# Name: 32, dtype: float64
# Portfolio Value: 1086.3968039909698
# Reward: -0.0012858349387017132
#
# log_return: -0.0021536874180733043
# Current Step: 33
# Current Position:
#  Stock: 1.85
#  R_f: -0.8500000000000001
# env.money = 0    2007.75111
# 1    -922.48024
# Name: 33, dtype: float64
# Portfolio Value: 1085.2708705155283
# Reward: -0.0010363924776889616
#
# log_return: -0.011648304390988573
# Current Step: 34
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money = 0    -265.486791
# 1    1327.433954
# Name: 34, dtype: float64
# Portfolio Value: 1061.9471628947763
# Reward: -0.021491139451363588
#
# log_return: -0.018065840556641483
# Current Step: 35
# Current Position:
#  Stock: 1.5499999999999998
#  R_f: -0.5499999999999998
# env.money = 0    1653.547218
# 1    -586.742561
# Name: 35, dtype: float64
# Portfolio Value: 1066.804656895396
# Reward: 0.004574139062981789
#
# log_return: 0.00899962429255608
# Current Step: 36
# Current Position:
#  Stock: -0.7
#  R_f: 1.7
# env.money = 0    -757.194911
# 1    1838.901927
# Name: 36, dtype: float64
# Portfolio Value: 1081.7070158837573
# Reward: 0.013969154420201024
#
# log_return: 0.014883630097703382
# Current Step: 37
# Current Position:
#  Stock: 1.4
#  R_f: -0.3999999999999999
# env.money = 0    1498.696404
# 1    -428.198973
# Name: 37, dtype: float64
# Portfolio Value: 1070.4974314432936
# Reward: -0.010362865615053285
#
# log_return: 0.019047653908457814
# Current Step: 38
# Current Position:
#  Stock: 0.6499999999999999
#  R_f: 0.3500000000000001
# env.money = 0    714.534626
# 1    384.749414
# Name: 38, dtype: float64
# Portfolio Value: 1099.2840396627744
# Reward: 0.02689087089230034
#
# log_return: -0.014157741981798585
# Current Step: 39
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0   -1089.269353
# 1    2178.538706
# Name: 39, dtype: float64
# Portfolio Value: 1089.2693527983959
# Reward: -0.009110190363039119
#
# log_return: 0.005954698846644046
# Current Step: 40
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money = 0    -433.173973
# 1    1516.108905
# Name: 40, dtype: float64
# Portfolio Value: 1082.9349318929892
# Reward: -0.005815293425022164
#
# log_return: 0.008446214124189333
# Current Step: 41
# Current Position:
#  Stock: -0.10000000000000009
#  R_f: 1.1
# env.money = 0    -107.937990
# 1    1187.317891
# Name: 41, dtype: float64
# Portfolio Value: 1079.3799005056665
# Reward: -0.003282774691835349
#
# log_return: 0.0025292933293474154
# Current Step: 42
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money = 0    -593.559919
# 1    1672.759773
# Name: 42, dtype: float64
# Portfolio Value: 1079.1998534265379
# Reward: -0.0001668060328381607
#
# log_return: 0.013618328325904714
# Current Step: 43
# Current Position:
#  Stock: 1.85
#  R_f: -0.8500000000000001
# env.money = 0    1981.706536
# 1    -910.513814
# Name: 43, dtype: float64
# Portfolio Value: 1071.1927221120154
# Reward: -0.0074195074147751375
#
# log_return: 0.017122859759180674
# Current Step: 44
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money = 0    -607.940206
# 1    1713.286034
# Name: 44, dtype: float64
# Portfolio Value: 1105.3458283559353
# Reward: 0.03188325082771469
#
# log_return: 0.0020103932555249767
# Current Step: 45
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money = 0    -441.702815
# 1    1545.959854
# Name: 45, dtype: float64
# Portfolio Value: 1104.2570385765189
# Reward: -0.0009850218379489806
#
# log_return: -0.0024466765333782
# Current Step: 46
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money = 0    386.910269
# 1    718.547642
# Name: 46, dtype: float64
# Portfolio Value: 1105.4579106663093
# Reward: 0.0010874932627447527
#
# log_return: 0.0009908109123095879
# Current Step: 47
# Current Position:
#  Stock: 0.7999999999999998
#  R_f: 0.20000000000000018
# env.money = 0    884.718338
# 1    221.179585
# Name: 47, dtype: float64
# Portfolio Value: 1105.8979225862658
# Reward: 0.00039803588694871015
#
# log_return: -0.002076901977998475
# Current Step: 48
# Current Position:
#  Stock: 0.19999999999999996
#  R_f: 0.8
# env.money = 0    220.815948
# 1    883.263790
# Name: 48, dtype: float64
# Portfolio Value: 1104.0797375103957
# Reward: -0.001644080379152991
#
# log_return: 0.015889959600647475
# Current Step: 49
# Current Position:
#  Stock: 1.5499999999999998
#  R_f: -0.5499999999999998
# env.money = 0    1716.913192
# 1    -609.227262
# Name: 49, dtype: float64
# Portfolio Value: 1107.685930471699
# Reward: 0.003266243223913341
#
# log_return: 0.0009517323480039651
# Current Step: 50
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money = 0    388.245506
# 1    721.027368
# Name: 50, dtype: float64
# Portfolio Value: 1109.2728740384132
# Reward: 0.0014326656347782075
#
# log_return: 0.01969992517194482
# Current Step: 51
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money = 0    390.968822
# 1    726.084955
# Name: 51, dtype: float64
# Portfolio Value: 1117.053777028063
# Reward: 0.007014417436642697
#
# log_return: -0.0003774590255689333
# Current Step: 52
# Current Position:
#  Stock: 1.85
#  R_f: -0.8500000000000001
# env.money = 0    2066.382086
# 1    -949.418796
# Name: 52, dtype: float64
# Portfolio Value: 1116.9632895097675
# Reward: -8.10055166155448e-05
#
# log_return: 0.005996100148737412
# Current Step: 53
# Current Position:
#  Stock: 0.050000000000000044
#  R_f: 0.95
# env.money = 0      56.465807
# 1    1072.850328
# Name: 53, dtype: float64
# Portfolio Value: 1129.316134317512
# Reward: 0.011059311370175975
#
# log_return: 0.007202328676536718
# Current Step: 54
# Current Position:
#  Stock: 1.5499999999999998
#  R_f: -0.5499999999999998
# env.money = 0    1751.203326
# 1    -621.394729
# Name: 54, dtype: float64
# Portfolio Value: 1129.808597560188
# Reward: 0.0004360720862042595
#
# log_return: 0.022549096489377335
# Current Step: 55
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money = 0    -994.241934
# 1    2163.938328
# Name: 55, dtype: float64
# Portfolio Value: 1169.696393333508
# Reward: 0.03530491435403959
#
# log_return: -0.009917562601691523
# Current Step: 56
# Current Position:
#  Stock: 0.7999999999999998
#  R_f: 0.20000000000000018
# env.money = 0    943.742535
# 1    235.935634
# Name: 56, dtype: float64
# Portfolio Value: 1179.6781683210584
# Reward: 0.008533646033654405
#
# log_return: 0.007918982848967235
# Current Step: 57
# Current Position:
#  Stock: 0.050000000000000044
#  R_f: 0.95
# env.money = 0      59.359993
# 1    1127.839867
# Name: 57, dtype: float64
# Portfolio Value: 1187.199859704223
# Reward: 0.0063760537281702875
#
# log_return: -0.004665251162893316
# Current Step: 58
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money = 0   -1008.960376
# 1    2195.972582
# Name: 58, dtype: float64
# Portfolio Value: 1187.012206627357
# Reward: -0.00015806359420616093
#
# log_return: 0.01607588609802328
# Current Step: 59
# Current Position:
#  Stock: 1.6999999999999997
#  R_f: -0.6999999999999997
# env.money = 0    1990.417407
# 1    -819.583638
# Name: 59, dtype: float64
# Portfolio Value: 1170.8337685914912
# Reward: -0.013629546474364769
#
# log_return: 0.020783577220570316
# Current Step: 60
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money = 0    -303.142559
# 1    1515.712796
# Name: 60, dtype: float64
# Portfolio Value: 1212.5702367163535
# Reward: 0.03564679226417524
#
# log_return: 0.002211884679632065
# Current Step: 61
# Current Position:
#  Stock: 1.85
#  R_f: -0.8500000000000001
# env.money = 0    2242.233467
# 1   -1030.215377
# Name: 61, dtype: float64
# Portfolio Value: 1212.0180904365895
# Reward: -0.00045535199780194935
#
# log_return: 0.020755596821493954
# Current Step: 62
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money = 0    -692.429295
# 1    1951.391650
# Name: 62, dtype: float64
# Portfolio Value: 1258.9623549693836
# Reward: 0.03873231340621649
#
# log_return: -0.013862918011455075
# Current Step: 63
# Current Position:
#  Stock: 0.7999999999999998
#  R_f: 0.20000000000000018
# env.money = 0    1014.918853
# 1     253.729713
# Name: 63, dtype: float64
# Portfolio Value: 1268.6485662119603
# Reward: 0.007693805302710821
#
# log_return: -0.004295656298148216
# Current Step: 64
# Current Position:
#  Stock: 1.6999999999999997
#  R_f: -0.6999999999999997
# env.money = 0    2149.340793
# 1    -885.022679
# Name: 64, dtype: float64
# Portfolio Value: 1264.3181135679297
# Reward: -0.003413437542408506
#
# log_return: 0.012644194791320977
# Current Step: 65
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0   -1291.597788
# 1    2583.195576
# Name: 65, dtype: float64
# Portfolio Value: 1291.5977878567019
# Reward: 0.0215765905716469
#
# log_return: 0.011179544930092348
# Current Step: 66
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0   -1277.280298
# 1    2554.560595
# Name: 66, dtype: float64
# Portfolio Value: 1277.2802976254804
# Reward: -0.011085099684925987
#
# log_return: -0.006698887587306796
# Current Step: 67
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money = 0    -514.403524
# 1    1800.412333
# Name: 67, dtype: float64
# Portfolio Value: 1286.0088096031666
# Reward: 0.006833669942230239
#
# log_return: 0.0036132107869469646
# Current Step: 68
# Current Position:
#  Stock: 1.6999999999999997
#  R_f: -0.6999999999999997
# env.money = 0    2183.290084
# 1    -899.001799
# Name: 68, dtype: float64
# Portfolio Value: 1284.2882846487423
# Reward: -0.001337879602049677
#
# log_return: 0.004781497467612359
# Current Step: 69
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money = 0    -712.075117
# 1    2006.757147
# Name: 69, dtype: float64
# Portfolio Value: 1294.6820304509583
# Reward: 0.008093000556381113
#
# log_return: -0.0028347155901228506
# Current Step: 70
# Current Position:
#  Stock: 0.5
#  R_f: 0.5
# env.money = 0    648.427702
# 1    648.427702
# Name: 70, dtype: float64
# Portfolio Value: 1296.8554035013258
# Reward: 0.001678692527778751
#
# log_return: -0.03014812921600243
# Current Step: 71
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money = 0    -319.412305
# 1    1597.061525
# Name: 71, dtype: float64
# Portfolio Value: 1277.649219951973
# Reward: -0.014809811099602006
#
# log_return: 0.028023610613282735
# Current Step: 72
# Current Position:
#  Stock: 0.6499999999999999
#  R_f: 0.3500000000000001
# env.money = 0    824.653075
# 1    444.043963
# Name: 72, dtype: float64
# Portfolio Value: 1268.697038167894
# Reward: -0.007006760262738951
#
# log_return: 0.02029002682357939
# Current Step: 73
# Current Position:
#  Stock: 1.4
#  R_f: -0.3999999999999999
# env.money = 0    1799.889097
# 1    -514.254028
# Name: 73, dtype: float64
# Portfolio Value: 1285.6350689893422
# Reward: 0.013350729379732838
#
# log_return: -0.001418055282068161
# Current Step: 74
# Current Position:
#  Stock: -0.7
#  R_f: 1.7
# env.money = 0    -898.130886
# 1    2181.175009
# Name: 74, dtype: float64
# Portfolio Value: 1283.0441229519606
# Reward: -0.0020153044202647725
#
# log_return: -0.04484466156653545
# Current Step: 75
# Current Position:
#  Stock: 1.25
#  R_f: -0.25
# env.money = 0    1653.252707
# 1    -330.650541
# Name: 75, dtype: float64
# Portfolio Value: 1322.602165467411
# Reward: 0.03083139683804268
#
# log_return: -0.0027914286133485407
# Current Step: 76
# Current Position:
#  Stock: 1.1
#  R_f: -0.10000000000000009
# env.money = 0    1449.764448
# 1    -131.796768
# Name: 76, dtype: float64
# Portfolio Value: 1317.9676795471773
# Reward: -0.003504066484418436
#
# log_return: 0.031889586092871854
# Current Step: 77
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money = 0    -545.973910
# 1    1910.908685
# Name: 77, dtype: float64
# Portfolio Value: 1364.9347751735475
# Reward: 0.03563599954325655
#
# log_return: 0.008254261229858608
# Current Step: 78
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money = 0    -340.139920
# 1    1700.699602
# Name: 78, dtype: float64
# Portfolio Value: 1360.5596818894658
# Reward: -0.003205349708762022
#
# log_return: 0.011570515456069328
# Current Step: 79
# Current Position:
#  Stock: 0.050000000000000044
#  R_f: 0.95
# env.money = 0      67.836744
# 1    1288.898137
# Name: 79, dtype: float64
# Portfolio Value: 1356.7348805664508
# Reward: -0.0028111970198200498
#
# log_return: -0.013930933770340177
# Current Step: 80
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money = 0    -745.743730
# 1    2101.641422
# Name: 80, dtype: float64
# Portfolio Value: 1355.897691472045
# Reward: -0.0006170616724000806
#
# log_return: 0.004747340895285812
# Current Step: 81
# Current Position:
#  Stock: 0.7999999999999998
#  R_f: 0.20000000000000018
# env.money = 0    1082.011306
# 1     270.502826
# Name: 81, dtype: float64
# Portfolio Value: 1352.5141323142548
# Reward: -0.0024954383941142065
#
# log_return: -0.006143960593768039
# Current Step: 82
# Current Position:
#  Stock: -0.10000000000000009
#  R_f: 1.1
# env.money = 0    -134.590794
# 1    1480.498729
# Name: 82, dtype: float64
# Portfolio Value: 1345.907935195755
# Reward: -0.004884383061636491
#
# log_return: 0.023053427087614514
# Current Step: 83
# Current Position:
#  Stock: -0.10000000000000009
#  R_f: 1.1
# env.money = 0    -134.288546
# 1    1477.174006
# Name: 83, dtype: float64
# Portfolio Value: 1342.8854597867671
# Reward: -0.0022456776796908676
#
# log_return: -0.007090309125747772
# Current Step: 84
# Current Position:
#  Stock: -0.7
#  R_f: 1.7
# env.money = 0    -940.765226
# 1    2284.715549
# Name: 84, dtype: float64
# Portfolio Value: 1343.950323177672
# Reward: 0.000792966654858309
#
# log_return: 0.00024909202779944484
# Current Step: 85
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money = 0    -537.558200
# 1    1881.453702
# Name: 85, dtype: float64
# Portfolio Value: 1343.8955011105127
# Reward: -4.079173628218495e-05
#
# log_return: -0.018694752904225703
# Current Step: 86
# Current Position:
#  Stock: 1.25
#  R_f: -0.25
# env.money = 0    1692.499398
# 1    -338.499880
# Name: 86, dtype: float64
# Portfolio Value: 1353.9995187924078
# Reward: 0.007518454875059697
#
# log_return: 0.014546028338518443
# Current Step: 87
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money = 0   -1171.956190
# 1    2550.728179
# Name: 87, dtype: float64
# Portfolio Value: 1378.7719887449894
# Reward: 0.01829577456177783
#
# log_return: -0.010478268485964561
# Current Step: 88
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0   -1391.188396
# 1    2782.376793
# Name: 88, dtype: float64
# Portfolio Value: 1391.1883963702376
# Reward: 0.009005410413472425
#
# log_return: -0.02293414254404499
# Current Step: 89
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money = 0    -782.622323
# 1    2205.572001
# Name: 89, dtype: float64
# Portfolio Value: 1422.9496781631906
# Reward: 0.022830323970370704
#
# log_return: -0.04863462662745887
# Current Step: 90
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money = 0   -1241.233574
# 1    2701.508367
# Name: 90, dtype: float64
# Portfolio Value: 1460.2747929395298
# Reward: 0.02623080446844768
#
# log_return: -0.03386836267684374
# Current Step: 91
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money = 0    -375.455430
# 1    1877.277151
# Name: 91, dtype: float64
# Portfolio Value: 1501.8217205006113
# Reward: 0.028451444729418088
#
# log_return: 0.015453780182129832
# Current Step: 92
# Current Position:
#  Stock: 0.7999999999999998
#  R_f: 0.20000000000000018
# env.money = 0    1196.897581
# 1     299.224395
# Name: 92, dtype: float64
# Portfolio Value: 1496.1219756841397
# Reward: -0.003795220656797841
#
# log_return: -0.06695280847952449
# Current Step: 93
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money = 0    -780.248484
# 1    2198.882092
# Name: 93, dtype: float64
# Portfolio Value: 1418.6336077546566
# Reward: -0.05179281448228813
#
# log_return: -0.0005777272071783371
# Current Step: 94
# Current Position:
#  Stock: 1.6999999999999997
#  R_f: -0.6999999999999997
# env.money = 0    2412.736981
# 1    -993.479933
# Name: 94, dtype: float64
# Portfolio Value: 1419.257047367809
# Reward: 0.0004394648552977418
#
# log_return: 0.08862127110806595
# Current Step: 95
# Current Position:
#  Stock: 1.5499999999999998
#  R_f: -0.5499999999999998
# env.money = 0    2546.277191
# 1    -903.517713
# Name: 95, dtype: float64
# Portfolio Value: 1642.759477800953
# Reward: 0.15747847146340213
#
# log_return: -0.03155813625738025
# Current Step: 96
# Current Position:
#  Stock: 0.5
#  R_f: 0.5
# env.money = 0    781.793709
# 1    781.793709
# Name: 96, dtype: float64
# Portfolio Value: 1563.5874180739047
# Reward: -0.04819455361355171
#
# log_return: 0.045020229684147504
# Current Step: 97
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0   -1599.64969
# 1    3199.29938
# Name: 97, dtype: float64
# Portfolio Value: 1599.6496901622272
# Reward: 0.023063802938978365
#
# log_return: -0.03339154847673219
# Current Step: 98
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0   -1652.43393
# 1    3304.86786
# Name: 98, dtype: float64
# Portfolio Value: 1652.4339298766122
# Reward: 0.03299737438703339
#
# log_return: -0.013061919551893576
# Current Step: 99
# Current Position:
#  Stock: 1.1
#  R_f: -0.10000000000000009
# env.money = 0    1841.550975
# 1    -167.413725
# Name: 99, dtype: float64
# Portfolio Value: 1674.137249568463
# Reward: 0.013134152778786962
#
# Episode: 1/10, Score: 98, Epsilon: 1.0
#
#
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Episode: 2/10
# log_return: -0.0042869088796554785
# Current Step: 1
# Current Position:
#  Stock: 1.5499999999999998
#  R_f: -0.5499999999999998
# env.money = 0    1542.575229
# 1    -547.365404
# Name: 1, dtype: float64
# Portfolio Value: 995.2098250457236
# Reward: -0.004790174954276381
#
# log_return: 0.01273573011634791
# Current Step: 2
# Current Position:
#  Stock: 0.6499999999999999
#  R_f: 0.3500000000000001
# env.money = 0    643.673904
# 1    346.593640
# Name: 2, dtype: float64
# Portfolio Value: 990.2675439097043
# Reward: -0.004966069477652393
#
# log_return: 0.0015700162306936521
# Current Step: 3
# Current Position:
#  Stock: -0.10000000000000009
#  R_f: 1.1
# env.money = 0     -99.109482
# 1    1090.204297
# Name: 3, dtype: float64
# Portfolio Value: 991.0948154523478
# Reward: 0.0008354020564759245
#
# log_return: 0.00018715854181075488
# Current Step: 4
# Current Position:
#  Stock: 0.6499999999999999
#  R_f: 0.3500000000000001
# env.money = 0    644.855734
# 1    347.230011
# Name: 4, dtype: float64
# Portfolio Value: 992.085745074796
# Reward: 0.00099983332270379
#
# log_return: -0.008676176975738768
# Current Step: 5
# Current Position:
#  Stock: 1.85
#  R_f: -0.8500000000000001
# env.money = 0    1865.927878
# 1    -857.318214
# Name: 5, dtype: float64
# Portfolio Value: 1008.6096635187149
# Reward: 0.01665573618606233
#
# log_return: 0.014938358025017572
# Current Step: 6
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money = 0    -402.284354
# 1    1407.995238
# Name: 6, dtype: float64
# Portfolio Value: 1005.7108842849251
# Reward: -0.0028740347615517593
#
# log_return: 0.012073192995882397
# Current Step: 7
# Current Position:
#  Stock: 0.19999999999999996
#  R_f: 0.8
# env.money = 0    199.299312
# 1    797.197248
# Name: 7, dtype: float64
# Portfolio Value: 996.4965599757263
# Reward: -0.009162001180637817
#
# log_return: 0.00019307833730988137
# Current Step: 8
# Current Position:
#  Stock: 1.4
#  R_f: -0.3999999999999999
# env.money = 0    1394.651919
# 1    -398.471977
# Name: 8, dtype: float64
# Portfolio Value: 996.1799424501637
# Reward: -0.0003177306759295971
#
# log_return: 0.002639798103550969
# Current Step: 9
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0   -1018.725850
# 1    2037.451701
# Name: 9, dtype: float64
# Portfolio Value: 1018.7258502949321
# Reward: 0.022632364780719644
#
# log_return: 0.0016445970923931416
# Current Step: 10
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0   -1023.805878
# 1    2047.611756
# Name: 10, dtype: float64
# Portfolio Value: 1023.8058780516255
# Reward: 0.004986648522978683
#
# log_return: 0.011459503276477517
# Current Step: 11
# Current Position:
#  Stock: 1.25
#  R_f: -0.25
# env.money = 0    1296.411634
# 1    -259.282327
# Name: 11, dtype: float64
# Portfolio Value: 1037.1293074096852
# Reward: 0.01301362850486374
#
# log_return: 0.018503251000571184
# Current Step: 12
# Current Position:
#  Stock: 1.5499999999999998
#  R_f: -0.5499999999999998
# env.money = 0    1607.951988
# 1    -570.563609
# Name: 12, dtype: float64
# Portfolio Value: 1037.3883792873753
# Reward: 0.0002497970849335353
#
# log_return: -0.0026532150374995083
# Current Step: 13
# Current Position:
#  Stock: 1.6999999999999997
#  R_f: -0.6999999999999997
# env.money = 0    1789.599858
# 1    -736.894059
# Name: 13, dtype: float64
# Portfolio Value: 1052.7057987474086
# Reward: 0.014765366342888352
#
# log_return: 0.0179064845445247
# Current Step: 14
# Current Position:
#  Stock: 0.6499999999999999
#  R_f: 0.3500000000000001
# env.money = 0    693.933254
# 1    373.656367
# Name: 14, dtype: float64
# Portfolio Value: 1067.5896211149504
# Reward: 0.014138634350881089
#
# log_return: -0.003721467954238122
# Current Step: 15
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0   -1070.055923
# 1    2140.111845
# Name: 15, dtype: float64
# Portfolio Value: 1070.0559227177532
# Reward: 0.0023101588419593986
#
# log_return: -0.006955945673714345
# Current Step: 16
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money = 0    -908.285668
# 1    1976.857043
# Name: 16, dtype: float64
# Portfolio Value: 1068.571374442193
# Reward: -0.0013873557858450146
#
# log_return: 0.013667205540911945
# Current Step: 17
# Current Position:
#  Stock: 0.19999999999999996
#  R_f: 0.8
# env.money = 0    213.667303
# 1    854.669213
# Name: 17, dtype: float64
# Portfolio Value: 1068.3365162523055
# Reward: -0.00021978708723141395
#
# log_return: 0.011351453851044389
# Current Step: 18
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money = 0    -907.128405
# 1    1974.338292
# Name: 18, dtype: float64
# Portfolio Value: 1067.2098876809462
# Reward: -0.0010545633835596247
#
# log_return: 0.0038570347755693536
# Current Step: 19
# Current Position:
#  Stock: 0.050000000000000044
#  R_f: 0.95
# env.money = 0      53.350215
# 1    1013.654081
# Name: 19, dtype: float64
# Portfolio Value: 1067.0042953690051
# Reward: -0.0001926446843439312
#
# log_return: -0.0027810362609910744
# Current Step: 20
# Current Position:
#  Stock: 1.4
#  R_f: -0.3999999999999999
# env.money = 0    1513.452261
# 1    -432.414932
# Name: 20, dtype: float64
# Portfolio Value: 1081.0373289707481
# Reward: 0.013151806101108447
#
# log_return: 0.01624321456250256
# Current Step: 21
# Current Position:
#  Stock: 1.4
#  R_f: -0.3999999999999999
# env.money = 0    1513.722122
# 1    -432.492035
# Name: 21, dtype: float64
# Portfolio Value: 1081.230087483273
# Reward: 0.00017830884036954152
#
# log_return: 0.006011963647123949
# Current Step: 22
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0   -1072.455988
# 1    2144.911977
# Name: 22, dtype: float64
# Portfolio Value: 1072.4559884724727
# Reward: -0.008114923097657687
#
# log_return: -0.004133558767956684
# Current Step: 23
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money = 0    -591.554519
# 1    1667.108190
# Name: 23, dtype: float64
# Portfolio Value: 1075.5536711679808
# Reward: 0.0028884007631122415
#
# log_return: -0.016797432590808195
# Current Step: 24
# Current Position:
#  Stock: 0.19999999999999996
#  R_f: 0.8
# env.money = 0    216.423587
# 1    865.694348
# Name: 24, dtype: float64
# Portfolio Value: 1082.1179355631784
# Reward: 0.006103149076762702
#
# log_return: -0.010965446517880523
# Current Step: 25
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0   -1081.659733
# 1    2163.319467
# Name: 25, dtype: float64
# Portfolio Value: 1081.659733456695
# Reward: -0.00042343084004515055
#
# log_return: 0.010036669347758797
# Current Step: 26
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money = 0    -920.600317
# 1    2003.659514
# Name: 26, dtype: float64
# Portfolio Value: 1083.0591965862884
# Reward: 0.0012938108781410439
#
# log_return: -0.001252869569313479
# Current Step: 27
# Current Position:
#  Stock: 0.6499999999999999
#  R_f: 0.3500000000000001
# env.money = 0    701.219955
# 1    377.579976
# Name: 27, dtype: float64
# Portfolio Value: 1078.7999309857817
# Reward: -0.003932624933089159
#
# log_return: 0.001084981100229722
# Current Step: 28
# Current Position:
#  Stock: 0.7999999999999998
#  R_f: 0.20000000000000018
# env.money = 0    862.911742
# 1    215.727936
# Name: 28, dtype: float64
# Portfolio Value: 1078.6396781209412
# Reward: -0.00014854734435700546
#
# log_return: -0.0034551956988281844
# Current Step: 29
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money = 0    -592.678408
# 1    1670.275514
# Name: 29, dtype: float64
# Portfolio Value: 1077.5971057127163
# Reward: -0.0009665622629803207
#
# log_return: -0.01022944294331767
# Current Step: 30
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money = 0    379.477468
# 1    704.743868
# Name: 30, dtype: float64
# Portfolio Value: 1084.2213361161937
# Reward: 0.006147223640783829
#
# log_return: -0.0008872506673707808
# Current Step: 31
# Current Position:
#  Stock: 1.1
#  R_f: -0.10000000000000009
# env.money = 0    1196.575082
# 1    -108.779553
# Name: 31, dtype: float64
# Portfolio Value: 1087.7955294889503
# Reward: 0.0032965532531943416
#
# log_return: -0.006066095754917529
# Current Step: 32
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money = 0    -923.437283
# 1    2009.834087
# Name: 32, dtype: float64
# Portfolio Value: 1086.3968039909698
# Reward: -0.0012858349387017132
#
# log_return: 0.0008890032103032167
# Current Step: 33
# Current Position:
#  Stock: 1.5499999999999998
#  R_f: -0.5499999999999998
# env.money = 0    1682.169849
# 1    -596.898979
# Name: 33, dtype: float64
# Portfolio Value: 1085.2708705155283
# Reward: -0.0010363924776889616
#
# log_return: 0.006044800267944198
# Current Step: 34
# Current Position:
#  Stock: 0.6499999999999999
#  R_f: 0.3500000000000001
# env.money = 0    690.265656
# 1    371.681507
# Name: 34, dtype: float64
# Portfolio Value: 1061.9471628947763
# Reward: -0.021491139451363588
#
# log_return: 0.011839311746990185
# Current Step: 35
# Current Position:
#  Stock: 1.85
#  R_f: -0.8500000000000001
# env.money = 0    1973.588615
# 1    -906.783958
# Name: 35, dtype: float64
# Portfolio Value: 1066.804656895396
# Reward: 0.004574139062981789
#
# log_return: 0.010423844989915004
# Current Step: 36
# Current Position:
#  Stock: 0.050000000000000044
#  R_f: 0.95
# env.money = 0      54.085351
# 1    1027.621665
# Name: 36, dtype: float64
# Portfolio Value: 1081.7070158837573
# Reward: 0.013969154420201024
#
# log_return: 0.006318962337024013
# Current Step: 37
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money = 0    -588.773587
# 1    1659.271019
# Name: 37, dtype: float64
# Portfolio Value: 1070.4974314432936
# Reward: -0.010362865615053285
#
# log_return: -0.0004334957524964307
# Current Step: 38
# Current Position:
#  Stock: 0.7999999999999998
#  R_f: 0.20000000000000018
# env.money = 0    879.427232
# 1    219.856808
# Name: 38, dtype: float64
# Portfolio Value: 1099.2840396627744
# Reward: 0.02689087089230034
#
# log_return: 0.005758042134216389
# Current Step: 39
# Current Position:
#  Stock: -0.10000000000000009
#  R_f: 1.1
# env.money = 0    -108.926935
# 1    1198.196288
# Name: 39, dtype: float64
# Portfolio Value: 1089.2693527983959
# Reward: -0.009110190363039119
#
# log_return: 0.020711035841626056
# Current Step: 40
# Current Position:
#  Stock: 0.95
#  R_f: 0.050000000000000044
# env.money = 0    1028.788185
# 1      54.146747
# Name: 40, dtype: float64
# Portfolio Value: 1082.9349318929892
# Reward: -0.005815293425022164
#
# log_return: -0.0064916811850627785
# Current Step: 41
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money = 0    -431.751960
# 1    1511.131861
# Name: 41, dtype: float64
# Portfolio Value: 1079.3799005056665
# Reward: -0.003282774691835349
#
# log_return: 0.00041970014269265496
# Current Step: 42
# Current Position:
#  Stock: -0.10000000000000009
#  R_f: 1.1
# env.money = 0    -107.919985
# 1    1187.119839
# Name: 42, dtype: float64
# Portfolio Value: 1079.1998534265379
# Reward: -0.0001668060328381607
#
# log_return: -0.0036139730505125537
# Current Step: 43
# Current Position:
#  Stock: 1.85
#  R_f: -0.8500000000000001
# env.money = 0    1981.706536
# 1    -910.513814
# Name: 43, dtype: float64
# Portfolio Value: 1071.1927221120154
# Reward: -0.0074195074147751375
#
# log_return: 0.001936815375604931
# Current Step: 44
# Current Position:
#  Stock: 0.19999999999999996
#  R_f: 0.8
# env.money = 0    221.069166
# 1    884.276663
# Name: 44, dtype: float64
# Portfolio Value: 1105.3458283559353
# Reward: 0.03188325082771469
#
# log_return: 0.012569523319867167
# Current Step: 45
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money = 0    386.489964
# 1    717.767075
# Name: 45, dtype: float64
# Portfolio Value: 1104.2570385765189
# Reward: -0.0009850218379489806
#
# log_return: -0.011919932136977852
# Current Step: 46
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money = 0    -939.639224
# 1    2045.097135
# Name: 46, dtype: float64
# Portfolio Value: 1105.4579106663093
# Reward: 0.0010874932627447527
#
# log_return: -0.005579625570980467
# Current Step: 47
# Current Position:
#  Stock: 1.5499999999999998
#  R_f: -0.5499999999999998
# env.money = 0    1714.141780
# 1    -608.243857
# Name: 47, dtype: float64
# Portfolio Value: 1105.8979225862658
# Reward: 0.00039803588694871015
#
# log_return: -0.017840173920920254
# Current Step: 48
# Current Position:
#  Stock: 1.1
#  R_f: -0.10000000000000009
# env.money = 0    1214.487711
# 1    -110.407974
# Name: 48, dtype: float64
# Portfolio Value: 1104.0797375103957
# Reward: -0.001644080379152991
#
# log_return: 0.014570967922508032
# Current Step: 49
# Current Position:
#  Stock: 0.7999999999999998
#  R_f: 0.20000000000000018
# env.money = 0    886.148744
# 1    221.537186
# Name: 49, dtype: float64
# Portfolio Value: 1107.685930471699
# Reward: 0.003266243223913341
#
# log_return: -0.005118962945597317
# Current Step: 50
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money = 0    -942.881943
# 1    2052.154817
# Name: 50, dtype: float64
# Portfolio Value: 1109.2728740384132
# Reward: 0.0014326656347782075
#
# log_return: 0.00844813651793079
# Current Step: 51
# Current Position:
#  Stock: 1.25
#  R_f: -0.25
# env.money = 0    1396.317221
# 1    -279.263444
# Name: 51, dtype: float64
# Portfolio Value: 1117.053777028063
# Reward: 0.007014417436642697
#
# log_return: 0.02567902827408182
# Current Step: 52
# Current Position:
#  Stock: 0.95
#  R_f: 0.050000000000000044
# env.money = 0    1061.115125
# 1      55.848164
# Name: 52, dtype: float64
# Portfolio Value: 1116.9632895097675
# Reward: -8.10055166155448e-05
#
# log_return: -0.0016578088394050684
# Current Step: 53
# Current Position:
#  Stock: 1.1
#  R_f: -0.10000000000000009
# env.money = 0    1242.247748
# 1    -112.931613
# Name: 53, dtype: float64
# Portfolio Value: 1129.316134317512
# Reward: 0.011059311370175975
#
# log_return: 0.0066633627254572125
# Current Step: 54
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money = 0    -282.452149
# 1    1412.260747
# Name: 54, dtype: float64
# Portfolio Value: 1129.808597560188
# Reward: 0.0004360720862042595
#
# log_return: 0.013972844934924794
# Current Step: 55
# Current Position:
#  Stock: 0.19999999999999996
#  R_f: 0.8
# env.money = 0    233.939279
# 1    935.757115
# Name: 55, dtype: float64
# Portfolio Value: 1169.696393333508
# Reward: 0.03530491435403959
#
# log_return: -0.006627281207704443
# Current Step: 56
# Current Position:
#  Stock: -0.7
#  R_f: 1.7
# env.money = 0    -825.774718
# 1    2005.452886
# Name: 56, dtype: float64
# Portfolio Value: 1179.6781683210584
# Reward: 0.008533646033654405
#
# log_return: -0.0023122525077837156
# Current Step: 57
# Current Position:
#  Stock: 1.1
#  R_f: -0.10000000000000009
# env.money = 0    1305.919846
# 1    -118.719986
# Name: 57, dtype: float64
# Portfolio Value: 1187.199859704223
# Reward: 0.0063760537281702875
#
# log_return: -0.026429698675411242
# Current Step: 58
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money = 0    -474.804883
# 1    1661.817089
# Name: 58, dtype: float64
# Portfolio Value: 1187.012206627357
# Reward: -0.00015806359420616093
#
# log_return: 0.005541379795208299
# Current Step: 59
# Current Position:
#  Stock: 1.25
#  R_f: -0.25
# env.money = 0    1463.542211
# 1    -292.708442
# Name: 59, dtype: float64
# Portfolio Value: 1170.8337685914912
# Reward: -0.013629546474364769
#
# log_return: -0.0055227817115616465
# Current Step: 60
# Current Position:
#  Stock: 0.95
#  R_f: 0.050000000000000044
# env.money = 0    1151.941725
# 1      60.628512
# Name: 60, dtype: float64
# Portfolio Value: 1212.5702367163535
# Reward: 0.03564679226417524
#
# log_return: -0.004877629607437164
# Current Step: 61
# Current Position:
#  Stock: 0.5
#  R_f: 0.5
# env.money = 0    606.009045
# 1    606.009045
# Name: 61, dtype: float64
# Portfolio Value: 1212.0180904365895
# Reward: -0.00045535199780194935
#
# log_return: -0.001672340500727233
# Current Step: 62
# Current Position:
#  Stock: -0.7
#  R_f: 1.7
# env.money = 0    -881.273648
# 1    2140.236003
# Name: 62, dtype: float64
# Portfolio Value: 1258.9623549693836
# Reward: 0.03873231340621649
#
# log_return: -0.00010561443334377366
# Current Step: 63
# Current Position:
#  Stock: -0.10000000000000009
#  R_f: 1.1
# env.money = 0    -126.864857
# 1    1395.513423
# Name: 63, dtype: float64
# Portfolio Value: 1268.6485662119603
# Reward: 0.007693805302710821
#
# log_return: 0.0028163449251361506
# Current Step: 64
# Current Position:
#  Stock: 1.25
#  R_f: -0.25
# env.money = 0    1580.397642
# 1    -316.079528
# Name: 64, dtype: float64
# Portfolio Value: 1264.3181135679297
# Reward: -0.003413437542408506
#
# log_return: 0.013042660119190117
# Current Step: 65
# Current Position:
#  Stock: 1.5499999999999998
#  R_f: -0.5499999999999998
# env.money = 0    2001.976571
# 1    -710.378783
# Name: 65, dtype: float64
# Portfolio Value: 1291.5977878567019
# Reward: 0.0215765905716469
#
# log_return: -0.00020946194325028905
# Current Step: 66
# Current Position:
#  Stock: 1.85
#  R_f: -0.8500000000000001
# env.money = 0    2362.968551
# 1   -1085.688253
# Name: 66, dtype: float64
# Portfolio Value: 1277.2802976254804
# Reward: -0.011085099684925987
#
# log_return: 0.013070223899911516
# Current Step: 67
# Current Position:
#  Stock: 1.85
#  R_f: -0.8500000000000001
# env.money = 0    2379.116298
# 1   -1093.107488
# Name: 67, dtype: float64
# Portfolio Value: 1286.0088096031666
# Reward: 0.006833669942230239
#
# log_return: 0.0027257098898222244
# Current Step: 68
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money = 0    -321.072071
# 1    1605.360356
# Name: 68, dtype: float64
# Portfolio Value: 1284.2882846487423
# Reward: -0.001337879602049677
#
# log_return: 0.0049263940871320305
# Current Step: 69
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0   -1294.682030
# 1    2589.364061
# Name: 69, dtype: float64
# Portfolio Value: 1294.6820304509583
# Reward: 0.008093000556381113
#
# log_return: 0.011930946457372528
# Current Step: 70
# Current Position:
#  Stock: 0.19999999999999996
#  R_f: 0.8
# env.money = 0     259.371081
# 1    1037.484323
# Name: 70, dtype: float64
# Portfolio Value: 1296.8554035013258
# Reward: 0.001678692527778751
#
# log_return: 0.013386607596743032
# Current Step: 71
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money = 0    -319.412305
# 1    1597.061525
# Name: 71, dtype: float64
# Portfolio Value: 1277.649219951973
# Reward: -0.014809811099602006
#
# log_return: 0.00039519552782931366
# Current Step: 72
# Current Position:
#  Stock: 0.6499999999999999
#  R_f: 0.3500000000000001
# env.money = 0    824.653075
# 1    444.043963
# Name: 72, dtype: float64
# Portfolio Value: 1268.697038167894
# Reward: -0.007006760262738951
#
# log_return: 9.770382280438326e-05
# Current Step: 73
# Current Position:
#  Stock: 1.1
#  R_f: -0.10000000000000009
# env.money = 0    1414.198576
# 1    -128.563507
# Name: 73, dtype: float64
# Portfolio Value: 1285.6350689893422
# Reward: 0.013350729379732838
#
# log_return: 0.007315599499060043
# Current Step: 74
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money = 0    -320.761031
# 1    1603.805154
# Name: 74, dtype: float64
# Portfolio Value: 1283.0441229519606
# Reward: -0.0020153044202647725
#
# log_return: 0.002128943548932218
# Current Step: 75
# Current Position:
#  Stock: 1.6999999999999997
#  R_f: -0.6999999999999997
# env.money = 0    2248.423681
# 1    -925.821516
# Name: 75, dtype: float64
# Portfolio Value: 1322.602165467411
# Reward: 0.03083139683804268
#
# log_return: -0.006288522870788035
# Current Step: 76
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money = 0   -1120.272528
# 1    2438.240207
# Name: 76, dtype: float64
# Portfolio Value: 1317.9676795471773
# Reward: -0.003504066484418436
#
# log_return: 0.012232522408781919
# Current Step: 77
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0   -1364.934775
# 1    2729.869550
# Name: 77, dtype: float64
# Portfolio Value: 1364.9347751735475
# Reward: 0.03563599954325655
#
# log_return: 0.0011867961127224656
# Current Step: 78
# Current Position:
#  Stock: 1.1
#  R_f: -0.10000000000000009
# env.money = 0    1496.615650
# 1    -136.055968
# Name: 78, dtype: float64
# Portfolio Value: 1360.5596818894658
# Reward: -0.003205349708762022
#
# log_return: 0.002479203505445262
# Current Step: 79
# Current Position:
#  Stock: 0.7999999999999998
#  R_f: 0.20000000000000018
# env.money = 0    1085.387904
# 1     271.346976
# Name: 79, dtype: float64
# Portfolio Value: 1356.7348805664508
# Reward: -0.0028111970198200498
#
# log_return: 0.007953483705108394
# Current Step: 80
# Current Position:
#  Stock: 1.1
#  R_f: -0.10000000000000009
# env.money = 0    1491.487461
# 1    -135.589769
# Name: 80, dtype: float64
# Portfolio Value: 1355.897691472045
# Reward: -0.0006170616724000806
#
# log_return: -0.04307529330134363
# Current Step: 81
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money = 0    -338.128533
# 1    1690.642665
# Name: 81, dtype: float64
# Portfolio Value: 1352.5141323142548
# Reward: -0.0024954383941142065
#
# log_return: -0.008529202563088882
# Current Step: 82
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money = 0    -740.249364
# 1    2086.157300
# Name: 82, dtype: float64
# Portfolio Value: 1345.907935195755
# Reward: -0.004884383061636491
#
# log_return: 0.008666756067726432
# Current Step: 83
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money = 0    -537.154184
# 1    1880.039644
# Name: 83, dtype: float64
# Portfolio Value: 1342.8854597867671
# Reward: -0.0022456776796908676
#
# log_return: -0.006270301570194344
# Current Step: 84
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money = 0   -1142.357775
# 1    2486.308098
# Name: 84, dtype: float64
# Portfolio Value: 1343.950323177672
# Reward: 0.000792966654858309
#
# log_return: -0.003725235698104408
# Current Step: 85
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money = 0    -335.973875
# 1    1679.869376
# Name: 85, dtype: float64
# Portfolio Value: 1343.8955011105127
# Reward: -4.079173628218495e-05
#
# log_return: 0.03058248215553213
# Current Step: 86
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money = 0    -338.499880
# 1    1692.499398
# Name: 86, dtype: float64
# Portfolio Value: 1353.9995187924078
# Reward: 0.007518454875059697
#
# log_return: 0.0042035479656023335
# Current Step: 87
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money = 0    482.570196
# 1    896.201793
# Name: 87, dtype: float64
# Portfolio Value: 1378.7719887449894
# Reward: 0.01829577456177783
#
# log_return: 0.002261468023156809
# Current Step: 88
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money = 0    -556.475359
# 1    1947.663755
# Name: 88, dtype: float64
# Portfolio Value: 1391.1883963702376
# Reward: 0.009005410413472425
#
# log_return: -0.00029452837109044576
# Current Step: 89
# Current Position:
# ...
#
# log_return: 0.0012239883985217142
# Current Step: 44
# Current Position:
#  Stock: -0.7
#  R_f: 1.7
# env.money = 0    -773.742080
# 1    1879.087908
# Name: 44, dtype: float64
# Portfolio Value: 1105.3458283559353
# Reward: 0.03188325082771469
#
# log_return: -0.005348365583198923
# Current Step: 45
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money = 0    386.489964
# 1    717.767075
# Name: 45, dtype: float64
# Portfolio Value: 1104.2570385765189
# Reward: -0.0009850218379489806
#
# log_return: 0.005552080946781362
# Current Step: 46
# Current Position:
#  Stock: 1.5499999999999998
#  R_f: -0.5499999999999998
# env.money = 0    1713.459762
# 1    -608.001851
# Name: 46, dtype: float64
# Portfolio Value: 1105.4579106663093
# Reward: 0.0010874932627447527
#
# log_return: -0.004577998073097812
# Current Step: 47
# Current Position:
#  Stock: 0.6499999999999999
#  R_f: 0.3500000000000001
# env.money = 0    718.833650
# 1    387.064273
# Name: 47, dtype: float64
# Portfolio Value: 1105.8979225862658
# Reward: 0.00039803588694871015
#
# log_return: -0.0038116794011067287
# Current Step: 48
# Current Position:
#  Stock: 0.19999999999999996
#  R_f: 0.8
# env.money = 0    220.815948
# 1    883.263790
# Name: 48, dtype: float64
# Portfolio Value: 1104.0797375103957
# Reward: -0.001644080379152991
#
# log_return: 0.012297727535287243
# Current Step: 49
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money = 0    -443.074372
# 1    1550.760303
# Name: 49, dtype: float64
# Portfolio Value: 1107.685930471699
# Reward: 0.003266243223913341
#
# log_return: -0.0011742822482873185
# Current Step: 50
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0   -1109.272874
# 1    2218.545748
# Name: 50, dtype: float64
# Portfolio Value: 1109.2728740384132
# Reward: 0.0014326656347782075
#
# log_return: 0.009232870457451775
# Current Step: 51
# Current Position:
#  Stock: 0.7999999999999998
#  R_f: 0.20000000000000018
# env.money = 0    893.643022
# 1    223.410755
# Name: 51, dtype: float64
# Portfolio Value: 1117.053777028063
# Reward: 0.007014417436642697
#
# log_return: 0.006061440417086252
# Current Step: 52
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money = 0    -949.418796
# 1    2066.382086
# Name: 52, dtype: float64
# Portfolio Value: 1116.9632895097675
# Reward: -8.10055166155448e-05
#
# log_return: -0.0058472816968892045
# Current Step: 53
# Current Position:
#  Stock: 1.1
#  R_f: -0.10000000000000009
# env.money = 0    1242.247748
# 1    -112.931613
# Name: 53, dtype: float64
# Portfolio Value: 1129.316134317512
# Reward: 0.011059311370175975
#
# log_return: 0.0007755517555828454
# Current Step: 54
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money = 0    395.433009
# 1    734.375588
# Name: 54, dtype: float64
# Portfolio Value: 1129.808597560188
# Reward: 0.0004360720862042595
#
# log_return: -0.0009909835902812852
# Current Step: 55
# Current Position:
#  Stock: 0.5
#  R_f: 0.5
# env.money = 0    584.848197
# 1    584.848197
# Name: 55, dtype: float64
# Portfolio Value: 1169.696393333508
# Reward: 0.03530491435403959
#
# log_return: 0.019834183073214995
# Current Step: 56
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0   -1179.678168
# 1    2359.356337
# Name: 56, dtype: float64
# Portfolio Value: 1179.6781683210584
# Reward: 0.008533646033654405
#
# log_return: 0.006356439063654777
# Current Step: 57
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money = 0    415.519951
# 1    771.679909
# Name: 57, dtype: float64
# Portfolio Value: 1187.199859704223
# Reward: 0.0063760537281702875
#
# log_return: -0.0030922379681365634
# Current Step: 58
# Current Position:
#  Stock: 1.1
#  R_f: -0.10000000000000009
# env.money = 0    1305.713427
# 1    -118.701221
# Name: 58, dtype: float64
# Portfolio Value: 1187.012206627357
# Reward: -0.00015806359420616093
#
# log_return: -0.0035972647649442986
# Current Step: 59
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0   -1170.833769
# 1    2341.667537
# Name: 59, dtype: float64
# Portfolio Value: 1170.8337685914912
# Reward: -0.013629546474364769
#
# log_return: 0.016433551929329084
# Current Step: 60
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money = 0    -666.913630
# 1    1879.483867
# Name: 60, dtype: float64
# Portfolio Value: 1212.5702367163535
# Reward: 0.03564679226417524
#
# log_return: 0.026689176004734905
# Current Step: 61
# Current Position:
#  Stock: 1.6999999999999997
#  R_f: -0.6999999999999997
# env.money = 0    2060.430754
# 1    -848.412663
# Name: 61, dtype: float64
# Portfolio Value: 1212.0180904365895
# Reward: -0.00045535199780194935
#
# log_return: 0.0063278814418775255
# Current Step: 62
# Current Position:
#  Stock: 1.5499999999999998
#  R_f: -0.5499999999999998
# env.money = 0    1951.391650
# 1    -692.429295
# Name: 62, dtype: float64
# Portfolio Value: 1258.9623549693836
# Reward: 0.03873231340621649
#
# log_return: -0.004682302161608556
# Current Step: 63
# Current Position:
#  Stock: 1.85
#  R_f: -0.8500000000000001
# env.money = 0    2346.999847
# 1   -1078.351281
# Name: 63, dtype: float64
# Portfolio Value: 1268.6485662119603
# Reward: 0.007693805302710821
#
# log_return: 0.008392556774647357
# Current Step: 64
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money = 0    -505.727245
# 1    1770.045359
# Name: 64, dtype: float64
# Portfolio Value: 1264.3181135679297
# Reward: -0.003413437542408506
#
# log_return: 0.0136571232212116
# Current Step: 65
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money = 0    452.059226
# 1    839.538562
# Name: 65, dtype: float64
# Portfolio Value: 1291.5977878567019
# Reward: 0.0215765905716469
#
# log_return: -0.002573356083366553
# Current Step: 66
# Current Position:
#  Stock: 0.5
#  R_f: 0.5
# env.money = 0    638.640149
# 1    638.640149
# Name: 66, dtype: float64
# Portfolio Value: 1277.2802976254804
# Reward: -0.011085099684925987
#
# log_return: -0.001458911302851454
# Current Step: 67
# Current Position:
#  Stock: 0.95
#  R_f: 0.050000000000000044
# env.money = 0    1221.708369
# 1      64.300440
# Name: 67, dtype: float64
# Portfolio Value: 1286.0088096031666
# Reward: 0.006833669942230239
#
# log_return: -0.034310744489760917
# Current Step: 68
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money = 0   -1091.645042
# 1    2375.933327
# Name: 68, dtype: float64
# Portfolio Value: 1284.2882846487423
# Reward: -0.001337879602049677
#
# log_return: 0.014892776411070223
# Current Step: 69
# Current Position:
#  Stock: 1.25
#  R_f: -0.25
# env.money = 0    1618.352538
# 1    -323.670508
# Name: 69, dtype: float64
# Portfolio Value: 1294.6820304509583
# Reward: 0.008093000556381113
#
# log_return: 0.003397755735484455
# Current Step: 70
# Current Position:
#  Stock: 0.7999999999999998
#  R_f: 0.20000000000000018
# env.money = 0    1037.484323
# 1     259.371081
# Name: 70, dtype: float64
# Portfolio Value: 1296.8554035013258
# Reward: 0.001678692527778751
#
# log_return: 0.0060416574509103635
# Current Step: 71
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money = 0   -1086.001837
# 1    2363.651057
# Name: 71, dtype: float64
# Portfolio Value: 1277.649219951973
# Reward: -0.014809811099602006
#
# log_return: -0.0012558283310666223
# Current Step: 72
# Current Position:
#  Stock: 1.1
#  R_f: -0.10000000000000009
# env.money = 0    1395.566742
# 1    -126.869704
# Name: 72, dtype: float64
# Portfolio Value: 1268.697038167894
# Reward: -0.007006760262738951
#
# log_return: -0.00306292736343777
# Current Step: 73
# Current Position:
#  Stock: 1.25
#  R_f: -0.25
# env.money = 0    1607.043836
# 1    -321.408767
# Name: 73, dtype: float64
# Portfolio Value: 1285.6350689893422
# Reward: 0.013350729379732838
#
# log_return: 0.003552229747129712
# Current Step: 74
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money = 0    -513.217649
# 1    1796.261772
# Name: 74, dtype: float64
# Portfolio Value: 1283.0441229519606
# Reward: -0.0020153044202647725
#
# log_return: -0.0017473748332024598
# Current Step: 75
# Current Position:
#  Stock: 1.25
#  R_f: -0.25
# env.money = 0    1653.252707
# 1    -330.650541
# Name: 75, dtype: float64
# Portfolio Value: 1322.602165467411
# Reward: 0.03083139683804268
#
# log_return: 0.0003775356520635172
# Current Step: 76
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money = 0    -724.882224
# 1    2042.849903
# Name: 76, dtype: float64
# Portfolio Value: 1317.9676795471773
# Reward: -0.003504066484418436
#
# log_return: -0.006161888482527906
# Current Step: 77
# Current Position:
#  Stock: 1.1
#  R_f: -0.10000000000000009
# env.money = 0    1501.428253
# 1    -136.493478
# Name: 77, dtype: float64
# Portfolio Value: 1364.9347751735475
# Reward: 0.03563599954325655
#
# log_return: 0.0026828852815780385
# Current Step: 78
# Current Position:
#  Stock: 1.25
#  R_f: -0.25
# env.money = 0    1700.699602
# 1    -340.139920
# Name: 78, dtype: float64
# Portfolio Value: 1360.5596818894658
# Reward: -0.003205349708762022
#
# log_return: 0.01492118020892395
# Current Step: 79
# Current Position:
#  Stock: 1.25
#  R_f: -0.25
# env.money = 0    1695.918601
# 1    -339.183720
# Name: 79, dtype: float64
# Portfolio Value: 1356.7348805664508
# Reward: -0.0028111970198200498
#
# log_return: -0.009425139088127534
# Current Step: 80
# Current Position:
#  Stock: 1.25
#  R_f: -0.25
# env.money = 0    1694.872114
# 1    -338.974423
# Name: 80, dtype: float64
# Portfolio Value: 1355.897691472045
# Reward: -0.0006170616724000806
#
# log_return: 0.0033956711643459963
# Current Step: 81
# Current Position:
#  Stock: 0.5
#  R_f: 0.5
# env.money = 0    676.257066
# 1    676.257066
# Name: 81, dtype: float64
# Portfolio Value: 1352.5141323142548
# Reward: -0.0024954383941142065
#
# log_return: 0.005965809481794741
# Current Step: 82
# Current Position:
#  Stock: 1.5499999999999998
#  R_f: -0.5499999999999998
# env.money = 0    2086.157300
# 1    -740.249364
# Name: 82, dtype: float64
# Portfolio Value: 1345.907935195755
# Reward: -0.004884383061636491
#
# log_return: -0.002543131846968394
# Current Step: 83
# Current Position:
#  Stock: 0.6499999999999999
#  R_f: 0.3500000000000001
# env.money = 0    872.875549
# 1    470.009911
# Name: 83, dtype: float64
# Portfolio Value: 1342.8854597867671
# Reward: -0.0022456776796908676
#
# log_return: -0.03918585517237143
# Current Step: 84
# Current Position:
#  Stock: -0.10000000000000009
#  R_f: 1.1
# env.money = 0    -134.395032
# 1    1478.345355
# Name: 84, dtype: float64
# Portfolio Value: 1343.950323177672
# Reward: 0.000792966654858309
#
# log_return: -0.024079635049263238
# Current Step: 85
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money = 0   -1142.311176
# 1    2486.206677
# Name: 85, dtype: float64
# Portfolio Value: 1343.8955011105127
# Reward: -4.079173628218495e-05
#
# log_return: 0.007999015838177852
# Current Step: 86
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money = 0    473.899832
# 1    880.099687
# Name: 86, dtype: float64
# Portfolio Value: 1353.9995187924078
# Reward: 0.007518454875059697
#
# log_return: -0.009662041088781582
# Current Step: 87
# Current Position:
#  Stock: 1.85
#  R_f: -0.8500000000000001
# env.money = 0    2550.728179
# 1   -1171.956190
# Name: 87, dtype: float64
# Portfolio Value: 1378.7719887449894
# Reward: 0.01829577456177783
#
# log_return: -0.005877183986435209
# Current Step: 88
# Current Position:
#  Stock: 1.25
#  R_f: -0.25
# env.money = 0    1738.985495
# 1    -347.797099
# Name: 88, dtype: float64
# Portfolio Value: 1391.1883963702376
# Reward: 0.009005410413472425
#
# log_return: -0.014116695588077332
# Current Step: 89
# Current Position:
#  Stock: -0.10000000000000009
#  R_f: 1.1
# env.money = 0    -142.294968
# 1    1565.244646
# Name: 89, dtype: float64
# Portfolio Value: 1422.9496781631906
# Reward: 0.022830323970370704
#
# log_return: 0.028170531444320662
# Current Step: 90
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money = 0   -1241.233574
# 1    2701.508367
# Name: 90, dtype: float64
# Portfolio Value: 1460.2747929395298
# Reward: 0.02623080446844768
#
# log_return: -0.009049064792552616
# Current Step: 91
# Current Position:
#  Stock: 1.85
#  R_f: -0.8500000000000001
# env.money = 0    2778.370183
# 1   -1276.548462
# Name: 91, dtype: float64
# Portfolio Value: 1501.8217205006113
# Reward: 0.028451444729418088
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# EXPLOITATION
# log_return: 0.005910993735112533
# Current Step: 92
# Current Position:
#  Stock: 0.5
#  R_f: 0.5
# env.money = 0    748.060988
# 1    748.060988
# Name: 92, dtype: float64
# Portfolio Value: 1496.1219756841397
# Reward: -0.003795220656797841
#
# log_return: -0.0017081918926735269
# Current Step: 93
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money = 0   -1205.838567
# 1    2624.472174
# Name: 93, dtype: float64
# Portfolio Value: 1418.6336077546566
# Reward: -0.05179281448228813
#
# log_return: 0.0044671244372264185
# Current Step: 94
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money = 0    -567.702819
# 1    1986.959866
# Name: 94, dtype: float64
# Portfolio Value: 1419.257047367809
# Reward: 0.0004394648552977418
#
# log_return: -0.003127551495736015
# Current Step: 95
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money = 0    -657.103791
# 1    2299.863269
# Name: 95, dtype: float64
# Portfolio Value: 1642.759477800953
# Reward: 0.15747847146340213
#
# log_return: -0.01458398093581416
# Current Step: 96
# Current Position:
#  Stock: 0.7999999999999998
#  R_f: 0.20000000000000018
# env.money = 0    1250.869934
# 1     312.717484
# Name: 96, dtype: float64
# Portfolio Value: 1563.5874180739047
# Reward: -0.04819455361355171
#
# log_return: 0.014453865307461063
# Current Step: 97
# Current Position:
#  Stock: 1.25
#  R_f: -0.25
# env.money = 0    1999.562113
# 1    -399.912423
# Name: 97, dtype: float64
# Portfolio Value: 1599.6496901622272
# Reward: 0.023063802938978365
#
# log_return: -0.0144549452083849
# Current Step: 98
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money = 0    -413.108482
# 1    2065.542412
# Name: 98, dtype: float64
# Portfolio Value: 1652.4339298766122
# Reward: 0.03299737438703339
#
# log_return: 0.0024437230796029233
# Current Step: 99
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0   -1674.137250
# 1    3348.274499
# Name: 99, dtype: float64
# Portfolio Value: 1674.137249568463
# Reward: 0.013134152778786962
#
# Episode: 10/10, Score: 98, Epsilon: 0.96
#
#
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Annualized rewards predicted: 1059.17%
