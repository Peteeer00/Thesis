# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from collections import deque
import random
import gymnasium as gym
from gymnasium import spaces
import datetime
import my_library as mylib
import statsmodels.api as sm
import matplotlib.pyplot as plt
pd.options.mode.chained_assignment = None

# %% [markdown]
# Environment Definition

# %%
class TradingEnv(gym.Env):
    def __init__(self, df, rf):
        super(TradingEnv, self).__init__()

        self.current_step = 0
        self.data = df.iloc[:,df.columns != 'log_ret']
        self.y = df['log_ret']
        self.initial_position = pd.DataFrame({'0': [0], '1': [1]}) # Initial position is 1000 in risk_free asset
        self.position = self.initial_position
        self.initial_portfolio_value = list([1000])
        self.money = pd.DataFrame(self.initial_portfolio_value[0] * self.position)
        self.rf = rf
        self.pos_sup = 2
        self.pos_inf = -1
        # Define action and observation space
        
        # Only one stock, the rest is in cash
        self.action_space = np.arange(self.pos_inf, self.pos_sup, 0.15).round(2)
        # If two stocks, then self.action_space = spaces.Box(low=np.array([0,0]), high=np.array([1,1]), dtype=np.float32)
        
        # observation_space is a dataframe with historical data
        self.observation_space = spaces.Box(low=0, high=np.inf, shape=(1,), dtype=np.float32)
           
    def step(self, state, action):
        # Execute one time step within the environment
        self.current_step += 1
        self.flag = 0

        # End the episode if we've run out of data
        if self.current_step >= days_train:
            return self.position, 0, True

        # Take the action (<0: short stock, ==0: hold positions, >0: buy stock)
        # action = action[0][0]
        if (action > self.pos_sup) or (action < self.pos_inf):
            reward = - 1000
            self.flag = 1
        new_port_value = np.exp(state[0]) * self.money.iloc[self.current_step-1,0] + self.money.iloc[self.current_step-1,1] * (1+self.rf)
        self.portfolio_value.append(new_port_value)
        
        if abs(action - self.position.iloc[self.current_step-1,0]) >= tol:
            new_row_pos = pd.DataFrame([[action, (1 - action)]])
        else:
            new_row_pos = pd.DataFrame([[self.position.iloc[self.current_step-1,0], self.position.iloc[self.current_step-1,1]]])
        self.position = pd.concat([self.position, new_row_pos], axis=0, ignore_index=True)    
        new_row_money = pd.DataFrame([[self.position.iloc[self.current_step,0]*self.portfolio_value[self.current_step], self.position.iloc[self.current_step,1]*self.portfolio_value[self.current_step]]])
        self.money = pd.concat([self.money, new_row_money], axis=0, ignore_index=True)

        if self.flag == 0:
            reward = (self.portfolio_value[self.current_step] - self.portfolio_value[self.current_step-1])/self.portfolio_value[self.current_step-1]
        
        done = self.current_step >= days_train - 1
        
        observation = np.concatenate(([self.y_train.iloc[self.current_step]], self.df_train.iloc[self.current_step], [self.position.iloc[self.current_step,0], self.position.iloc[self.current_step,1], self.money.iloc[self.current_step,0], self.money.iloc[self.current_step,1], self.portfolio_value[self.current_step]]))

        return observation, reward, done

    def reset(self):
        # Reset the state of the environment to an initial state
        self.current_step = 0
        a = (3 * np.random.rand(1) - 1)[0].round(5)
        self.position = pd.DataFrame([a,1-a]).T
        self.portfolio_value = self.initial_portfolio_value
        self.money = pd.DataFrame(self.portfolio_value[0] * self.position)
        starting_point = np.random.randint(0, self.data.shape[0]-days_train)
        self.df_train = self.data.iloc[starting_point:starting_point+days_train,]
        self.y_train = self.y.iloc[starting_point:starting_point+days_train,]
        for i in range(days_train):
            b = (0.05 * np.random.rand(1) - 0.025)[0].round(5)
            self.y_train.iloc[i] *= (1+b)
            for j in range(len(self.df_train.columns)):
                c = (0.05 * np.random.rand(1) - 0.025)[0].round(5)
                self.df_train.iloc[i,j] *= (1+c)

        # The first observation is the returns of the first day, the initial position, and the initial portfolio value
        observation = np.insert(self.df_train.iloc[self.current_step].values.flatten(),0,self.y_train.iloc[self.current_step])
        observation = np.concatenate((observation, [self.position.iloc[self.current_step,0], self.position.iloc[self.current_step,1], self.money.iloc[self.current_step,0], self.money.iloc[self.current_step,1], self.portfolio_value[self.current_step]]))

        return observation

    def render(self, mode='human'):
        # Render the environment to the screen
        if mode == 'human':
            print(f"Current Step: {self.current_step}")
            # print(f"Current Price: {self.df_train.iloc[self.current_step]}")
            print(f"Current Position:\n Stock: {self.position.iloc[self.current_step,0]}\n R_f: {self.position.iloc[self.current_step,1]}")
            print(f"env.money = {self.money.iloc[self.current_step]}")
            print(f"Portfolio Value: {self.portfolio_value[self.current_step]}")
    
    def train(self, episodes, days):
        self.days_train = days
        for e in range(episodes):
            print(f"Episode: {e+1}/{episodes}")
            state = env.reset()
            # state = np.reshape(state, [1, state_size])
            for time in range(days): 
                action = agent.act(state)*0.15-1
                print(f"log_return: {state[0]}")
                next_state, reward, done = env.step(state,action)
                if agent.flag == 1:
                    agent.reward_pred *= (1+reward)
                    agent.flag = 0
                # next_state = np.reshape(next_state, [1, state_size])
                agent.remember(state, action, reward, next_state, done)
                self.render()
                print(f"Reward: {reward}\n")
                state = next_state
                if done:
                    print(f"Episode: {e+1}/{episodes}, Score: {time}, Epsilon: {agent.epsilon:.2}\n\n\n")
                    break
            if len(agent.memory) > 32:
                agent.replay(32)

# %% [markdown]
# Agent Definition

# %%
class DQN:
    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.memory = deque(maxlen=3000)
        self.gamma = 0.95  # discount rate
        self.epsilon = 1.0  # exploration rate
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995
        self.learning_rate = 0.001
        self.model = self._build_model()
        self.reward_pred = 1
        self.n_exploit = 0
        self.flag = 0

    def _build_model(self):
        model = Sequential()
        model.add(Dense(64, input_dim=self.state_size, activation='sigmoid'))
        model.add(Dense(64, activation='sigmoid'))
        model.add(Dense(self.action_size, activation='linear'))
        model.compile(loss='mse', optimizer=Adam(learning_rate=self.learning_rate))
        return model

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        act_values = self.model.predict(state)
        print("EXPLOITATION")
        self.flag = 1
        self.n_exploit += 1
        return np.argmax(act_values[0])

    def replay(self, batch_size):
        minibatch = random.sample(self.memory, batch_size)
        for state, action, reward, next_state, done in minibatch:
            target = reward
            if not done:
                target = (reward + self.gamma * np.amax(self.model.predict(next_state)[0]))
            target_f = self.model.predict(state)
            target_f[0][int(action)] = target
            self.model.fit(state, target_f, epochs=1, verbose=0)
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

# %% [markdown]
# Global variables setting

# %%
rf = (1+0.02)**(1/252) - 1
tol = 0.01
episodes = 10
days_train = 100

# %% [markdown]
# Data manipulation

# %%
data = pd.read_csv('AAPL.csv', sep=';')
data['Date'] = pd.to_datetime(data['Date'],format='%d/%m/%Y')
adj_close = data['Adj Close']
df = pd.DataFrame({'Date': data['Date'], 'log_ret': np.log(adj_close/adj_close.shift(1)).dropna()}).dropna().set_index('Date')
sp500 = pd.read_csv('sp500_joined_closes.csv', sep=',')
data.set_index('Date', inplace=True)
new_cols = list([])
for i, col in enumerate(sp500.columns):
    if col.endswith(' '):
        new_cols.append(col[:-1])
    else:
        new_cols.append(col)
sp500.columns = new_cols
sp500['Date'] = pd.to_datetime(sp500['Date'])
sp500 = sp500.set_index('Date')
sp500.drop('AAPL', axis=1, inplace=True)

# %%
sp500_lr = np.log(sp500/sp500.shift(1))
sp500_lr = sp500_lr.drop(sp500_lr.index[0])
sp500_lr = sp500_lr.drop([col for col in sp500_lr.columns if sp500_lr[col].count() < 3633], axis=1)
df = df.join(sp500_lr,how='inner').dropna()

# %% [markdown]
# Performing PCA on AAPL and SP500 stocks

# %%
cum_var_exp, PCs, regr_PCs = mylib.PCA(df['log_ret'], sp500_lr, plot=False)

# %%
regr_PCs.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   AAPL   R-squared:                       0.464
# Model:                            OLS   Adj. R-squared:                  0.463
# Method:                 Least Squares   F-statistic:                     314.1
# Date:                Sun, 07 Jul 2024   Prob (F-statistic):               0.00
# Time:                        13:16:34   Log-Likelihood:                -4020.1
# No. Observations:                3633   AIC:                             8062.
# Df Residuals:                    3622   BIC:                             8130.
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.395e-17      0.012   1.97e-15      1.000      -0.024       0.024
# PC0            0.0456      0.001     48.614      0.000       0.044       0.047
# PC1            0.0156      0.003      5.676      0.000       0.010       0.021
# PC2           -0.0751      0.003    -22.826      0.000      -0.082      -0.069
# PC3            0.0145      0.004      3.290      0.001       0.006       0.023
# PC4            0.0389      0.005      7.646      0.000       0.029       0.049
# PC5           -0.0080      0.006     -1.451      0.147      -0.019       0.003
# PC6           -0.0074      0.006     -1.266      0.206      -0.019       0.004
# PC7           -0.0679      0.006    -11.232      0.000      -0.080      -0.056
# PC8           -0.0212      0.006     -3.314      0.001      -0.034      -0.009
# PC9            0.0253      0.007      3.841      0.000       0.012       0.038
# ==============================================================================
# Omnibus:                      573.429   Durbin-Watson:                   1.928
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10155.212
# Skew:                          -0.061   Prob(JB):                         0.00
# Kurtosis:                      11.190   Cond. No.                         13.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
Y = PCs['AAPL']

# %%
[i-1 for i,p in enumerate(regr_PCs.tvalues) if abs(p) > 1.96]
# Out:
# [0, 1, 2, 3, 4, 7, 8, 9]

# %%
t_vals = regr_PCs.tvalues.drop('const')

# %%
t_vals.drop([p for p in t_vals.index if abs(t_vals[p]) == abs(t_vals).min()], inplace=True)
list(t_vals.index)
# Out:
# ['PC0', 'PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC7', 'PC8', 'PC9']

# %%
X = PCs[list(t_vals.index)]

# %%
regr_PCs = sm.OLS(Y, X).fit()
regr_PCs.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   AAPL   R-squared (uncentered):                   0.464
# Model:                            OLS   Adj. R-squared (uncentered):              0.463
# Method:                 Least Squares   F-statistic:                              348.9
# Date:                Sun, 07 Jul 2024   Prob (F-statistic):                        0.00
# Time:                        13:49:08   Log-Likelihood:                         -4020.9
# No. Observations:                3633   AIC:                                      8060.
# Df Residuals:                    3624   BIC:                                      8116.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# PC0            0.0456      0.001     48.617      0.000       0.044       0.047
# PC1            0.0156      0.003      5.677      0.000       0.010       0.021
# PC2           -0.0751      0.003    -22.828      0.000      -0.082      -0.069
# PC3            0.0145      0.004      3.290      0.001       0.006       0.023
# PC4            0.0389      0.005      7.647      0.000       0.029       0.049
# PC5           -0.0080      0.006     -1.451      0.147      -0.019       0.003
# PC7           -0.0679      0.006    -11.232      0.000      -0.080      -0.056
# PC8           -0.0212      0.006     -3.314      0.001      -0.034      -0.009
# PC9            0.0253      0.007      3.841      0.000       0.012       0.038
# ==============================================================================
# Omnibus:                      571.772   Durbin-Watson:                   1.928
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10041.479
# Skew:                          -0.066   Prob(JB):                         0.00
# Kurtosis:                      11.144   Cond. No.                         7.02
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
t_vals = regr_PCs.tvalues
t_vals.drop([p for p in t_vals.index if abs(t_vals[p]) == abs(t_vals).min()], inplace=True)
list(t_vals.index)
X = PCs[list(t_vals.index)]
X = sm.add_constant(X)
regr_PCs = sm.OLS(Y, X).fit()
regr_PCs.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   AAPL   R-squared:                       0.464
# Model:                            OLS   Adj. R-squared:                  0.463
# Method:                 Least Squares   F-statistic:                     392.0
# Date:                Sun, 07 Jul 2024   Prob (F-statistic):               0.00
# Time:                        15:28:55   Log-Likelihood:                -4021.9
# No. Observations:                3633   AIC:                             8062.
# Df Residuals:                    3624   BIC:                             8118.
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.395e-17      0.012   1.97e-15      1.000      -0.024       0.024
# PC0            0.0456      0.001     48.603      0.000       0.044       0.047
# PC1            0.0156      0.003      5.675      0.000       0.010       0.021
# PC2           -0.0751      0.003    -22.821      0.000      -0.082      -0.069
# PC3            0.0145      0.004      3.289      0.001       0.006       0.023
# PC4            0.0389      0.005      7.644      0.000       0.029       0.049
# PC7           -0.0679      0.006    -11.229      0.000      -0.080      -0.056
# PC8           -0.0212      0.006     -3.314      0.001      -0.034      -0.009
# PC9            0.0253      0.007      3.840      0.000       0.012       0.038
# ==============================================================================
# Omnibus:                      571.083   Durbin-Watson:                   1.931
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9984.148
# Skew:                          -0.070   Prob(JB):                         0.00
# Kurtosis:                      11.120   Cond. No.                         13.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
t_vals = regr_PCs.tvalues
any(abs(t_vals) < 1.96)
# Out:
# True

# %%
t_vals = regr_PCs.tvalues
t_vals.drop([p for p in t_vals.index if abs(t_vals[p]) == abs(t_vals).min()], inplace=True)
list(t_vals.index)
X = PCs[list(t_vals.index)]
regr_PCs = sm.OLS(Y, X).fit()
regr_PCs.summary()
t_vals = regr_PCs.tvalues
any(abs(t_vals) < 1.96)
# Out:
# False

# %%
regr_PCs.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   AAPL   R-squared (uncentered):                   0.464
# Model:                            OLS   Adj. R-squared (uncentered):              0.463
# Method:                 Least Squares   F-statistic:                              392.1
# Date:                Sun, 07 Jul 2024   Prob (F-statistic):                        0.00
# Time:                        15:30:54   Log-Likelihood:                         -4021.9
# No. Observations:                3633   AIC:                                      8060.
# Df Residuals:                    3625   BIC:                                      8109.
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# PC0            0.0456      0.001     48.610      0.000       0.044       0.047
# PC1            0.0156      0.003      5.676      0.000       0.010       0.021
# PC2           -0.0751      0.003    -22.824      0.000      -0.082      -0.069
# PC3            0.0145      0.004      3.290      0.001       0.006       0.023
# PC4            0.0389      0.005      7.646      0.000       0.029       0.049
# PC7           -0.0679      0.006    -11.230      0.000      -0.080      -0.056
# PC8           -0.0212      0.006     -3.314      0.001      -0.034      -0.009
# PC9            0.0253      0.007      3.840      0.000       0.012       0.038
# ==============================================================================
# Omnibus:                      571.083   Durbin-Watson:                   1.931
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9984.148
# Skew:                          -0.070   Prob(JB):                         0.00
# Kurtosis:                      11.120   Cond. No.                         7.02
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# Add the relevant PCs to the df

# %%
PCs['AAPL']
# Out:
# Date
# 2010-01-05    0.044287
# 2010-01-06   -0.960478
# 2010-01-07   -0.158106
# 2010-01-08    0.321426
# 2010-01-11   -0.554678
#                 ...
# 2024-06-05    0.387274
# 2024-06-06   -0.456310
# 2024-06-07    0.643276
# 2024-06-10   -1.147117
# 2024-06-11    1.867397
# Name: AAPL, Length: 3633, dtype: float64

# %%
dataframe = pd.DataFrame(PCs[list(t_vals.index)])
dataframe['log_ret'] = df['log_ret']
dataframe
# Out:
#                  PC0       PC1       PC2       PC3       PC4       PC7  \
# Date
# 2010-01-05  2.277725  5.598344  3.573229  1.501416 -2.727350 -0.331074
# 2010-01-06  1.487877  0.917696  1.890682 -0.739696  2.193443  2.344322
# 2010-01-07  5.457933  3.292415  3.593552  1.434769 -6.515021  2.830913
# 2010-01-08  2.347663  3.042308 -1.758965 -1.573010  3.061445  0.025891
# 2010-01-11  3.132203 -3.110919  1.425089  0.095026  0.606712  0.379562
# ...              ...       ...       ...       ...       ...       ...
# 2024-06-05  4.370851  7.734809 -5.675138  2.531673  0.669577  0.257385
# 2024-06-06 -3.327944 -0.154414 -0.253791 -1.452974  0.201252  0.250025
# 2024-06-07 -3.678136  3.166701  1.440477 -2.540191 -2.242545 -1.479271
# 2024-06-10  0.940698  1.386533 -0.699183  2.503593  3.738634  0.322610
# 2024-06-11 -5.742519 -1.431239 -3.595270 -0.203016  3.279811 -0.138426
#
#                  PC8       PC9   log_ret
# Date
# 2010-01-05 -3.486098  0.800556  0.001727
# 2010-01-06  2.210504 -0.477584 -0.016034
# 2010-01-07  1.448740 -0.823186 -0.001850
# 2010-01-08  2.377851 -1.518725  0.006626
# 2010-01-11  0.458655 -3.778597 -0.008861
# ...              ...       ...       ...
# 2024-06-05  0.070731 -0.569867  0.007790
# 2024-06-06 -2.509249  2.491141 -0.007122
# 2024-06-07  0.525229 -0.008270  0.012316
# 2024-06-10  0.032548 -1.317276 -0.019333
# 2024-06-11  1.466820  1.157794  0.033955
#
# [3633 rows x 9 columns]

# %% [markdown]
# Create the environment and agent, training

# %%
env = TradingEnv(dataframe, rf)
state_size = env.observation_space.shape[0]
action_size = len(env.action_space)
agent = DQN(state_size, action_size)

env.train(episodes, days_train)
print(f"Annualized rewards predicted: {(agent.reward_pred**(252/agent.n_exploit)-1)*100:.2f}%")
# Out:
# C:\Users\pietr\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Episode: 1/10
# log_return: -0.03836061767234994
# Current Step: 1
# Current Position:
#  Stock: 0.6499999999999999
#  R_f: 0.3500000000000001
# env.money = 0    631.802162
# 1    340.201164
# Name: 1, dtype: float64
# Portfolio Value: 972.0033261496974
# Reward: -0.027996673850302613
#
# log_return: 0.028366424369132944
# Current Step: 2
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money = 0    -841.677345
# 1    1831.885985
# Name: 2, dtype: float64
# Portfolio Value: 990.2086408005221
# Reward: 0.018729683490837038
#
# log_return: -0.006529010969374214
# Current Step: 3
# Current Position:
#  Stock: 0.6499999999999999
#  R_f: 0.3500000000000001
# env.money = 0    647.289513
# 1    348.540507
# Name: 3, dtype: float64
# Portfolio Value: 995.8300195449775
# Reward: 0.0056769639375302975
#
# log_return: 0.0063387150489206835
# Current Step: 4
# Current Position:
#  Stock: 1.1
#  R_f: -0.10000000000000009
# env.money = 0    1099.970767
# 1     -99.997342
# Name: 4, dtype: float64
# Portfolio Value: 999.9734246976118
# Reward: 0.0041607554214197215
#
# log_return: -0.01532027177293153
# Current Step: 5
# Current Position:
#  Stock: -0.7
#  R_f: 1.7
# env.money = 0    -688.269502
# 1    1671.511648
# Name: 5, dtype: float64
# Portfolio Value: 983.242146085063
# Reward: -0.016731723263153944
#
# log_return: 0.007391939475152343
# Current Step: 6
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money = 0    -391.306802
# 1    1369.573807
# Name: 6, dtype: float64
# Portfolio Value: 978.2670050222665
# Reward: -0.00505993470947706
#
# log_return: -0.0028662148568147695
# Current Step: 7
# Current Position:
#  Stock: 0.5
#  R_f: 0.5
# env.money = 0    489.747298
# 1    489.747298
# Name: 7, dtype: float64
# Portfolio Value: 979.4945964750823
# Reward: 0.0012548633926254432
#
# log_return: 0.0
# Current Step: 8
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0    -979.533083
# 1    1959.066166
# Name: 8, dtype: float64
# Portfolio Value: 979.5330832381014
# Reward: 3.929247099232532e-05
#
# log_return: -0.00889376706982492
# Current Step: 9
# Current Position:
#  Stock: 0.95
#  R_f: 0.050000000000000044
# env.money = 0    938.942142
# 1     49.418007
# Name: 9, dtype: float64
# Portfolio Value: 988.3601499231096
# Reward: 0.009011504395367635
#
# log_return: 0.020054720284118116
# Current Step: 10
# Current Position:
#  Stock: 1.6999999999999997
#  R_f: -0.6999999999999997
# env.money = 0    1712.553380
# 1    -705.169039
# Name: 10, dtype: float64
# Portfolio Value: 1007.3843414622507
# Reward: 0.01924823814539787
#
# log_return: 0.002169146824500193
# Current Step: 11
# Current Position:
#  Stock: 0.19999999999999996
#  R_f: 0.8
# env.money = 0    202.209547
# 1    808.838190
# Name: 11, dtype: float64
# Portfolio Value: 1011.0477373873314
# Reward: 0.0036365424538593667
#
# log_return: -0.0029144155874461022
# Current Step: 12
# Current Position:
#  Stock: -0.7
#  R_f: 1.7
# env.money = 0    -707.365985
# 1    1717.888820
# Name: 12, dtype: float64
# Portfolio Value: 1010.5228351643716
# Reward: -0.000519166606629467
#
# log_return: -0.009109376183201923
# Current Step: 13
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money = 0    355.975283
# 1    661.096955
# Name: 13, dtype: float64
# Portfolio Value: 1017.0722382502727
# Reward: 0.006481202460739792
#
# log_return: -0.010441299845356288
# Current Step: 14
# Current Position:
#  Stock: -0.7
#  R_f: 1.7
# env.money = 0    -709.398678
# 1    1722.825361
# Name: 14, dtype: float64
# Portfolio Value: 1013.4266828299722
# Reward: -0.0035843623325833586
#
# log_return: -0.01260091641427972
# Current Step: 15
# Current Position:
#  Stock: 1.85
#  R_f: -0.8500000000000001
# env.money = 0    1891.523361
# 1    -869.078301
# Name: 15, dtype: float64
# Portfolio Value: 1022.4450599669245
# Reward: 0.008898894502924234
#
# log_return: -0.013288719111735531
# Current Step: 16
# Current Position:
#  Stock: 0.95
#  R_f: 0.050000000000000044
# env.money = 0    947.536760
# 1     49.870356
# Name: 16, dtype: float64
# Portfolio Value: 997.4071156289044
# Reward: -0.02448830291070121
#
# log_return: 0.014414016816846297
# Current Step: 17
# Current Position:
#  Stock: 1.25
#  R_f: -0.25
# env.money = 0    1263.959690
# 1    -252.791938
# Name: 17, dtype: float64
# Portfolio Value: 1011.1677520785905
# Reward: 0.013796408942811162
#
# log_return: 0.021637481448484864
# Current Step: 18
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money = 0    -882.975595
# 1    1921.770412
# Name: 18, dtype: float64
# Portfolio Value: 1038.794817121847
# Reward: 0.02732194038671167
#
# log_return: 0.026401327604391456
# Current Step: 19
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money = 0    -558.428010
# 1    1573.751665
# Name: 19, dtype: float64
# Portfolio Value: 1015.323654984255
# Reward: -0.022594608435400926
#
# log_return: 0.004979987458292729
# Current Step: 20
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money = 0    -556.962685
# 1    1569.622113
# Name: 20, dtype: float64
# Portfolio Value: 1012.6594275869633
# Reward: -0.002624017853039213
#
# log_return: 0.017387416580334332
# Current Step: 21
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0   -1003.013953
# 1    2006.027906
# Name: 21, dtype: float64
# Portfolio Value: 1003.0139528315159
# Reward: -0.009524895036459877
#
# log_return: 0.0036413994050841325
# Current Step: 22
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0    -999.512564
# 1    1999.025128
# Name: 22, dtype: float64
# Portfolio Value: 999.5125640509934
# Reward: -0.0034908674706249244
#
# log_return: -0.0010380745422699776
# Current Step: 23
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money = 0    -250.176672
# 1    1250.883359
# Name: 23, dtype: float64
# Portfolio Value: 1000.7066875216827
# Reward: 0.0011947058132511714
#
# log_return: 0.01541750157357808
# Current Step: 24
# Current Position:
#  Stock: 1.4
#  R_f: -0.3999999999999999
# env.money = 0    1395.685203
# 1    -398.767201
# Name: 24, dtype: float64
# Portfolio Value: 996.9180020729913
# Reward: -0.0037860099227221126
#
# log_return: 0.00570917118131804
# Current Step: 25
# Current Position:
#  Stock: 0.95
#  R_f: 0.050000000000000044
# env.money = 0    954.633777
# 1     50.243883
# Name: 25, dtype: float64
# Portfolio Value: 1004.8776599881819
# Reward: 0.007984265404616348
#
# log_return: -0.003405144815626357
# Current Step: 26
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money = 0    -400.654588
# 1    1402.291059
# Name: 26, dtype: float64
# Portfolio Value: 1001.6364703623783
# Reward: -0.0032254569435265566
#
# log_return: 0.009458218651404537
# Current Step: 27
# Current Position:
#  Stock: 0.050000000000000044
#  R_f: 0.95
# env.money = 0     49.896961
# 1    948.042252
# Name: 27, dtype: float64
# Portfolio Value: 997.9392131327901
# Reward: -0.003691216662918235
#
# log_return: 0.013010111143267696
# Current Step: 28
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money = 0    349.533492
# 1    649.133629
# Name: 28, dtype: float64
# Portfolio Value: 998.6671212094675
# Reward: 0.0007294112377770149
#
# log_return: -0.007523099248485933
# Current Step: 29
# Current Position:
#  Stock: 0.5
#  R_f: 0.5
# env.money = 0    498.049212
# 1    498.049212
# Name: 29, dtype: float64
# Portfolio Value: 996.0984247035158
# Reward: -0.0025721248365930174
#
# log_return: 0.0024391791560509587
# Current Step: 30
# Current Position:
#  Stock: 0.95
#  R_f: 0.050000000000000044
# env.money = 0    947.486184
# 1     49.867694
# Name: 30, dtype: float64
# Portfolio Value: 997.3538779303312
# Reward: 0.0012603706578384979
#
# log_return: 0.0028712245749026193
# Current Step: 31
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money = 0    -550.045183
# 1    1550.127335
# Name: 31, dtype: float64
# Portfolio Value: 1000.0821516418407
# Reward: 0.0027355122107421666
#
# log_return: 0.002894385782053295
# Current Step: 32
# Current Position:
#  Stock: 0.5
#  R_f: 0.5
# env.money = 0    499.30481
# 1    499.30481
# Name: 32, dtype: float64
# Portfolio Value: 998.6096191324629
# Reward: -0.0014724115483516942
#
# log_return: -0.0016844078313229787
# Current Step: 33
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money = 0    349.232986
# 1    648.575546
# Name: 33, dtype: float64
# Portfolio Value: 997.8085319641996
# Reward: -0.0008022025353202788
#
# log_return: 0.007912716619707699
# Current Step: 34
# Current Position:
#  Stock: 1.25
#  R_f: -0.25
# env.money = 0    1250.792305
# 1    -250.158461
# Name: 34, dtype: float64
# Portfolio Value: 1000.6338437112836
# Reward: 0.002831516925919997
#
# log_return: 0.013822438323408941
# Current Step: 35
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money = 0    356.308129
# 1    661.715096
# Name: 35, dtype: float64
# Portfolio Value: 1018.0232250204689
# Reward: 0.01737836614109438
#
# log_return: 0.013737781270436043
# Current Step: 36
# Current Position:
#  Stock: 0.050000000000000044
#  R_f: 0.95
# env.money = 0     51.150194
# 1    971.853692
# Name: 36, dtype: float64
# Portfolio Value: 1023.0038859136553
# Reward: 0.004892482578760655
#
# log_return: 0.012156434819224219
# Current Step: 37
# Current Position:
#  Stock: 1.85
#  R_f: -0.8500000000000001
# env.money = 0    1893.855837
# 1    -870.149979
# Name: 37, dtype: float64
# Portfolio Value: 1023.7058578040673
# Reward: 0.000686186924681175
#
# log_return: -0.0016445482585966415
# Current Step: 38
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money = 0    -561.289025
# 1    1581.814524
# Name: 38, dtype: float64
# Portfolio Value: 1020.5254993999113
# Reward: -0.0031067111513634494
#
# log_return: 0.012886363738267315
# Current Step: 39
# Current Position:
#  Stock: 0.6499999999999999
#  R_f: 0.3500000000000001
# env.money = 0    658.690518
# 1    354.679510
# Name: 39, dtype: float64
# Portfolio Value: 1013.3700274687097
# Reward: -0.007011556237849116
#
# log_return: -0.006834222159106465
# Current Step: 40
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money = 0    -857.574869
# 1    1866.486479
# Name: 40, dtype: float64
# Portfolio Value: 1008.9116102161879
# Reward: -0.004399594552503667
#
# log_return: 0.014418924658032807
# Current Step: 41
# Current Position:
#  Stock: 0.95
#  R_f: 0.050000000000000044
# env.money = 0    946.773233
# 1     49.830170
# Name: 41, dtype: float64
# Portfolio Value: 996.6034032916544
# Reward: -0.012199489826364554
#
# log_return: 0.0013939091355512855
# Current Step: 42
# Current Position:
#  Stock: -0.7
#  R_f: 1.7
# env.money = 0    -698.549569
# 1    1696.477524
# Name: 42, dtype: float64
# Portfolio Value: 997.9279552611463
# Reward: 0.001329066271615177
#
# log_return: 0.01860826871993856
# Current Step: 43
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money = 0    -246.235195
# 1    1231.175973
# Name: 43, dtype: float64
# Portfolio Value: 984.9407785166193
# Reward: -0.0130141426302948
#
# log_return: -0.008655991614136153
# Current Step: 44
# Current Position:
#  Stock: 1.1
#  R_f: -0.10000000000000009
# env.money = 0    1085.875716
# 1     -98.715974
# Name: 44, dtype: float64
# Portfolio Value: 987.1597420151713
# Reward: 0.002252890272137936
#
# log_return: 0.011715549208115034
# Current Step: 45
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money = 0    -249.987107
# 1    1249.935534
# Name: 45, dtype: float64
# Portfolio Value: 999.948427127032
# Reward: 0.012955031052779833
#
# log_return: -0.0005932147438115586
# Current Step: 46
# Current Position:
#  Stock: 1.25
#  R_f: -0.25
# env.money = 0    1250.243632
# 1    -250.048726
# Name: 46, dtype: float64
# Portfolio Value: 1000.1949052989529
# Reward: 0.00024649088416395535
#
# log_return: -0.032743798228986445
# Current Step: 47
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money = 0    335.965176
# 1    623.935327
# Name: 47, dtype: float64
# Portfolio Value: 959.9005025494192
# Reward: -0.04028655068732818
#
# log_return: -0.003893906075566558
# Current Step: 48
# Current Position:
#  Stock: 1.4
#  R_f: -0.3999999999999999
# env.money = 0    1342.101406
# 1    -383.457545
# Name: 48, dtype: float64
# Portfolio Value: 958.6438613652726
# Reward: -0.0013091369165960942
#
# log_return: 0.011436495196495852
# Current Step: 49
# Current Position:
#  Stock: 0.95
#  R_f: 0.050000000000000044
# env.money = 0    925.348230
# 1     48.702538
# Name: 49, dtype: float64
# Portfolio Value: 974.0507682251373
# Reward: 0.016071564718437334
#
# log_return: -0.0038540133543010758
# Current Step: 50
# Current Position:
#  Stock: -0.7
#  R_f: 1.7
# env.money = 0    -679.346608
# 1    1649.841763
# Name: 50, dtype: float64
# Portfolio Value: 970.4951545485347
# Reward: -0.0036503371206014186
#
# log_return: -0.004313569837855601
# Current Step: 51
# Current Position:
#  Stock: 1.6999999999999997
#  R_f: -0.6999999999999997
# env.money = 0    1655.033139
# 1    -681.484234
# Name: 51, dtype: float64
# Portfolio Value: 973.5489051220734
# Reward: 0.0031465902320339007
#
# log_return: -0.022576452132317425
# Current Step: 52
# Current Position:
#  Stock: 1.85
#  R_f: -0.8500000000000001
# env.money = 0    1732.61602
# 1    -796.06682
# Name: 52, dtype: float64
# Portfolio Value: 936.5492000534093
# Reward: -0.03800497835701913
#
# log_return: 0.014993957500193913
# Current Step: 53
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money = 0    336.931403
# 1    625.729748
# Name: 53, dtype: float64
# Portfolio Value: 962.6611515309758
# Reward: 0.02788102480475914
#
# log_return: -0.019426158851525942
# Current Step: 54
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money = 0    -382.491283
# 1    1338.719489
# Name: 54, dtype: float64
# Portfolio Value: 956.2282066825721
# Reward: -0.0066824602178793
#
# log_return: -0.0029630523240557227
# Current Step: 55
# Current Position:
#  Stock: -0.7
#  R_f: 1.7
# env.money = 0    -670.225552
# 1    1627.690626
# Name: 55, dtype: float64
# Portfolio Value: 957.465074141845
# Reward: 0.0012934856456116152
#
# log_return: -0.01680896549069576
# Current Step: 56
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money = 0    -532.820546
# 1    1501.585176
# Name: 56, dtype: float64
# Portfolio Value: 968.7646293688259
# Reward: 0.011801532538519472
#
# log_return: -0.013877959029079514
# Current Step: 57
# Current Position:
#  Stock: 1.1
#  R_f: -0.10000000000000009
# env.money = 0    1073.848622
# 1     -97.622602
# Name: 57, dtype: float64
# Portfolio Value: 976.2260195819765
# Reward: 0.0077019639104824395
#
# log_return: -0.013644161580393522
# Current Step: 58
# Current Position:
#  Stock: 1.5499999999999998
#  R_f: -0.5499999999999998
# env.money = 0    1490.582434
# 1    -528.916347
# Name: 58, dtype: float64
# Portfolio Value: 961.6660862720986
# Reward: -0.014914510592652032
#
# log_return: 0.025014936832946557
# Current Step: 59
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money = 0    -399.752650
# 1    1399.134273
# Name: 59, dtype: float64
# Portfolio Value: 999.3816237547259
# Reward: 0.0392189534611038
#
# log_return: 0.02849953974819344
# Current Step: 60
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money = 0    -839.744674
# 1    1827.679584
# Name: 60, dtype: float64
# Portfolio Value: 987.9349105180872
# Reward: -0.011453795991998297
#
# log_return: -0.007794014066524264
# Current Step: 61
# Current Position:
#  Stock: 0.7999999999999998
#  R_f: 0.20000000000000018
# env.money = 0    795.678465
# 1    198.919616
# Name: 61, dtype: float64
# Portfolio Value: 994.5980807084445
# Reward: 0.006744543713778689
#
# log_return: 0.010379680275010572
# Current Step: 62
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money = 0    -401.166245
# 1    1404.081857
# Name: 62, dtype: float64
# Portfolio Value: 1002.9156118522628
# Reward: 0.0083627058056394
#
# log_return: -0.0036228613712059577
# Current Step: 63
# Current Position:
#  Stock: 1.6999999999999997
#  R_f: -0.6999999999999997
# env.money = 0    1707.610376
# 1    -703.133684
# Name: 63, dtype: float64
# Portfolio Value: 1004.4766917329505
# Reward: 0.0015565416095223935
#
# log_return: -0.0047826788702856424
# Current Step: 64
# Current Position:
#  Stock: 0.7999999999999998
#  R_f: 0.20000000000000018
# env.money = 0    797.019186
# 1    199.254797
# Name: 64, dtype: float64
# Portfolio Value: 996.2739828060115
# Reward: -0.008166151583654387
#
# log_return: 0.01760011946035004
# Current Step: 65
# Current Position:
#  Stock: 1.1
#  R_f: -0.10000000000000009
# env.money = 0    1111.485590
# 1    -101.044145
# Name: 65, dtype: float64
# Portfolio Value: 1010.4414455375975
# Reward: 0.014220448366706516
#
# log_return: -0.0007016119115106755
# Current Step: 66
# Current Position:
#  Stock: 1.5499999999999998
#  R_f: -0.5499999999999998
# env.money = 0    1564.963618
# 1    -555.309671
# Name: 66, dtype: float64
# Portfolio Value: 1009.6539469654557
# Reward: -0.0007793609175668651
#
# log_return: -0.012013066092484984
# Current Step: 67
# Current Position:
#  Stock: 0.6499999999999999
#  R_f: 0.3500000000000001
# env.money = 0    644.099800
# 1    346.822969
# Name: 67, dtype: float64
# Portfolio Value: 990.9227686752404
# Reward: -0.01855207751775985
#
# log_return: -0.019236995755025747
# Current Step: 68
# Current Position:
#  Stock: -0.7
#  R_f: 1.7
# env.money = 0    -685.074528
# 1    1663.752424
# Name: 68, dtype: float64
# Portfolio Value: 978.6778965080568
# Reward: -0.012357039876633008
#
# log_return: -0.009676270786509043
# Current Step: 69
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money = 0    -837.594794
# 1    1823.000435
# Name: 69, dtype: float64
# Portfolio Value: 985.4056403907427
# Reward: 0.006874318820002608
#
# log_return: -0.02901811606048804
# Current Step: 70
# Current Position:
#  Stock: -0.10000000000000009
#  R_f: 1.1
# env.money = 0    -100.950506
# 1    1110.455568
# Name: 70, dtype: float64
# Portfolio Value: 1009.505061400742
# Reward: 0.024456345714078804
#
# log_return: 9.367547327236937e-05
# Current Step: 71
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money = 0    -858.145439
# 1    1867.728308
# Name: 71, dtype: float64
# Portfolio Value: 1009.5828694577149
# Reward: 7.70754500873427e-05
#
# log_return: 0.013619748176862444
# Current Step: 72
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money = 0    349.286688
# 1    648.675278
# Name: 72, dtype: float64
# Portfolio Value: 997.9619654911207
# Reward: -0.011510599395209795
#
# log_return: 0.03850478164726159
# Current Step: 73
# Current Position:
#  Stock: 0.6499999999999999
#  R_f: 0.3500000000000001
# env.money = 0    657.620882
# 1    354.103552
# Name: 73, dtype: float64
# Portfolio Value: 1011.7244342319636
# Reward: 0.013790574407382418
#
# log_return: 0.001045928284697696
# Current Step: 74
# Current Position:
#  Stock: -0.7
#  R_f: 1.7
# env.money = 0    -708.708312
# 1    1721.148757
# Name: 74, dtype: float64
# Portfolio Value: 1012.4404455532841
# Reward: 0.0007077137776790272
#
# log_return: -0.02496650236149537
# Current Step: 75
# Current Position:
#  Stock: 1.5499999999999998
#  R_f: -0.5499999999999998
# env.money = 0    1596.578458
# 1    -566.527840
# Name: 75, dtype: float64
# Portfolio Value: 1030.0506181966846
# Reward: 0.01739378619329728
#
# log_return: 0.008646621236039298
# Current Step: 76
# Current Position:
#  Stock: 0.6499999999999999
#  R_f: 0.3500000000000001
# env.money = 0    678.516126
# 1    365.354837
# Name: 76, dtype: float64
# Portfolio Value: 1043.8709625760703
# Reward: 0.013417150706225527
#
# log_return: -0.0038960853667429733
# Current Step: 77
# Current Position:
#  Stock: 0.19999999999999996
#  R_f: 0.8
# env.money = 0    208.252252
# 1    833.009008
# Name: 77, dtype: float64
# Portfolio Value: 1041.2612602963136
# Reward: -0.002500023827960918
#
# log_return: -0.027079331184725164
# Current Step: 78
# Current Position:
#  Stock: 0.6499999999999999
#  R_f: 0.3500000000000001
# env.money = 0    673.245989
# 1    362.517071
# Name: 78, dtype: float64
# Portfolio Value: 1035.7630606524474
# Reward: -0.0052803267090735405
#
# log_return: -0.007803513214615084
# Current Step: 79
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0   -1030.558310
# 1    2061.116621
# Name: 79, dtype: float64
# Portfolio Value: 1030.5583104399675
# Reward: -0.005025039422820621
#
# log_return: 0.025785046057485148
# Current Step: 80
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0   -1003.801733
# 1    2007.603466
# Name: 80, dtype: float64
# Portfolio Value: 1003.801733068372
# Reward: -0.025963186265678243
#
# log_return: 0.007694250611469934
# Current Step: 81
# Current Position:
#  Stock: 1.85
#  R_f: -0.8500000000000001
# env.money = 0    1842.981486
# 1    -846.775277
# Name: 81, dtype: float64
# Portfolio Value: 996.2062087375017
# Reward: -0.007566757538515734
#
# log_return: 0.025643869428062488
# Current Step: 82
# Current Position:
#  Stock: 0.95
#  R_f: 0.050000000000000044
# env.money = 0    991.811433
# 1     52.200602
# Name: 82, dtype: float64
# Portfolio Value: 1044.012034529147
# Reward: 0.04798788179831762
#
# log_return: 0.005218021609446616
# Current Step: 83
# Current Position:
#  Stock: -0.7
#  R_f: 1.7
# env.money = 0    -734.443469
# 1    1783.648425
# Name: 83, dtype: float64
# Portfolio Value: 1049.2049561118306
# Reward: 0.004974005481675855
#
# log_return: 0.0010714243827454142
# Current Step: 84
# Current Position:
#  Stock: 0.7999999999999998
#  R_f: 0.20000000000000018
# env.money = 0    838.846241
# 1    209.711560
# Name: 84, dtype: float64
# Portfolio Value: 1048.557801676267
# Reward: -0.0006168045926525621
#
# log_return: -0.035351867241618526
# Current Step: 85
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money = 0    -254.859389
# 1    1274.296943
# Name: 85, dtype: float64
# Portfolio Value: 1019.4375541679838
# Reward: -0.02777171412174934
#
# log_return: 0.054608794407343314
# Current Step: 86
# Current Position:
#  Stock: 1.4
#  R_f: -0.3999999999999999
# env.money = 0    1407.326350
# 1    -402.093243
# Name: 86, dtype: float64
# Portfolio Value: 1005.2331072874133
# Reward: -0.01393361155128668
#
# log_return: 0.030803988864738084
# Current Step: 87
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0   -1049.227379
# 1    2098.454758
# Name: 87, dtype: float64
# Portfolio Value: 1049.2273790032023
# Reward: 0.04376524350108799
#
# log_return: -0.014845970827138347
# Current Step: 88
# Current Position:
#  Stock: 1.85
#  R_f: -0.8500000000000001
# env.money = 0    1969.979953
# 1    -905.125924
# Name: 88, dtype: float64
# Portfolio Value: 1064.854028733866
# Reward: 0.014893482617189752
#
# log_return: 0.012491423553807857
# Current Step: 89
# Current Position:
#  Stock: 1.6999999999999997
#  R_f: -0.6999999999999997
# env.money = 0    1852.226651
# 1    -762.681562
# Name: 89, dtype: float64
# Portfolio Value: 1089.5450889704052
# Reward: 0.02318727221786202
#
# log_return: 0.00017045083640709714
# Current Step: 90
# Current Position:
#  Stock: 0.5
#  R_f: 0.5
# env.money = 0    544.900447
# 1    544.900447
# Name: 90, dtype: float64
# Portfolio Value: 1089.8008941743524
# Reward: 0.0002347816593702218
#
# log_return: 0.007559060907832692
# Current Step: 91
# Current Position:
#  Stock: 0.050000000000000044
#  R_f: 0.95
# env.money = 0      54.698913
# 1    1039.279345
# Name: 91, dtype: float64
# Portfolio Value: 1093.9782577552332
# Reward: 0.003833143836834242
#
# log_return: 0.007214076273777862
# Current Step: 92
# Current Position:
#  Stock: 1.85
#  R_f: -0.8500000000000001
# env.money = 0    2024.743523
# 1    -930.287565
# Name: 92, dtype: float64
# Portfolio Value: 1094.4559583657392
# Reward: 0.00043666371531566895
#
# log_return: -0.008498158896889886
# Current Step: 93
# Current Position:
#  Stock: -0.10000000000000009
#  R_f: 1.1
# env.money = 0    -107.724917
# 1    1184.974082
# Name: 93, dtype: float64
# Portfolio Value: 1077.249165097926
# Reward: -0.015721777688986926
#
# log_return: 0.00651039893563206
# Current Step: 94
# Current Position:
#  Stock: 1.6999999999999997
#  R_f: -0.6999999999999997
# env.money = 0    1830.285732
# 1    -753.647066
# Name: 94, dtype: float64
# Portfolio Value: 1076.638666097015
# Reward: -0.0005667203286766812
#
# log_return: 0.018707029025423306
# Current Step: 95
# Current Position:
#  Stock: 1.4
#  R_f: -0.3999999999999999
# env.money = 0    1555.597277
# 1    -444.456365
# Name: 95, dtype: float64
# Portfolio Value: 1111.140912431328
# Reward: 0.03204626345010353
#
# log_return: 0.023222716126539755
# Current Step: 96
# Current Position:
#  Stock: 1.4
#  R_f: -0.3999999999999999
# env.money = 0    1606.715470
# 1    -459.061563
# Name: 96, dtype: float64
# Portfolio Value: 1147.653907355506
# Reward: 0.03286081406568188
#
# log_return: 0.012680398854351169
# Current Step: 97
# Current Position:
#  Stock: 0.95
#  R_f: 0.050000000000000044
# env.money = 0    1109.715279
# 1      58.406067
# Name: 97, dtype: float64
# Portfolio Value: 1168.1213466762952
# Reward: 0.017834156438286848
#
# log_return: 0.004881115624896885
# Current Step: 98
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money = 0    410.744539
# 1    762.811287
# Name: 98, dtype: float64
# Portfolio Value: 1173.5558262820678
# Reward: 0.004652324539086241
#
# log_return: 0.005871329782562539
# Current Step: 99
# Current Position:
#  Stock: 0.5
#  R_f: 0.5
# env.money = 0    588.017241
# 1    588.017241
# Name: 99, dtype: float64
# Portfolio Value: 1176.0344819832594
# Reward: 0.0021120901500223162
#
# Episode: 1/10, Score: 98, Epsilon: 1.0
#
#
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Episode: 2/10
# log_return: -0.007868218887860889
# Current Step: 1
# Current Position:
#  Stock: 1.1
#  R_f: -0.10000000000000009
# env.money = 0    1069.203659
# 1     -97.200333
# Name: 1, dtype: float64
# Portfolio Value: 972.0033261496974
# Reward: -0.027996673850302613
#
# log_return: -0.025067361319301075
# Current Step: 2
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money = 0    -247.552160
# 1    1237.760801
# Name: 2, dtype: float64
# Portfolio Value: 990.2086408005221
# Reward: 0.018729683490837038
#
# log_return: -0.014098278825808911
# Current Step: 3
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money = 0    -547.706511
# 1    1543.536530
# Name: 3, dtype: float64
# Portfolio Value: 995.8300195449775
# Reward: 0.0056769639375302975
#
# log_return: 0.01221202128168356
# Current Step: 4
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0    -999.973425
# 1    1999.946849
# Name: 4, dtype: float64
# Portfolio Value: 999.9734246976118
# Reward: 0.0041607554214197215
#
# log_return: -0.0034600224579028056
# Current Step: 5
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money = 0    -245.810537
# 1    1229.052683
# Name: 5, dtype: float64
# Portfolio Value: 983.242146085063
# Reward: -0.016731723263153944
#
# log_return: 0.016088729902466185
# Current Step: 6
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money = 0    -244.566751
# 1    1222.833756
# Name: 6, dtype: float64
# Portfolio Value: 978.2670050222665
# Reward: -0.00505993470947706
#
# log_return: 0.0066257556411595695
# Current Step: 7
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money = 0    -391.797839
# 1    1371.292435
# Name: 7, dtype: float64
# Portfolio Value: 979.4945964750823
# Reward: 0.0012548633926254432
#
# log_return: -0.015688157180286676
# Current Step: 8
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0    -979.533083
# 1    1959.066166
# Name: 8, dtype: float64
# Portfolio Value: 979.5330832381014
# Reward: 3.929247099232532e-05
#
# log_return: -0.04787081814145672
# Current Step: 9
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money = 0    345.926052
# 1    642.434097
# Name: 9, dtype: float64
# Portfolio Value: 988.3601499231096
# Reward: 0.009011504395367635
#
# log_return: -0.014942193073964577
# Current Step: 10
# Current Position:
#  Stock: 0.95
#  R_f: 0.050000000000000044
# env.money = 0    957.015124
# 1     50.369217
# Name: 10, dtype: float64
# Portfolio Value: 1007.3843414622507
# Reward: 0.01924823814539787
#
# log_return: -0.016254972906892824
# Current Step: 11
# Current Position:
#  Stock: 1.4
#  R_f: -0.3999999999999999
# env.money = 0    1415.466832
# 1    -404.419095
# Name: 11, dtype: float64
# Portfolio Value: 1011.0477373873314
# Reward: 0.0036365424538593667
#
# log_return: -0.0005289724276862485
# Current Step: 12
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money = 0    353.682992
# 1    656.839843
# Name: 12, dtype: float64
# Portfolio Value: 1010.5228351643716
# Reward: -0.000519166606629467
#
# log_return: 0.023646905282323858
# Current Step: 13
# Current Position:
#  Stock: 1.25
#  R_f: -0.25
# env.money = 0    1271.340298
# 1    -254.268060
# Name: 13, dtype: float64
# Portfolio Value: 1017.0722382502727
# Reward: 0.006481202460739792
#
# log_return: -0.023561137016210626
# Current Step: 14
# Current Position:
#  Stock: 0.5
#  R_f: 0.5
# env.money = 0    506.713341
# 1    506.713341
# Name: 14, dtype: float64
# Portfolio Value: 1013.4266828299722
# Reward: -0.0035843623325833586
#
# log_return: -0.002754948134684364
# Current Step: 15
# Current Position:
#  Stock: 0.5
#  R_f: 0.5
# env.money = 0    511.22253
# 1    511.22253
# Name: 15, dtype: float64
# Portfolio Value: 1022.4450599669245
# Reward: 0.008898894502924234
#
# log_return: -0.014038836160975569
# Current Step: 16
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0    -997.407116
# 1    1994.814231
# Name: 16, dtype: float64
# Portfolio Value: 997.4071156289044
# Reward: -0.02448830291070121
#
# log_return: -0.030726261370616903
# Current Step: 17
# Current Position:
#  Stock: 1.25
#  R_f: -0.25
# env.money = 0    1263.959690
# 1    -252.791938
# Name: 17, dtype: float64
# Portfolio Value: 1011.1677520785905
# Reward: 0.013796408942811162
#
# log_return: 0.02756681544107348
# Current Step: 18
# Current Position:
#  Stock: 0.6499999999999999
#  R_f: 0.3500000000000001
# env.money = 0    675.216631
# 1    363.578186
# Name: 18, dtype: float64
# Portfolio Value: 1038.794817121847
# Reward: 0.02732194038671167
#
# log_return: 0.0025053597772654286
# Current Step: 19
# Current Position:
#  Stock: 0.19999999999999996
#  R_f: 0.8
# env.money = 0    203.064731
# 1    812.258924
# Name: 19, dtype: float64
# Portfolio Value: 1015.323654984255
# Reward: -0.022594608435400926
#
# log_return: -0.03870509902160334
# Current Step: 20
# Current Position:
#  Stock: 0.050000000000000044
#  R_f: 0.95
# env.money = 0     50.632971
# 1    962.026456
# Name: 20, dtype: float64
# Portfolio Value: 1012.6594275869633
# Reward: -0.002624017853039213
#
# log_return: 0.01030375668678656
# Current Step: 21
# Current Position:
#  Stock: 1.6999999999999997
#  R_f: -0.6999999999999997
# env.money = 0    1705.123720
# 1    -702.109767
# Name: 21, dtype: float64
# Portfolio Value: 1003.0139528315159
# Reward: -0.009524895036459877
#
# log_return: -0.010762404706373756
# Current Step: 22
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0    -999.512564
# 1    1999.025128
# Name: 22, dtype: float64
# Portfolio Value: 999.5125640509934
# Reward: -0.0034908674706249244
#
# log_return: 0.03643552711858911
# Current Step: 23
# Current Position:
#  Stock: 0.19999999999999996
#  R_f: 0.8
# env.money = 0    200.141338
# 1    800.565350
# Name: 23, dtype: float64
# Portfolio Value: 1000.7066875216827
# Reward: 0.0011947058132511714
#
# log_return: 0.004176355114283441
# Current Step: 24
# Current Position:
#  Stock: 1.4
#  R_f: -0.3999999999999999
# env.money = 0    1395.685203
# 1    -398.767201
# Name: 24, dtype: float64
# Portfolio Value: 996.9180020729913
# Reward: -0.0037860099227221126
#
# log_return: 0.0045041011495181695
# Current Step: 25
# Current Position:
#  Stock: 0.5
#  R_f: 0.5
# env.money = 0    502.43883
# 1    502.43883
# Name: 25, dtype: float64
# Portfolio Value: 1004.8776599881819
# Reward: 0.007984265404616348
#
# log_return: 0.021034396796332813
# Current Step: 26
# Current Position:
#  Stock: 0.95
#  R_f: 0.050000000000000044
# env.money = 0    951.554647
# 1     50.081824
# Name: 26, dtype: float64
# Portfolio Value: 1001.6364703623783
# Reward: -0.0032254569435265566
#
# log_return: -0.0006013203800888257
# Current Step: 27
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money = 0    -848.248331
# 1    1846.187544
# Name: 27, dtype: float64
# Portfolio Value: 997.9392131327901
# Reward: -0.003691216662918235
#
# log_return: 0.010141458426798594
# Current Step: 28
# Current Position:
#  Stock: 1.85
#  R_f: -0.8500000000000001
# env.money = 0    1847.534174
# 1    -848.867053
# Name: 28, dtype: float64
# Portfolio Value: 998.6671212094675
# Reward: 0.0007294112377770149
#
# log_return: 0.00872510033970454
# Current Step: 29
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money = 0    -249.024606
# 1    1245.123031
# Name: 29, dtype: float64
# Portfolio Value: 996.0984247035158
# Reward: -0.0025721248365930174
#
# log_return: -0.005322900491587294
# Current Step: 30
# Current Position:
#  Stock: 1.25
#  R_f: -0.25
# env.money = 0    1246.692347
# 1    -249.338469
# Name: 30, dtype: float64
# Portfolio Value: 997.3538779303312
# Reward: 0.0012603706578384979
#
# log_return: 0.000434717377100104
# Current Step: 31
# Current Position:
#  Stock: 0.95
#  R_f: 0.050000000000000044
# env.money = 0    950.078044
# 1     50.004108
# Name: 31, dtype: float64
# Portfolio Value: 1000.0821516418407
# Reward: 0.0027355122107421666
#
# log_return: 0.019289588791415818
# Current Step: 32
# Current Position:
#  Stock: 0.7999999999999998
#  R_f: 0.20000000000000018
# env.money = 0    798.887695
# 1    199.721924
# Name: 32, dtype: float64
# Portfolio Value: 998.6096191324629
# Reward: -0.0014724115483516942
#
# log_return: 0.023435059060854968
# Current Step: 33
# Current Position:
#  Stock: 0.050000000000000044
#  R_f: 0.95
# env.money = 0     49.890427
# 1    947.918105
# Name: 33, dtype: float64
# Portfolio Value: 997.8085319641996
# Reward: -0.0008022025353202788
#
# log_return: 0.009844090897504236
# Current Step: 34
# Current Position:
#  Stock: -0.7
#  R_f: 1.7
# env.money = 0    -700.443691
# 1    1701.077534
# Name: 34, dtype: float64
# Portfolio Value: 1000.6338437112836
# Reward: 0.002831516925919997
#
# log_return: -0.004829075202872907
# Current Step: 35
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money = 0    -407.209290
# 1    1425.232515
# Name: 35, dtype: float64
# Portfolio Value: 1018.0232250204689
# Reward: 0.01737836614109438
#
# log_return: 0.015028026959871852
# Current Step: 36
# Current Position:
#  Stock: 0.7999999999999998
#  R_f: 0.20000000000000018
# env.money = 0    818.403109
# 1    204.600777
# Name: 36, dtype: float64
# Portfolio Value: 1023.0038859136553
# Reward: 0.004892482578760655
#
# log_return: 0.01377467883902351
# Current Step: 37
# Current Position:
#  Stock: 0.6499999999999999
#  R_f: 0.3500000000000001
# env.money = 0    665.408808
# 1    358.297050
# Name: 37, dtype: float64
# Portfolio Value: 1023.7058578040673
# Reward: 0.000686186924681175
#
# log_return: -0.0200200171859044
# Current Step: 38
# Current Position:
#  Stock: 1.5499999999999998
#  R_f: -0.5499999999999998
# env.money = 0    1581.814524
# 1    -561.289025
# Name: 38, dtype: float64
# Portfolio Value: 1020.5254993999113
# Reward: -0.0031067111513634494
#
# log_return: 0.009031634020127789
# Current Step: 39
# Current Position:
#  Stock: 0.6499999999999999
#  R_f: 0.3500000000000001
# env.money = 0    658.690518
# 1    354.679510
# Name: 39, dtype: float64
# Portfolio Value: 1013.3700274687097
# Reward: -0.007011556237849116
#
# log_return: 0.007799004900058143
# Current Step: 40
# Current Position:
#  Stock: 1.6999999999999997
#  R_f: -0.6999999999999997
# env.money = 0    1715.149737
# 1    -706.238127
# Name: 40, dtype: float64
# Portfolio Value: 1008.9116102161879
# Reward: -0.004399594552503667
#
# log_return: 0.037110250172447706
# Current Step: 41
# Current Position:
#  Stock: 0.7999999999999998
#  R_f: 0.20000000000000018
# env.money = 0    797.282723
# 1    199.320681
# Name: 41, dtype: float64
# Portfolio Value: 996.6034032916544
# Reward: -0.012199489826364554
#
# log_return: 0.02386900298421407
# Current Step: 42
# Current Position:
#  Stock: 0.6499999999999999
#  R_f: 0.3500000000000001
# env.money = 0    648.653171
# 1    349.274784
# Name: 42, dtype: float64
# Portfolio Value: 997.9279552611463
# Reward: 0.001329066271615177
#
# log_return: -0.01839580811871249
# Current Step: 43
# Current Position:
#  Stock: -0.10000000000000009
#  R_f: 1.1
# env.money = 0     -98.494078
# 1    1083.434856
# Name: 43, dtype: float64
# Portfolio Value: 984.9407785166193
# Reward: -0.0130141426302948
#
# log_return: 0.019458400944105766
# Current Step: 44
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money = 0    345.505910
# 1    641.653832
# Name: 44, dtype: float64
# Portfolio Value: 987.1597420151713
# Reward: 0.002252890272137936
#
# log_return: -0.01771867284829706
# Current Step: 45
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0    -999.948427
# 1    1999.896854
# Name: 45, dtype: float64
# Portfolio Value: 999.948427127032
# Reward: 0.012955031052779833
#
# log_return: -0.006783448800543507
# Current Step: 46
# Current Position:
#  Stock: 0.6499999999999999
#  R_f: 0.3500000000000001
# env.money = 0    650.126688
# 1    350.068217
# Name: 46, dtype: float64
# Portfolio Value: 1000.1949052989529
# Reward: 0.00024649088416395535
#
# log_return: 0.002464416500721568
# Current Step: 47
# Current Position:
#  Stock: 0.95
#  R_f: 0.050000000000000044
# env.money = 0    911.905477
# 1     47.995025
# Name: 47, dtype: float64
# Portfolio Value: 959.9005025494192
# Reward: -0.04028655068732818
#
# log_return: 0.018797856009365444
# Current Step: 48
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0    -958.643861
# 1    1917.287723
# Name: 48, dtype: float64
# Portfolio Value: 958.6438613652726
# Reward: -0.0013091369165960942
#
# log_return: -0.004169816850264282
# Current Step: 49
# Current Position:
#  Stock: 0.19999999999999996
#  R_f: 0.8
# env.money = 0    194.810154
# 1    779.240615
# Name: 49, dtype: float64
# Portfolio Value: 974.0507682251373
# Reward: 0.016071564718437334
#
# log_return: 0.014003789128378541
# Current Step: 50
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0    -970.495155
# 1    1940.990309
# Name: 50, dtype: float64
# Portfolio Value: 970.4951545485347
# Reward: -0.0036503371206014186
#
# log_return: -0.010392171464893012
# Current Step: 51
# Current Position:
#  Stock: 0.050000000000000044
#  R_f: 0.95
# env.money = 0     48.677445
# 1    924.871460
# Name: 51, dtype: float64
# Portfolio Value: 973.5489051220734
# Reward: 0.0031465902320339007
#
# log_return: -0.007437586407146715
# Current Step: 52
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0    -936.5492
# 1    1873.0984
# Name: 52, dtype: float64
# Portfolio Value: 936.5492000534093
# Reward: -0.03800497835701913
#
# log_return: -0.027653942135228905
# Current Step: 53
# Current Position:
#  Stock: -0.10000000000000009
#  R_f: 1.1
# env.money = 0     -96.266115
# 1    1058.927267
# Name: 53, dtype: float64
# Portfolio Value: 962.6611515309758
# Reward: 0.02788102480475914
#
# log_return: 0.002858163914885183
# Current Step: 54
# Current Position:
#  Stock: 1.1
#  R_f: -0.10000000000000009
# env.money = 0    1051.851027
# 1     -95.622821
# Name: 54, dtype: float64
# Portfolio Value: 956.2282066825721
# Reward: -0.0066824602178793
#
# log_return: 0.0033561753734447234
# Current Step: 55
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money = 0    -526.605791
# 1    1484.070865
# Name: 55, dtype: float64
# Portfolio Value: 957.465074141845
# Reward: 0.0012934856456116152
#
# log_return: -0.01845000148811724
# Current Step: 56
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money = 0    -242.191157
# 1    1210.955787
# Name: 56, dtype: float64
# Portfolio Value: 968.7646293688259
# Reward: 0.011801532538519472
#
# log_return: 0.008366744287882985
# Current Step: 57
# Current Position:
#  Stock: 1.25
#  R_f: -0.25
# env.money = 0    1220.282524
# 1    -244.056505
# Name: 57, dtype: float64
# Portfolio Value: 976.2260195819765
# Reward: 0.0077019639104824395
#
# log_return: -0.0033932016558135235
# Current Step: 58
# Current Position:
#  Stock: 1.5499999999999998
#  R_f: -0.5499999999999998
# env.money = 0    1490.582434
# 1    -528.916347
# Name: 58, dtype: float64
# Portfolio Value: 961.6660862720986
# Reward: -0.014914510592652032
#
# log_return: -0.014271903416052653
# Current Step: 59
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money = 0    -849.474380
# 1    1848.856004
# Name: 59, dtype: float64
# Portfolio Value: 999.3816237547259
# Reward: 0.0392189534611038
#
# log_return: 0.004098801334350104
# Current Step: 60
# Current Position:
#  Stock: -0.7
#  R_f: 1.7
# env.money = 0    -691.554437
# 1    1679.489348
# Name: 60, dtype: float64
# Portfolio Value: 987.9349105180872
# Reward: -0.011453795991998297
#
# log_return: 0.034473248903210844
# Current Step: 61
# Current Position:
#  Stock: 0.19999999999999996
#  R_f: 0.8
# env.money = 0    198.919616
# 1    795.678465
# Name: 61, dtype: float64
# Portfolio Value: 994.5980807084445
# Reward: 0.006744543713778689
#
# log_return: 0.018638606573326572
# Current Step: 62
# Current Position:
#  Stock: 1.6999999999999997
#  R_f: -0.6999999999999997
# env.money = 0    1704.956540
# 1    -702.040928
# Name: 62, dtype: float64
# Portfolio Value: 1002.9156118522628
# Reward: 0.0083627058056394
#
# log_return: -0.014655248925977965
# Current Step: 63
# Current Position:
#  Stock: 1.5499999999999998
#  R_f: -0.5499999999999998
# env.money = 0    1556.938872
# 1    -552.462180
# Name: 63, dtype: float64
# Portfolio Value: 1004.4766917329505
# Reward: 0.0015565416095223935
#
# log_return: 0.00834301306287455
# Current Step: 64
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money = 0    -846.832885
# 1    1843.106868
# Name: 64, dtype: float64
# Portfolio Value: 996.2739828060115
# Reward: -0.008166151583654387
#
# log_return: -0.015306283017758986
# Current Step: 65
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0   -1010.441446
# 1    2020.882891
# Name: 65, dtype: float64
# Portfolio Value: 1010.4414455375975
# Reward: 0.014220448366706516
#
# log_return: -0.01407342131718981
# Current Step: 66
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0   -1009.653947
# 1    2019.307894
# Name: 66, dtype: float64
# Portfolio Value: 1009.6539469654557
# Reward: -0.0007793609175668651
#
# log_return: 0.013138626445285564
# Current Step: 67
# Current Position:
#  Stock: 0.6499999999999999
#  R_f: 0.3500000000000001
# env.money = 0    644.099800
# 1    346.822969
# Name: 67, dtype: float64
# Portfolio Value: 990.9227686752404
# Reward: -0.01855207751775985
#
# log_return: 0.0141797883576758
# Current Step: 68
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money = 0    342.537264
# 1    636.140633
# Name: 68, dtype: float64
# Portfolio Value: 978.6778965080568
# Reward: -0.012357039876633008
#
# log_return: 0.002673382545473383
# Current Step: 69
# Current Position:
#  Stock: 0.050000000000000044
#  R_f: 0.95
# env.money = 0     49.270282
# 1    936.135358
# Name: 69, dtype: float64
# Portfolio Value: 985.4056403907427
# Reward: 0.006874318820002608
#
# log_return: 0.01811645268967861
# Current Step: 70
# Current Position:
#  Stock: 1.5499999999999998
#  R_f: -0.5499999999999998
# env.money = 0    1564.732845
# 1    -555.227784
# Name: 70, dtype: float64
# Portfolio Value: 1009.505061400742
# Reward: 0.024456345714078804
#
# log_return: -0.0053955176441788395
# Current Step: 71
# Current Position:
#  Stock: 1.6999999999999997
#  R_f: -0.6999999999999997
# env.money = 0    1716.290878
# 1    -706.708009
# Name: 71, dtype: float64
# Portfolio Value: 1009.5828694577149
# Reward: 7.70754500873427e-05
#
# log_return: 0.015656197288780815
# Current Step: 72
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money = 0    -249.490491
# 1    1247.452457
# Name: 72, dtype: float64
# Portfolio Value: 997.9619654911207
# Reward: -0.011510599395209795
#
# log_return: 0.011922407018573508
# Current Step: 73
# Current Position:
#  Stock: 1.5499999999999998
#  R_f: -0.5499999999999998
# env.money = 0    1568.172873
# 1    -556.448439
# Name: 73, dtype: float64
# Portfolio Value: 1011.7244342319636
# Reward: 0.013790574407382418
#
# log_return: -0.009074310846288389
# Current Step: 74
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money = 0    354.354156
# 1    658.086290
# Name: 74, dtype: float64
# Portfolio Value: 1012.4404455532841
# Reward: 0.0007077137776790272
#
# log_return: 0.0070200105926883525
# Current Step: 75
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money = 0    -566.527840
# 1    1596.578458
# Name: 75, dtype: float64
# Portfolio Value: 1030.0506181966846
# Reward: 0.01739378619329728
#
# log_return: 0.00818955336495582
# Current Step: 76
# Current Position:
#  Stock: 0.95
#  R_f: 0.050000000000000044
# env.money = 0    991.677414
# 1     52.193548
# Name: 76, dtype: float64
# Portfolio Value: 1043.8709625760703
# Reward: 0.013417150706225527
#
# log_return: -0.012135990206916204
# Current Step: 77
# Current Position:
#  Stock: -0.10000000000000009
#  R_f: 1.1
# env.money = 0    -104.126126
# 1    1145.387386
# Name: 77, dtype: float64
# Portfolio Value: 1041.2612602963136
# Reward: -0.002500023827960918
#
# log_return: -0.003897608821196875
# Current Step: 78
# Current Position:
#  Stock: 0.19999999999999996
#  R_f: 0.8
# env.money = 0    207.152612
# 1    828.610449
# Name: 78, dtype: float64
# Portfolio Value: 1035.7630606524474
# Reward: -0.0052803267090735405
#
# log_return: 0.01921198182389551
# Current Step: 79
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money = 0    -566.807071
# 1    1597.365381
# Name: 79, dtype: float64
# Portfolio Value: 1030.5583104399675
# Reward: -0.005025039422820621
#
# log_return: 0.0096113656358754
# Current Step: 80
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money = 0    351.330607
# 1    652.471126
# Name: 80, dtype: float64
# Portfolio Value: 1003.801733068372
# Reward: -0.025963186265678243
#
# log_return: 0.015852254168016694
# Current Step: 81
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money = 0    -249.051552
# 1    1245.257761
# Name: 81, dtype: float64
# Portfolio Value: 996.2062087375017
# Reward: -0.007566757538515734
#
# log_return: 0.007499321224377301
# Current Step: 82
# Current Position:
#  Stock: 1.5499999999999998
#  R_f: -0.5499999999999998
# env.money = 0    1618.218654
# 1    -574.206619
# Name: 82, dtype: float64
# Portfolio Value: 1044.012034529147
# Reward: 0.04798788179831762
#
# log_return: -0.0031743619259472504
# Current Step: 83
# Current Position:
#  Stock: 0.19999999999999996
#  R_f: 0.8
# env.money = 0    209.840991
# 1    839.363965
# Name: 83, dtype: float64
# Portfolio Value: 1049.2049561118306
# Reward: 0.004974005481675855
#
# log_return: -0.011105824774561438
# Current Step: 84
# Current Position:
#  Stock: -0.7
#  R_f: 1.7
# env.money = 0    -733.990461
# 1    1782.548263
# Name: 84, dtype: float64
# Portfolio Value: 1048.557801676267
# Reward: -0.0006168045926525621
#
# log_return: 0.005610758160908172
# Current Step: 85
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money = 0    356.803144
# 1    662.634410
# Name: 85, dtype: float64
# Portfolio Value: 1019.4375541679838
# Reward: -0.02777171412174934
#
# log_return: -0.015992134156817373
# Current Step: 86
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money = 0    -251.308277
# 1    1256.541384
# Name: 86, dtype: float64
# Portfolio Value: 1005.2331072874133
# Reward: -0.01393361155128668
#
# log_return: -0.007640578386449547
# Current Step: 87
# Current Position:
#  Stock: 1.1
#  R_f: -0.10000000000000009
# env.money = 0    1154.150117
# 1    -104.922738
# Name: 87, dtype: float64
# Portfolio Value: 1049.2273790032023
# Reward: 0.04376524350108799
#
# log_return: -0.004374803751053697
# Current Step: 88
# Current Position:
#  Stock: 1.4
#  R_f: -0.3999999999999999
# env.money = 0    1490.795640
# 1    -425.941611
# Name: 88, dtype: float64
# Portfolio Value: 1064.854028733866
# Reward: 0.014893482617189752
#
# log_return: 0.03348234098783269
# Current Step: 89
# Current Position:
#  Stock: 1.5499999999999998
# ...
# Reward: 0.002252890272137936
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# EXPLOITATION
# log_return: 0.020983332249877848
# Current Step: 45
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money = 0    -849.956163
# 1    1849.904590
# Name: 45, dtype: float64
# Portfolio Value: 999.948427127032
# Reward: 0.012955031052779833
#
# log_return: -0.01400175492820842
# Current Step: 46
# Current Position:
#  Stock: 0.95
#  R_f: 0.050000000000000044
# env.money = 0    950.185160
# 1     50.009745
# Name: 46, dtype: float64
# Portfolio Value: 1000.1949052989529
# Reward: 0.00024649088416395535
#
# log_return: -0.017315162161117094
# Current Step: 47
# Current Position:
#  Stock: 0.050000000000000044
#  R_f: 0.95
# env.money = 0     47.995025
# 1    911.905477
# Name: 47, dtype: float64
# Portfolio Value: 959.9005025494192
# Reward: -0.04028655068732818
#
# log_return: 0.0015461213118944672
# Current Step: 48
# Current Position:
#  Stock: 1.5499999999999998
#  R_f: -0.5499999999999998
# env.money = 0    1485.897985
# 1    -527.254124
# Name: 48, dtype: float64
# Portfolio Value: 958.6438613652726
# Reward: -0.0013091369165960942
#
# log_return: -0.007278984097445026
# Current Step: 49
# Current Position:
#  Stock: 1.4
#  R_f: -0.3999999999999999
# env.money = 0    1363.671076
# 1    -389.620307
# Name: 49, dtype: float64
# Portfolio Value: 974.0507682251373
# Reward: 0.016071564718437334
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# EXPLOITATION
# log_return: -0.0161340216999897
# Current Step: 50
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money = 0    -824.920881
# 1    1795.416036
# Name: 50, dtype: float64
# Portfolio Value: 970.4951545485347
# Reward: -0.0036503371206014186
#
# log_return: -0.044207216155404655
# Current Step: 51
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money = 0    340.742117
# 1    632.806788
# Name: 51, dtype: float64
# Portfolio Value: 973.5489051220734
# Reward: 0.0031465902320339007
#
# log_return: 0.019309727498653163
# Current Step: 52
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money = 0    -374.61968
# 1    1311.16888
# Name: 52, dtype: float64
# Portfolio Value: 936.5492000534093
# Reward: -0.03800497835701913
#
# log_return: 0.017851211051836693
# Current Step: 53
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0    -962.661152
# 1    1925.322303
# Name: 53, dtype: float64
# Portfolio Value: 962.6611515309758
# Reward: 0.02788102480475914
#
# log_return: -0.006107097157726612
# Current Step: 54
# Current Position:
#  Stock: 0.050000000000000044
#  R_f: 0.95
# env.money = 0     47.811410
# 1    908.416796
# Name: 54, dtype: float64
# Portfolio Value: 956.2282066825721
# Reward: -0.0066824602178793
#
# log_return: -0.004560027171148402
# Current Step: 55
# Current Position:
#  Stock: 1.6999999999999997
#  R_f: -0.6999999999999997
# env.money = 0    1627.690626
# 1    -670.225552
# Name: 55, dtype: float64
# Portfolio Value: 957.465074141845
# Reward: 0.0012934856456116152
#
# log_return: 0.03652701228228759
# Current Step: 56
# Current Position:
#  Stock: 1.4
#  R_f: -0.3999999999999999
# env.money = 0    1356.270481
# 1    -387.505852
# Name: 56, dtype: float64
# Portfolio Value: 968.7646293688259
# Reward: 0.011801532538519472
#
# log_return: 0.013860713796017955
# Current Step: 57
# Current Position:
#  Stock: 1.6999999999999997
#  R_f: -0.6999999999999997
# env.money = 0    1659.584233
# 1    -683.358214
# Name: 57, dtype: float64
# Portfolio Value: 976.2260195819765
# Reward: 0.0077019639104824395
#
# log_return: 0.015580246305606787
# Current Step: 58
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money = 0    -240.416522
# 1    1202.082608
# Name: 58, dtype: float64
# Portfolio Value: 961.6660862720986
# Reward: -0.014914510592652032
#
# log_return: 0.0117390130304917
# Current Step: 59
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money = 0    -549.659893
# 1    1549.041517
# Name: 59, dtype: float64
# Portfolio Value: 999.3816237547259
# Reward: 0.0392189534611038
#
# log_return: -0.0031377978458533074
# Current Step: 60
# Current Position:
#  Stock: 1.85
#  R_f: -0.8500000000000001
# env.money = 0    1827.679584
# 1    -839.744674
# Name: 60, dtype: float64
# Portfolio Value: 987.9349105180872
# Reward: -0.011453795991998297
#
# log_return: -0.02758534578427127
# Current Step: 61
# Current Position:
#  Stock: 0.95
#  R_f: 0.050000000000000044
# env.money = 0    944.868177
# 1     49.729904
# Name: 61, dtype: float64
# Portfolio Value: 994.5980807084445
# Reward: 0.006744543713778689
#
# log_return: -0.020114315987614664
# Current Step: 62
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money = 0    -250.728903
# 1    1253.644515
# Name: 62, dtype: float64
# Portfolio Value: 1002.9156118522628
# Reward: 0.0083627058056394
#
# log_return: -0.0065529847685601795
# Current Step: 63
# Current Position:
#  Stock: 0.050000000000000044
#  R_f: 0.95
# env.money = 0     50.223835
# 1    954.252857
# Name: 63, dtype: float64
# Portfolio Value: 1004.4766917329505
# Reward: 0.0015565416095223935
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# EXPLOITATION
# log_return: -0.024354621954452697
# Current Step: 64
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money = 0    -846.832885
# 1    1843.106868
# Name: 64, dtype: float64
# Portfolio Value: 996.2739828060115
# Reward: -0.008166151583654387
#
# log_return: 0.029324770002849727
# Current Step: 65
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0   -1010.441446
# 1    2020.882891
# Name: 65, dtype: float64
# Portfolio Value: 1010.4414455375975
# Reward: 0.014220448366706516
#
# log_return: 0.012128597136440378
# Current Step: 66
# Current Position:
#  Stock: 1.4
#  R_f: -0.3999999999999999
# env.money = 0    1413.515526
# 1    -403.861579
# Name: 66, dtype: float64
# Portfolio Value: 1009.6539469654557
# Reward: -0.0007793609175668651
#
# log_return: 0.0029655352458741904
# Current Step: 67
# Current Position:
#  Stock: 0.95
#  R_f: 0.050000000000000044
# env.money = 0    941.376630
# 1     49.546138
# Name: 67, dtype: float64
# Portfolio Value: 990.9227686752404
# Reward: -0.01855207751775985
#
# log_return: 0.020785746311259505
# Current Step: 68
# Current Position:
#  Stock: 0.95
#  R_f: 0.050000000000000044
# env.money = 0    929.744002
# 1     48.933895
# Name: 68, dtype: float64
# Portfolio Value: 978.6778965080568
# Reward: -0.012357039876633008
#
# log_return: 0.028737355856464548
# Current Step: 69
# Current Position:
#  Stock: 0.95
#  R_f: 0.050000000000000044
# env.money = 0    936.135358
# 1     49.270282
# Name: 69, dtype: float64
# Portfolio Value: 985.4056403907427
# Reward: 0.006874318820002608
#
# log_return: 0.01672741918067103
# Current Step: 70
# Current Position:
#  Stock: 0.19999999999999996
#  R_f: 0.8
# env.money = 0    201.901012
# 1    807.604049
# Name: 70, dtype: float64
# Portfolio Value: 1009.505061400742
# Reward: 0.024456345714078804
#
# log_return: 0.008041119117272991
# Current Step: 71
# Current Position:
#  Stock: 1.1
#  R_f: -0.10000000000000009
# env.money = 0    1110.541156
# 1    -100.958287
# Name: 71, dtype: float64
# Portfolio Value: 1009.5828694577149
# Reward: 7.70754500873427e-05
#
# log_return: -0.014617639307399333
# Current Step: 72
# Current Position:
#  Stock: 0.5
#  R_f: 0.5
# env.money = 0    498.980983
# 1    498.980983
# Name: 72, dtype: float64
# Portfolio Value: 997.9619654911207
# Reward: -0.011510599395209795
#
# log_return: 0.013501281440676194
# Current Step: 73
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money = 0    -404.689774
# 1    1416.414208
# Name: 73, dtype: float64
# Portfolio Value: 1011.7244342319636
# Reward: 0.013790574407382418
#
# log_return: -0.010572065140145857
# Current Step: 74
# Current Position:
#  Stock: 0.19999999999999996
#  R_f: 0.8
# env.money = 0    202.488089
# 1    809.952356
# Name: 74, dtype: float64
# Portfolio Value: 1012.4404455532841
# Reward: 0.0007077137776790272
#
# log_return: -0.007363222050176026
# Current Step: 75
# Current Position:
#  Stock: 0.5
#  R_f: 0.5
# env.money = 0    515.025309
# 1    515.025309
# Name: 75, dtype: float64
# Portfolio Value: 1030.0506181966846
# Reward: 0.01739378619329728
#
# log_return: -0.00849643408796104
# Current Step: 76
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money = 0    -574.129029
# 1    1617.999992
# Name: 76, dtype: float64
# Portfolio Value: 1043.8709625760703
# Reward: 0.013417150706225527
#
# log_return: 0.005987201562357802
# Current Step: 77
# Current Position:
#  Stock: 0.7999999999999998
#  R_f: 0.20000000000000018
# env.money = 0    833.009008
# 1    208.252252
# Name: 77, dtype: float64
# Portfolio Value: 1041.2612602963136
# Reward: -0.002500023827960918
#
# log_return: -0.04631126523962641
# Current Step: 78
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money = 0    362.517071
# 1    673.245989
# Name: 78, dtype: float64
# Portfolio Value: 1035.7630606524474
# Reward: -0.0052803267090735405
#
# log_return: -0.018479143765804115
# Current Step: 79
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0   -1030.558310
# 1    2061.116621
# Name: 79, dtype: float64
# Portfolio Value: 1030.5583104399675
# Reward: -0.005025039422820621
#
# log_return: -0.012106953298871112
# Current Step: 80
# Current Position:
#  Stock: 0.7999999999999998
#  R_f: 0.20000000000000018
# env.money = 0    803.041386
# 1    200.760347
# Name: 80, dtype: float64
# Portfolio Value: 1003.801733068372
# Reward: -0.025963186265678243
#
# log_return: -0.00631347283601594
# Current Step: 81
# Current Position:
#  Stock: 1.4
#  R_f: -0.3999999999999999
# env.money = 0    1394.688692
# 1    -398.482483
# Name: 81, dtype: float64
# Portfolio Value: 996.2062087375017
# Reward: -0.007566757538515734
#
# log_return: 0.006701415523757452
# Current Step: 82
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money = 0    365.404212
# 1    678.607822
# Name: 82, dtype: float64
# Portfolio Value: 1044.012034529147
# Reward: 0.04798788179831762
#
# log_return: 0.03994921943764976
# Current Step: 83
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money = 0    -577.062726
# 1    1626.267682
# Name: 83, dtype: float64
# Portfolio Value: 1049.2049561118306
# Reward: 0.004974005481675855
#
# log_return: -0.002255946156517525
# Current Step: 84
# Current Position:
#  Stock: 0.95
#  R_f: 0.050000000000000044
# env.money = 0    996.129912
# 1     52.427890
# Name: 84, dtype: float64
# Portfolio Value: 1048.557801676267
# Reward: -0.0006168045926525621
#
# log_return: 0.0057896644590330485
# Current Step: 85
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money = 0    -560.690655
# 1    1580.128209
# Name: 85, dtype: float64
# Portfolio Value: 1019.4375541679838
# Reward: -0.02777171412174934
#
# log_return: -0.009168867870315506
# Current Step: 86
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money = 0    -854.448141
# 1    1859.681248
# Name: 86, dtype: float64
# Portfolio Value: 1005.2331072874133
# Reward: -0.01393361155128668
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# EXPLOITATION
# log_return: -0.021426405737477502
# Current Step: 87
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money = 0    -891.843272
# 1    1941.070651
# Name: 87, dtype: float64
# Portfolio Value: 1049.2273790032023
# Reward: 0.04376524350108799
#
# log_return: 0.003719850148704488
# Current Step: 88
# Current Position:
#  Stock: 0.6499999999999999
#  R_f: 0.3500000000000001
# env.money = 0    692.155119
# 1    372.698910
# Name: 88, dtype: float64
# Portfolio Value: 1064.854028733866
# Reward: 0.014893482617189752
#
# log_return: -0.0050451032645889345
# Current Step: 89
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0   -1089.545089
# 1    2179.090178
# Name: 89, dtype: float64
# Portfolio Value: 1089.5450889704052
# Reward: 0.02318727221786202
#
# log_return: -0.006127453096433742
# Current Step: 90
# Current Position:
#  Stock: -0.10000000000000009
#  R_f: 1.1
# env.money = 0    -108.980089
# 1    1198.780984
# Name: 90, dtype: float64
# Portfolio Value: 1089.8008941743524
# Reward: 0.0002347816593702218
#
# log_return: -0.017445407321776248
# Current Step: 91
# Current Position:
#  Stock: 1.85
#  R_f: -0.8500000000000001
# env.money = 0    2023.859777
# 1    -929.881519
# Name: 91, dtype: float64
# Portfolio Value: 1093.9782577552332
# Reward: 0.003833143836834242
#
# log_return: 0.024853076093039998
# Current Step: 92
# Current Position:
#  Stock: 1.25
#  R_f: -0.25
# env.money = 0    1368.069948
# 1    -273.613990
# Name: 92, dtype: float64
# Portfolio Value: 1094.4559583657392
# Reward: 0.00043666371531566895
#
# log_return: 0.00925514296267852
# Current Step: 93
# Current Position:
#  Stock: 0.7999999999999998
#  R_f: 0.20000000000000018
# env.money = 0    861.799332
# 1    215.449833
# Name: 93, dtype: float64
# Portfolio Value: 1077.249165097926
# Reward: -0.015721777688986926
#
# log_return: 0.018373081363269775
# Current Step: 94
# Current Position:
#  Stock: 0.050000000000000044
#  R_f: 0.95
# env.money = 0      53.831933
# 1    1022.806733
# Name: 94, dtype: float64
# Portfolio Value: 1076.638666097015
# Reward: -0.0005667203286766812
#
# log_return: 0.003578071243784362
# Current Step: 95
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money = 0    388.899319
# 1    722.241593
# Name: 95, dtype: float64
# Portfolio Value: 1111.140912431328
# Reward: 0.03204626345010353
#
# log_return: -0.0025537733468686645
# Current Step: 96
# Current Position:
#  Stock: 0.6499999999999999
#  R_f: 0.3500000000000001
# env.money = 0    745.975040
# 1    401.678868
# Name: 96, dtype: float64
# Portfolio Value: 1147.653907355506
# Reward: 0.03286081406568188
#
# log_return: 0.018487329487693008
# Current Step: 97
# Current Position:
#  Stock: -0.7
#  R_f: 1.7
# env.money = 0    -817.684943
# 1    1985.806289
# Name: 97, dtype: float64
# Portfolio Value: 1168.1213466762952
# Reward: 0.017834156438286848
#
# log_return: -0.011989378815033064
# Current Step: 98
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money = 0    -645.455704
# 1    1819.011531
# Name: 98, dtype: float64
# Portfolio Value: 1173.5558262820678
# Reward: 0.004652324539086241
#
# log_return: -0.01081216047786043
# Current Step: 99
# Current Position:
#  Stock: -0.10000000000000009
#  R_f: 1.1
# env.money = 0    -117.603448
# 1    1293.637930
# Name: 99, dtype: float64
# Portfolio Value: 1176.0344819832594
# Reward: 0.0021120901500223162
#
# Episode: 10/10, Score: 98, Epsilon: 0.96
#
#
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Annualized rewards predicted: 70.70%
