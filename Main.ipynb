# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from collections import deque
import random
import gymnasium as gym
from gymnasium import spaces
import datetime
import my_library as mylib
import statsmodels.api as sm
import matplotlib.pyplot as plt
pd.options.mode.chained_assignment = None

# %% [markdown]
# Environment Definition

# %%
class TradingEnv(gym.Env):
    def __init__(self, df, rf):
        super(TradingEnv, self).__init__()

        self.current_step = 0
        self.data = df.iloc[:,df.columns != 'log_ret']
        self.y = df['log_ret']
        self.initial_position = pd.DataFrame({'0': [0], '1': [1]}) # Initial position is 1000 in risk_free asset
        self.position = self.initial_position
        self.initial_portfolio_value = list([1000])
        self.money = pd.DataFrame(self.initial_portfolio_value[0] * self.position)
        self.rf = rf
        self.pos_sup = 2
        self.pos_inf = -1
        # Define action and observation space
        
        # Only one stock, the rest is in cash
        self.action_space = np.arange(self.pos_inf, self.pos_sup, 0.15).round(2)
        # If two stocks, then self.action_space = spaces.Box(low=np.array([0,0]), high=np.array([1,1]), dtype=np.float32)
        
        # observation_space is a dataframe with historical data
        self.observation_space = spaces.Box(low=0, high=np.inf, shape=(1,), dtype=np.float32)
           
    def step(self, state, action):
        # Execute one time step within the environment
        self.current_step += 1
        self.flag = 0

        # End the episode if we've run out of data
        if self.current_step >= days_train:
            return self.position, 0, True

        # Take the action (<0: short stock, ==0: hold positions, >0: buy stock)
        # action = action[0][0]
        if (action > self.pos_sup) or (action < self.pos_inf):
            reward = - 1000
            self.flag = 1
        new_port_value = np.exp(state[0]) * self.money.iloc[self.current_step-1,0] + self.money.iloc[self.current_step-1,1] * (1+self.rf)
        self.portfolio_value.append(new_port_value)
        
        if abs(action - self.position.iloc[self.current_step-1,0]) >= tol:
            new_row_pos = pd.DataFrame([[action, (1 - action)]])
        else:
            new_row_pos = pd.DataFrame([[self.position.iloc[self.current_step-1,0], self.position.iloc[self.current_step-1,1]]])
        self.position = pd.concat([self.position, new_row_pos], axis=0, ignore_index=True)    
        new_row_money = pd.DataFrame([[self.position.iloc[self.current_step,0]*self.portfolio_value[self.current_step], self.position.iloc[self.current_step,1]*self.portfolio_value[self.current_step]]])
        self.money = pd.concat([self.money, new_row_money], axis=0, ignore_index=True)

        if self.flag == 0:
            reward = (self.portfolio_value[self.current_step] - self.portfolio_value[self.current_step-1])/self.portfolio_value[self.current_step-1]
        
        done = self.current_step >= days_train - 1
        
        observation = np.concatenate(([self.y_train.iloc[self.current_step]], self.df_train.iloc[self.current_step], [self.position.iloc[self.current_step,0], self.position.iloc[self.current_step,1], self.money.iloc[self.current_step,0], self.money.iloc[self.current_step,1], self.portfolio_value[self.current_step]]))

        return observation, reward, done

    def reset(self):
        # Reset the state of the environment to an initial state
        self.current_step = 0
        a = (3 * np.random.rand(1) - 1)[0].round(5)
        self.position = pd.DataFrame([a,1-a]).T
        self.portfolio_value = self.initial_portfolio_value
        self.money = pd.DataFrame(self.portfolio_value[0] * self.position)
        starting_point = np.random.randint(0, self.data.shape[0]-days_train)
        self.df_train = self.data.iloc[starting_point:starting_point+days_train,]
        self.y_train = self.y.iloc[starting_point:starting_point+days_train,]
        for i in range(days_train):
            b = (0.05 * np.random.rand(1) - 0.025)[0].round(5)
            self.y_train.iloc[i] *= (1+b)
            for j in range(len(self.df_train.columns)):
                c = (0.05 * np.random.rand(1) - 0.025)[0].round(5)
                self.df_train.iloc[i,j] *= (1+c)

        # The first observation is the returns of the first day, the initial position, and the initial portfolio value
        observation = np.insert(self.df_train.iloc[self.current_step].values.flatten(),0,self.y_train.iloc[self.current_step])
        observation = np.concatenate((observation, [self.position.iloc[self.current_step,0], self.position.iloc[self.current_step,1], self.money.iloc[self.current_step,0], self.money.iloc[self.current_step,1], self.portfolio_value[self.current_step]]))

        return observation

    def render(self, mode='human'):
        # Render the environment to the screen
        if mode == 'human':
            print(f"Current Step: {self.current_step}")
            # print(f"Current Price: {self.df_train.iloc[self.current_step]}")
            print(f"Current Position:\n Stock: {self.position.iloc[self.current_step,0]}\n R_f: {self.position.iloc[self.current_step,1]}")
            print(f"env.money = {self.money.iloc[self.current_step]}")
            print(f"Portfolio Value: {self.portfolio_value[self.current_step]}")
    
    def train(self, episodes, days):
        self.days_train = days
        for e in range(episodes):
            print(f"Episode: {e+1}/{episodes}")
            state = env.reset()
            # state = np.reshape(state, [1, state_size])
            for time in range(days): 
                action = agent.act(state)*0.15-1
                print(f"log_return: {state[0]}")
                next_state, reward, done = env.step(state,action)
                if agent.flag == 1:
                    agent.reward_pred *= (1+reward)
                    agent.flag = 0
                # next_state = np.reshape(next_state, [1, state_size])
                agent.remember(state, action, reward, next_state, done)
                self.render()
                print(f"Reward: {reward}\n")
                state = next_state
                if done:
                    print(f"Episode: {e+1}/{episodes}, Score: {time}, Epsilon: {agent.epsilon:.2}\n\n\n")
                    break
            if len(agent.memory) > 32:
                agent.replay(32)

# %% [markdown]
# Agent Definition

# %%
class DQN:
    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.memory = deque(maxlen=3000)
        self.gamma = 0.95  # discount rate
        self.epsilon = 1.0  # exploration rate
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995
        self.learning_rate = 0.001
        self.model = self._build_model()
        self.reward_pred = 1
        self.n_exploit = 0
        self.flag = 0

    def _build_model(self):
        model = Sequential()
        model.add(Dense(64, input_dim=self.state_size, activation='sigmoid'))
        model.add(Dense(64, activation='sigmoid'))
        model.add(Dense(self.action_size, activation='linear'))
        model.compile(loss='mse', optimizer=Adam(learning_rate=self.learning_rate))
        return model

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        act_values = self.model.predict(state)
        print("EXPLOITATION")
        self.flag = 1
        self.n_exploit += 1
        return np.argmax(act_values[0])

    def replay(self, batch_size):
        minibatch = random.sample(self.memory, batch_size)
        for state, action, reward, next_state, done in minibatch:
            target = reward
            if not done:
                target = (reward + self.gamma * np.amax(self.model.predict(next_state)[0]))
            target_f = self.model.predict(state)
            target_f[0][int(action)] = target
            self.model.fit(state, target_f, epochs=1, verbose=0)
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

# %% [markdown]
# Global variables setting

# %%
rf = (1+0.02)**(1/252) - 1
tol = 0.01
episodes = 10
days_train = 100

# %% [markdown]
# Data manipulation

# %%
data = pd.read_csv('AAPL.csv', sep=';')
data['Date'] = pd.to_datetime(data['Date'],format='%d/%m/%Y')
adj_close = data['Adj Close']
df = pd.DataFrame({'Date': data['Date'], 'log_ret': np.log(adj_close/adj_close.shift(1)).dropna()}).dropna().set_index('Date')
sp500 = pd.read_csv('sp500_joined_closes.csv', sep=',')
data.set_index('Date', inplace=True)
new_cols = list([])
for i, col in enumerate(sp500.columns):
    if col.endswith(' '):
        new_cols.append(col[:-1])
    else:
        new_cols.append(col)
sp500.columns = new_cols
sp500['Date'] = pd.to_datetime(sp500['Date'])
sp500 = sp500.set_index('Date')
sp500.drop('AAPL', axis=1, inplace=True)

# %%
sp500_lr = np.log(sp500/sp500.shift(1))
sp500_lr = sp500_lr.drop(sp500_lr.index[0])
sp500_lr = sp500_lr.drop([col for col in sp500_lr.columns if sp500_lr[col].count() < 3633], axis=1)
df = df.join(sp500_lr,how='inner').dropna()

# %% [markdown]
# Performing PCA on AAPL and SP500 stocks

# %%
cum_var_exp, PCs, regr_PCs = mylib.PCA(df['log_ret'], sp500_lr, plot=False)

# %%
regr_PCs.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   AAPL   R-squared:                       0.464
# Model:                            OLS   Adj. R-squared:                  0.463
# Method:                 Least Squares   F-statistic:                     314.1
# Date:                Sun, 07 Jul 2024   Prob (F-statistic):               0.00
# Time:                        13:16:34   Log-Likelihood:                -4020.1
# No. Observations:                3633   AIC:                             8062.
# Df Residuals:                    3622   BIC:                             8130.
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.395e-17      0.012   1.97e-15      1.000      -0.024       0.024
# PC0            0.0456      0.001     48.614      0.000       0.044       0.047
# PC1            0.0156      0.003      5.676      0.000       0.010       0.021
# PC2           -0.0751      0.003    -22.826      0.000      -0.082      -0.069
# PC3            0.0145      0.004      3.290      0.001       0.006       0.023
# PC4            0.0389      0.005      7.646      0.000       0.029       0.049
# PC5           -0.0080      0.006     -1.451      0.147      -0.019       0.003
# PC6           -0.0074      0.006     -1.266      0.206      -0.019       0.004
# PC7           -0.0679      0.006    -11.232      0.000      -0.080      -0.056
# PC8           -0.0212      0.006     -3.314      0.001      -0.034      -0.009
# PC9            0.0253      0.007      3.841      0.000       0.012       0.038
# ==============================================================================
# Omnibus:                      573.429   Durbin-Watson:                   1.928
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10155.212
# Skew:                          -0.061   Prob(JB):                         0.00
# Kurtosis:                      11.190   Cond. No.                         13.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
Y = PCs['AAPL']

# %%
[i-1 for i,p in enumerate(regr_PCs.tvalues) if abs(p) > 1.96]
# Out:
# [0, 1, 2, 3, 4, 7, 8, 9]

# %%
t_vals = regr_PCs.tvalues.drop('const')

# %%
t_vals.drop([p for p in t_vals.index if abs(t_vals[p]) == abs(t_vals).min()], inplace=True)
list(t_vals.index)
# Out:
# ['PC0', 'PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC7', 'PC8', 'PC9']

# %%
X = PCs[list(t_vals.index)]

# %%
regr_PCs = sm.OLS(Y, X).fit()
regr_PCs.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   AAPL   R-squared (uncentered):                   0.464
# Model:                            OLS   Adj. R-squared (uncentered):              0.463
# Method:                 Least Squares   F-statistic:                              348.9
# Date:                Sun, 07 Jul 2024   Prob (F-statistic):                        0.00
# Time:                        13:49:08   Log-Likelihood:                         -4020.9
# No. Observations:                3633   AIC:                                      8060.
# Df Residuals:                    3624   BIC:                                      8116.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# PC0            0.0456      0.001     48.617      0.000       0.044       0.047
# PC1            0.0156      0.003      5.677      0.000       0.010       0.021
# PC2           -0.0751      0.003    -22.828      0.000      -0.082      -0.069
# PC3            0.0145      0.004      3.290      0.001       0.006       0.023
# PC4            0.0389      0.005      7.647      0.000       0.029       0.049
# PC5           -0.0080      0.006     -1.451      0.147      -0.019       0.003
# PC7           -0.0679      0.006    -11.232      0.000      -0.080      -0.056
# PC8           -0.0212      0.006     -3.314      0.001      -0.034      -0.009
# PC9            0.0253      0.007      3.841      0.000       0.012       0.038
# ==============================================================================
# Omnibus:                      571.772   Durbin-Watson:                   1.928
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10041.479
# Skew:                          -0.066   Prob(JB):                         0.00
# Kurtosis:                      11.144   Cond. No.                         7.02
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
t_vals = regr_PCs.tvalues
t_vals.drop([p for p in t_vals.index if abs(t_vals[p]) == abs(t_vals).min()], inplace=True)
list(t_vals.index)
X = PCs[list(t_vals.index)]
X = sm.add_constant(X)
regr_PCs = sm.OLS(Y, X).fit()
regr_PCs.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   AAPL   R-squared:                       0.464
# Model:                            OLS   Adj. R-squared:                  0.463
# Method:                 Least Squares   F-statistic:                     392.0
# Date:                Sun, 07 Jul 2024   Prob (F-statistic):               0.00
# Time:                        15:28:55   Log-Likelihood:                -4021.9
# No. Observations:                3633   AIC:                             8062.
# Df Residuals:                    3624   BIC:                             8118.
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.395e-17      0.012   1.97e-15      1.000      -0.024       0.024
# PC0            0.0456      0.001     48.603      0.000       0.044       0.047
# PC1            0.0156      0.003      5.675      0.000       0.010       0.021
# PC2           -0.0751      0.003    -22.821      0.000      -0.082      -0.069
# PC3            0.0145      0.004      3.289      0.001       0.006       0.023
# PC4            0.0389      0.005      7.644      0.000       0.029       0.049
# PC7           -0.0679      0.006    -11.229      0.000      -0.080      -0.056
# PC8           -0.0212      0.006     -3.314      0.001      -0.034      -0.009
# PC9            0.0253      0.007      3.840      0.000       0.012       0.038
# ==============================================================================
# Omnibus:                      571.083   Durbin-Watson:                   1.931
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9984.148
# Skew:                          -0.070   Prob(JB):                         0.00
# Kurtosis:                      11.120   Cond. No.                         13.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
t_vals = regr_PCs.tvalues
any(abs(t_vals) < 1.96)
# Out:
# True

# %%
t_vals = regr_PCs.tvalues
t_vals.drop([p for p in t_vals.index if abs(t_vals[p]) == abs(t_vals).min()], inplace=True)
list(t_vals.index)
X = PCs[list(t_vals.index)]
regr_PCs = sm.OLS(Y, X).fit()
regr_PCs.summary()
t_vals = regr_PCs.tvalues
any(abs(t_vals) < 1.96)
# Out:
# False

# %%
regr_PCs.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   AAPL   R-squared (uncentered):                   0.464
# Model:                            OLS   Adj. R-squared (uncentered):              0.463
# Method:                 Least Squares   F-statistic:                              392.1
# Date:                Sun, 07 Jul 2024   Prob (F-statistic):                        0.00
# Time:                        15:30:54   Log-Likelihood:                         -4021.9
# No. Observations:                3633   AIC:                                      8060.
# Df Residuals:                    3625   BIC:                                      8109.
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# PC0            0.0456      0.001     48.610      0.000       0.044       0.047
# PC1            0.0156      0.003      5.676      0.000       0.010       0.021
# PC2           -0.0751      0.003    -22.824      0.000      -0.082      -0.069
# PC3            0.0145      0.004      3.290      0.001       0.006       0.023
# PC4            0.0389      0.005      7.646      0.000       0.029       0.049
# PC7           -0.0679      0.006    -11.230      0.000      -0.080      -0.056
# PC8           -0.0212      0.006     -3.314      0.001      -0.034      -0.009
# PC9            0.0253      0.007      3.840      0.000       0.012       0.038
# ==============================================================================
# Omnibus:                      571.083   Durbin-Watson:                   1.931
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9984.148
# Skew:                          -0.070   Prob(JB):                         0.00
# Kurtosis:                      11.120   Cond. No.                         7.02
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# Add the relevant PCs to the df

# %%
PCs['AAPL']
# Out:
# Date
# 2010-01-05    0.044287
# 2010-01-06   -0.960478
# 2010-01-07   -0.158106
# 2010-01-08    0.321426
# 2010-01-11   -0.554678
#                 ...
# 2024-06-05    0.387274
# 2024-06-06   -0.456310
# 2024-06-07    0.643276
# 2024-06-10   -1.147117
# 2024-06-11    1.867397
# Name: AAPL, Length: 3633, dtype: float64

# %%
dataframe = pd.DataFrame(PCs[list(t_vals.index)])
dataframe['log_ret'] = df['log_ret']
dataframe
# Out:
#                  PC0       PC1       PC2       PC3       PC4       PC7  \
# Date
# 2010-01-05  2.277725  5.598344  3.573229  1.501416 -2.727350 -0.331074
# 2010-01-06  1.487877  0.917696  1.890682 -0.739696  2.193443  2.344322
# 2010-01-07  5.457933  3.292415  3.593552  1.434769 -6.515021  2.830913
# 2010-01-08  2.347663  3.042308 -1.758965 -1.573010  3.061445  0.025891
# 2010-01-11  3.132203 -3.110919  1.425089  0.095026  0.606712  0.379562
# ...              ...       ...       ...       ...       ...       ...
# 2024-06-05  4.370851  7.734809 -5.675138  2.531673  0.669577  0.257385
# 2024-06-06 -3.327944 -0.154414 -0.253791 -1.452974  0.201252  0.250025
# 2024-06-07 -3.678136  3.166701  1.440477 -2.540191 -2.242545 -1.479271
# 2024-06-10  0.940698  1.386533 -0.699183  2.503593  3.738634  0.322610
# 2024-06-11 -5.742519 -1.431239 -3.595270 -0.203016  3.279811 -0.138426
#
#                  PC8       PC9   log_ret
# Date
# 2010-01-05 -3.486098  0.800556  0.001727
# 2010-01-06  2.210504 -0.477584 -0.016034
# 2010-01-07  1.448740 -0.823186 -0.001850
# 2010-01-08  2.377851 -1.518725  0.006626
# 2010-01-11  0.458655 -3.778597 -0.008861
# ...              ...       ...       ...
# 2024-06-05  0.070731 -0.569867  0.007790
# 2024-06-06 -2.509249  2.491141 -0.007122
# 2024-06-07  0.525229 -0.008270  0.012316
# 2024-06-10  0.032548 -1.317276 -0.019333
# 2024-06-11  1.466820  1.157794  0.033955
#
# [3633 rows x 9 columns]

# %% [markdown]
# Create the environment and agent, training

# %%
env = TradingEnv(df, rf)
state_size = env.observation_space.shape[0]
action_size = len(env.action_space)
agent = DQN(state_size, action_size)

env.train(episodes, days_train)
print(f"Annualized rewards predicted: {(agent.reward_pred**(252/agent.n_exploit)-1)*100:.2f}%")
# Out:
# C:\Users\pietr\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Episode: 1/10
# log_return: 0.0021210262281872814
# Current Step: 1
# Current Position:
#  Stock: -0.10000000000000009
#  R_f: 1.1
# env.money = 0     -99.855224
# 1    1098.407467
# Name: 1, dtype: float64
# Portfolio Value: 998.5522426216658
# Reward: -0.001447757378334245
#
# log_return: 0.01793242667035696
# Current Step: 2
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money = 0    -847.306998
# 1    1844.138761
# Name: 2, dtype: float64
# Portfolio Value: 996.8317627015191
# Reward: -0.0017229743690020621
#
# log_return: -0.01728969703007488
# Current Step: 3
# Current Position:
#  Stock: 1.4
#  R_f: -0.3999999999999999
# env.money = 0    1416.100627
# 1    -404.600179
# Name: 3, dtype: float64
# Portfolio Value: 1011.5004479919162
# Reward: 0.014715306874495461
#
# log_return: -0.004810190114505152
# Current Step: 4
# Current Position:
#  Stock: 1.85
#  R_f: -0.8500000000000001
# env.money = 0    1858.645597
# 1    -853.972301
# Name: 4, dtype: float64
# Portfolio Value: 1004.673295853502
# Reward: -0.0067495295251403555
#
# log_return: -0.014768188169216077
# Current Step: 5
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0    -977.359049
# 1    1954.718098
# Name: 5, dtype: float64
# Portfolio Value: 977.3590492072415
# Reward: -0.02718719285064331
#
# log_return: -0.015564942648223194
# Current Step: 6
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money = 0    -397.042968
# 1    1389.650386
# Name: 6, dtype: float64
# Portfolio Value: 992.6074188936517
# Reward: 0.015601604854202285
#
# log_return: 0.030756940270802165
# Current Step: 7
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0    -980.315058
# 1    1960.630116
# Name: 7, dtype: float64
# Portfolio Value: 980.3150581635986
# Reward: -0.012383909787571456
#
# log_return: -0.008607457722773501
# Current Step: 8
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money = 0    -840.540302
# 1    1829.411246
# Name: 8, dtype: float64
# Portfolio Value: 988.8709436029923
# Reward: 0.00872768949955869
#
# log_return: 0.025729158899108585
# Current Step: 9
# Current Position:
#  Stock: 0.19999999999999996
#  R_f: 0.8
# env.money = 0    193.421539
# 1    773.686157
# Name: 9, dtype: float64
# Portfolio Value: 967.1076968080661
# Reward: -0.022008177038381684
#
# log_return: -0.014471364205766057
# Current Step: 10
# Current Position:
#  Stock: 0.6499999999999999
#  R_f: 0.3500000000000001
# env.money = 0    626.853226
# 1    337.536353
# Name: 10, dtype: float64
# Portfolio Value: 964.3895792101066
# Reward: -0.002810563504902914
#
# log_return: 0.01752575369872181
# Current Step: 11
# Current Position:
#  Stock: 1.5499999999999998
#  R_f: -0.5499999999999998
# env.money = 0    1512.023472
# 1    -536.524458
# Name: 11, dtype: float64
# Portfolio Value: 975.499014233975
# Reward: 0.011519654777862386
#
# log_return: 0.009462252511148414
# Current Step: 12
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money = 0    -544.407546
# 1    1534.239449
# Name: 12, dtype: float64
# Portfolio Value: 989.8319023116314
# Reward: 0.01469287807421471
#
# log_return: -0.0037279117703849377
# Current Step: 13
# Current Position:
#  Stock: 0.050000000000000044
#  R_f: 0.95
# env.money = 0     49.598910
# 1    942.379286
# Name: 13, dtype: float64
# Portfolio Value: 991.9781955211014
# Reward: 0.00216834111373612
#
# log_return: 0.004981305869997393
# Current Step: 14
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money = 0    -545.764965
# 1    1538.064901
# Name: 14, dtype: float64
# Portfolio Value: 992.2999360650462
# Reward: 0.0003243423549000036
#
# log_return: 0.022436776928803626
# Current Step: 15
# Current Position:
#  Stock: -0.7
#  R_f: 1.7
# env.money = 0    -686.026035
# 1    1666.063229
# Name: 15, dtype: float64
# Portfolio Value: 980.0371933681595
# Reward: -0.0123578993116884
#
# log_return: 0.01725399975233035
# Current Step: 16
# Current Position:
#  Stock: 0.6499999999999999
#  R_f: 0.3500000000000001
# env.money = 0    629.348670
# 1    338.880053
# Name: 16, dtype: float64
# Portfolio Value: 968.2287228164189
# Reward: -0.012049002457914503
#
# log_return: 0.0064495555239629425
# Current Step: 17
# Current Position:
#  Stock: 0.050000000000000044
#  R_f: 0.95
# env.money = 0     48.616375
# 1    923.711116
# Name: 17, dtype: float64
# Portfolio Value: 972.3274904963243
# Reward: 0.004233263880029097
#
# log_return: 0.014737776533131363
# Current Step: 18
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money = 0    -389.248753
# 1    1362.370637
# Name: 18, dtype: float64
# Portfolio Value: 973.1218833659541
# Reward: 0.0008170013471739326
#
# log_return: 0.006858657566605955
# Current Step: 19
# Current Position:
#  Stock: 1.6999999999999997
#  R_f: -0.6999999999999997
# env.money = 0    1649.935076
# 1    -679.385031
# Name: 19, dtype: float64
# Portfolio Value: 970.5500449478301
# Reward: -0.002642873890810276
#
# log_return: -0.016685102609420424
# Current Step: 20
# Current Position:
#  Stock: 1.6999999999999997
#  R_f: -0.6999999999999997
# env.money = 0    1603.432711
# 1    -660.236999
# Name: 20, dtype: float64
# Portfolio Value: 943.1957123470038
# Reward: -0.028184360758333356
#
# log_return: -0.0006930553466903215
# Current Step: 21
# Current Position:
#  Stock: -0.10000000000000009
#  R_f: 1.1
# env.money = 0     -94.203295
# 1    1036.236240
# Name: 21, dtype: float64
# Portfolio Value: 942.0329450433939
# Reward: -0.0012327953662093778
#
# log_return: 0.011816145398126705
# Current Step: 22
# Current Position:
#  Stock: -0.7
#  R_f: 1.7
# env.money = 0    -658.696259
# 1    1599.690914
# Name: 22, dtype: float64
# Portfolio Value: 940.9946554112311
# Reward: -0.00110217974607561
#
# log_return: -0.000712222426875564
# Current Step: 23
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0    -941.589338
# 1    1883.178677
# Name: 23, dtype: float64
# Portfolio Value: 941.5893382511892
# Reward: 0.0006319726010540358
#
# log_return: 0.020021111873141408
# Current Step: 24
# Current Position:
#  Stock: -0.7
#  R_f: 1.7
# env.money = 0    -645.886977
# 1    1568.582657
# Name: 24, dtype: float64
# Portfolio Value: 922.695680845235
# Reward: -0.020065708731415135
#
# log_return: 0.023741188570075924
# Current Step: 25
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money = 0    -771.206147
# 1    1678.507496
# Name: 25, dtype: float64
# Portfolio Value: 907.3013490569106
# Reward: -0.016684083504349367
#
# log_return: 0.007921120349644952
# Current Step: 26
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0    -901.300179
# 1    1802.600359
# Name: 26, dtype: float64
# Portfolio Value: 901.3001794237672
# Reward: -0.00661430696579616
#
# log_return: 0.026367226836973623
# Current Step: 27
# Current Position:
#  Stock: -0.10000000000000009
#  R_f: 1.1
# env.money = 0    -87.736097
# 1    965.097070
# Name: 27, dtype: float64
# Portfolio Value: 877.360972718277
# Reward: -0.026560747741995724
#
# log_return: 0.0010096470821845853
# Current Step: 28
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money = 0    -482.541503
# 1    1359.889691
# Name: 28, dtype: float64
# Portfolio Value: 877.3481875873366
# Reward: -1.4572258554883706e-05
#
# log_return: 0.015147272270140436
# Current Step: 29
# Current Position:
#  Stock: 0.7999999999999998
#  R_f: 0.20000000000000018
# env.money = 0    696.072183
# 1    174.018046
# Name: 29, dtype: float64
# Portfolio Value: 870.0902292179898
# Reward: -0.00827260883652803
#
# log_return: 0.013528696114000418
# Current Step: 30
# Current Position:
#  Stock: 0.050000000000000044
#  R_f: 0.95
# env.money = 0     43.979242
# 1    835.605599
# Name: 30, dtype: float64
# Portfolio Value: 879.5848412106068
# Reward: 0.010912215393052383
#
# log_return: 0.011700613330310753
# Current Step: 31
# Current Position:
#  Stock: 1.85
#  R_f: -0.8500000000000001
# env.money = 0    1628.311010
# 1    -748.142897
# Name: 31, dtype: float64
# Portfolio Value: 880.1681135847664
# Reward: 0.0006631223582216641
#
# log_return: -0.025938703422022827
# Current Step: 32
# Current Position:
#  Stock: 1.85
#  R_f: -0.8500000000000001
# env.money = 0    1551.069814
# 1    -712.653699
# Name: 32, dtype: float64
# Portfolio Value: 838.4161159159282
# Reward: -0.047436389735581064
#
# log_return: -0.0019665325347271527
# Current Step: 33
# Current Position:
#  Stock: 0.6499999999999999
#  R_f: 0.3500000000000001
# env.money = 0    542.953372
# 1    292.359508
# Name: 33, dtype: float64
# Portfolio Value: 835.312880035135
# Reward: -0.0037013075272332016
#
# log_return: -0.0034686951438715643
# Current Step: 34
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money = 0    -333.382311
# 1    1166.838089
# Name: 34, dtype: float64
# Portfolio Value: 833.4557779575027
# Reward: -0.0022232412812240305
#
# log_return: 0.01538619570016635
# Current Step: 35
# Current Position:
#  Stock: 1.25
#  R_f: -0.25
# env.money = 0    1035.472904
# 1    -207.094581
# Name: 35, dtype: float64
# Portfolio Value: 828.3783235754304
# Reward: -0.006092050131940224
#
# log_return: -0.02013526053686766
# Current Step: 36
# Current Position:
#  Stock: 1.5499999999999998
#  R_f: -0.5499999999999998
# env.money = 0    1251.967605
# 1    -444.246570
# Name: 36, dtype: float64
# Portfolio Value: 807.7210358061673
# Reward: -0.024937021142830654
#
# log_return: 0.009430015413581754
# Current Step: 37
# Current Position:
#  Stock: -0.7
#  R_f: 1.7
# env.money = 0    -573.683628
# 1    1393.231667
# Name: 37, dtype: float64
# Portfolio Value: 819.5480396509756
# Reward: 0.01464243633695154
#
# log_return: -0.04022381051901074
# Current Step: 38
# Current Position:
#  Stock: 0.95
#  R_f: 0.050000000000000044
# env.money = 0    800.161565
# 1     42.113767
# Name: 38, dtype: float64
# Portfolio Value: 842.2753316047667
# Reward: 0.02773149449966359
#
# log_return: -0.009890067295774234
# Current Step: 39
# Current Position:
#  Stock: 0.050000000000000044
#  R_f: 0.95
# env.money = 0     41.720200
# 1    792.683794
# Name: 39, dtype: float64
# Portfolio Value: 834.4039939692584
# Reward: -0.009345326094866458
#
# log_return: -0.0547696735962121
# Current Step: 40
# Current Position:
#  Stock: 1.4
#  R_f: -0.3999999999999999
# env.money = 0    1165.139826
# 1    -332.897093
# Name: 40, dtype: float64
# Portfolio Value: 832.2427327377658
# Reward: -0.0025901856260437043
#
# log_return: 0.05698321380523525
# Current Step: 41
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money = 0    -360.215235
# 1    1260.753322
# Name: 41, dtype: float64
# Portfolio Value: 900.538087451227
# Reward: 0.08206182166204712
#
# log_return: -0.028532976641324776
# Current Step: 42
# Current Position:
#  Stock: 0.19999999999999996
#  R_f: 0.8
# env.money = 0    182.153986
# 1    728.615944
# Name: 42, dtype: float64
# Portfolio Value: 910.7699301288403
# Reward: 0.011361921078288
#
# log_return: 0.02714447101668393
# Current Step: 43
# Current Position:
#  Stock: 0.5
#  R_f: 0.5
# env.money = 0    457.91969
# 1    457.91969
# Name: 43, dtype: float64
# Portfolio Value: 915.8393808676129
# Reward: 0.00556611562489275
#
# log_return: 0.009078021032022671
# Current Step: 44
# Current Position:
#  Stock: 1.85
#  R_f: -0.8500000000000001
# env.money = 0    1702.094899
# 1    -782.043602
# Name: 44, dtype: float64
# Portfolio Value: 920.0512969547594
# Reward: 0.004598968088876438
#
# log_return: 0.017126632827480923
# Current Step: 45
# Current Position:
#  Stock: 1.1
#  R_f: -0.10000000000000009
# env.money = 0    1044.331262
# 1     -94.939206
# Name: 45, dtype: float64
# Portfolio Value: 949.3920562744858
# Reward: 0.03189035156717904
#
# log_return: -0.007870844665812083
# Current Step: 46
# Current Position:
#  Stock: -0.10000000000000009
#  R_f: 1.1
# env.money = 0     -94.119709
# 1    1035.316799
# Name: 46, dtype: float64
# Portfolio Value: 941.1970899008422
# Reward: -0.00863180423670431
#
# log_return: -0.00010356710562841185
# Current Step: 47
# Current Position:
#  Stock: 0.6499999999999999
#  R_f: 0.3500000000000001
# env.money = 0    611.837328
# 1    329.450869
# Name: 47, dtype: float64
# Portfolio Value: 941.2881974125081
# Reward: 9.679961045723228e-05
#
# log_return: -0.03857266967163324
# Current Step: 48
# Current Position:
#  Stock: 1.25
#  R_f: -0.25
# env.money = 0    1147.704067
# 1    -229.540813
# Name: 48, dtype: float64
# Portfolio Value: 918.1632532141614
# Reward: -0.024567336828310936
#
# log_return: -0.027605808809041264
# Current Step: 49
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money = 0    -354.758096
# 1    1241.653337
# Name: 49, dtype: float64
# Portfolio Value: 886.8952406959553
# Reward: -0.03405495962591397
#
# log_return: 0.0011341214017601907
# Current Step: 50
# Current Position:
#  Stock: 1.25
#  R_f: -0.25
# env.money = 0    1108.237811
# 1    -221.647562
# Name: 50, dtype: float64
# Portfolio Value: 886.5902489652016
# Reward: -0.00034388698547350093
#
# log_return: 0.04750537285862091
# Current Step: 51
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money = 0    -376.196254
# 1    1316.686888
# Name: 51, dtype: float64
# Portfolio Value: 940.4906343395853
# Reward: 0.0607951479697577
#
# log_return: 0.006950962027354724
# Current Step: 52
# Current Position:
#  Stock: 0.050000000000000044
#  R_f: 0.95
# env.money = 0     46.898504
# 1    891.071567
# Name: 52, dtype: float64
# Portfolio Value: 937.9700710088025
# Reward: -0.002680051495199367
#
# log_return: -0.006768467394423377
# Current Step: 53
# Current Position:
#  Stock: -0.7
#  R_f: 1.7
# env.money = 0    -656.406616
# 1    1594.130352
# Name: 53, dtype: float64
# Portfolio Value: 937.7237366651633
# Reward: -0.0002626249506812818
#
# log_return: 0.026059009619793058
# Current Step: 54
# Current Position:
#  Stock: -0.7
#  R_f: 1.7
# env.money = 0    -644.363218
# 1    1564.882101
# Name: 54, dtype: float64
# Portfolio Value: 920.5188826894201
# Reward: -0.018347465573313695
#
# log_return: 0.01716093497414725
# Current Step: 55
# Current Position:
#  Stock: 1.85
#  R_f: -0.8500000000000001
# env.money = 0    1682.553830
# 1    -773.065273
# Name: 55, dtype: float64
# Portfolio Value: 909.4885567476871
# Reward: -0.011982726426541591
#
# log_return: 5.050386623779746e-05
# Current Step: 56
# Current Position:
#  Stock: 0.7999999999999998
#  R_f: 0.20000000000000018
# env.money = 0    727.610226
# 1    181.902557
# Name: 56, dtype: float64
# Portfolio Value: 909.5127830774383
# Reward: 2.663731123545473e-05
#
# log_return: -0.013507278683711613
# Current Step: 57
# Current Position:
#  Stock: 1.85
#  R_f: -0.8500000000000001
# env.money = 0    1664.565474
# 1    -764.800353
# Name: 57, dtype: float64
# Portfolio Value: 899.7651209330273
# Reward: -0.010717454801931005
#
# log_return: -0.009732551900354536
# Current Step: 58
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money = 0    -751.045661
# 1    1634.628791
# Name: 58, dtype: float64
# Portfolio Value: 883.583130096718
# Reward: -0.017984683402185113
#
# log_return: -0.018913678149605533
# Current Step: 59
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money = 0    -224.445783
# 1    1122.228914
# Name: 59, dtype: float64
# Portfolio Value: 897.7831313985905
# Reward: 0.016070928493528536
#
# log_return: 0.015618715982019504
# Current Step: 60
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money = 0    -491.886036
# 1    1386.224284
# Name: 60, dtype: float64
# Portfolio Value: 894.3382475386213
# Reward: -0.003837100229988353
#
# log_return: 0.010817555063366416
# Current Step: 61
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0    -889.097295
# 1    1778.194591
# Name: 61, dtype: float64
# Portfolio Value: 889.0972954260831
# Reward: -0.005860145338704108
#
# log_return: 0.0005656443738752473
# Current Step: 62
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0    -888.733980
# 1    1777.467959
# Name: 62, dtype: float64
# Portfolio Value: 888.7339796001137
# Reward: -0.00040863449685252706
#
# log_return: -0.017822068298129545
# Current Step: 63
# Current Position:
#  Stock: 1.5499999999999998
#  R_f: -0.5499999999999998
# env.money = 0    1402.087269
# 1    -497.514837
# Name: 63, dtype: float64
# Portfolio Value: 904.5724316992669
# Reward: 0.0178213643932909
#
# log_return: 0.006575720854118179
# Current Step: 64
# Current Position:
#  Stock: 0.19999999999999996
#  R_f: 0.8
# env.money = 0    182.756690
# 1    731.026759
# Name: 64, dtype: float64
# Portfolio Value: 913.7834487728483
# Reward: 0.010182730261056278
#
# log_return: 0.01207503456006657
# Current Step: 65
# Current Position:
#  Stock: -0.10000000000000009
#  R_f: 1.1
# env.money = 0     -91.606107
# 1    1007.667174
# Name: 65, dtype: float64
# Portfolio Value: 916.061067155852
# Reward: 0.002492514376423045
#
# log_return: 0.011925092560442468
# Current Step: 66
# Current Position:
#  Stock: -0.10000000000000009
#  R_f: 1.1
# env.money = 0     -91.504130
# 1    1006.545434
# Name: 66, dtype: float64
# Portfolio Value: 915.0413037986738
# Reward: -0.0011132045599802287
#
# log_return: 0.00956416438489581
# Current Step: 67
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money = 0    -228.560261
# 1    1142.801305
# Name: 67, dtype: float64
# Portfolio Value: 914.2410441044583
# Reward: -0.000874561280341441
#
# log_return: 0.019172451358989574
# Current Step: 68
# Current Position:
#  Stock: -0.10000000000000009
#  R_f: 1.1
# env.money = 0     -90.990651
# 1    1000.897165
# Name: 68, dtype: float64
# Portfolio Value: 909.906513417369
# Reward: -0.004741124580919702
#
# log_return: 0.027392993762165654
# Current Step: 69
# Current Position:
#  Stock: 1.25
#  R_f: -0.25
# env.money = 0    1134.322763
# 1    -226.864553
# Name: 69, dtype: float64
# Portfolio Value: 907.4582100469829
# Reward: -0.002690719688543454
#
# log_return: 0.004365711471757033
# Current Step: 70
# Current Position:
#  Stock: -0.10000000000000009
#  R_f: 1.1
# env.money = 0     -91.240333
# 1    1003.643667
# Name: 70, dtype: float64
# Portfolio Value: 912.4033333308549
# Reward: 0.0054494226060459484
#
# log_return: -0.003125703931609062
# Current Step: 71
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money = 0    -502.021822
# 1    1414.788772
# Name: 71, dtype: float64
# Portfolio Value: 912.7669496326449
# Reward: 0.0003985258366632191
#
# log_return: -0.025488670829861552
# Current Step: 72
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money = 0    -370.204921
# 1    1295.717222
# Name: 72, dtype: float64
# Portfolio Value: 925.5123015943932
# Reward: 0.013963424033788476
#
# log_return: 0.006063993116245857
# Current Step: 73
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0    -923.362385
# 1    1846.724770
# Name: 73, dtype: float64
# Portfolio Value: 923.3623849975411
# Reward: -0.0023229476184686215
#
# log_return: -0.002801303521240999
# Current Step: 74
# Current Position:
#  Stock: 1.5499999999999998
#  R_f: -0.5499999999999998
# env.money = 0    1435.440288
# 1    -509.349780
# Name: 74, dtype: float64
# Portfolio Value: 926.0905084860789
# Reward: 0.002954553415715602
#
# log_return: -0.0098287983575548
# Current Step: 75
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money = 0    319.203828
# 1    592.807109
# Name: 75, dtype: float64
# Portfolio Value: 912.0109370654222
# Reward: -0.015203234772023668
#
# log_return: -0.005606307995286061
# Current Step: 76
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money = 0    -773.732029
# 1    1684.005003
# Name: 76, dtype: float64
# Portfolio Value: 910.2729748416175
# Reward: -0.0019056374799593793
#
# log_return: -0.016756714784975126
# Current Step: 77
# Current Position:
#  Stock: 1.5499999999999998
#  R_f: -0.5499999999999998
# env.money = 0    1431.056869
# 1    -507.794373
# Name: 77, dtype: float64
# Portfolio Value: 923.2624962747367
# Reward: 0.014269918795929648
#
# log_return: -0.024409646552115458
# Current Step: 78
# Current Position:
#  Stock: 1.1
#  R_f: -0.10000000000000009
# env.money = 0    977.585274
# 1    -88.871389
# Name: 78, dtype: float64
# Portfolio Value: 888.7138850002425
# Reward: -0.0374201393578685
#
# log_return: -0.0175031001046708
# Current Step: 79
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0    -871.745004
# 1    1743.490008
# Name: 79, dtype: float64
# Portfolio Value: 871.7450040677229
# Reward: -0.01909375021468801
#
# log_return: -0.005513297538253426
# Current Step: 80
# Current Position:
#  Stock: 0.19999999999999996
#  R_f: 0.8
# env.money = 0    175.334996
# 1    701.339985
# Name: 80, dtype: float64
# Portfolio Value: 876.6749810521645
# Reward: 0.005655297089673519
#
# log_return: 0.015146333209438975
# Current Step: 81
# Current Position:
#  Stock: -0.10000000000000009
#  R_f: 1.1
# env.money = 0    -87.940599
# 1    967.346591
# Name: 81, dtype: float64
# Portfolio Value: 879.4059919406836
# Reward: 0.003115192001078226
#
# log_return: -0.0022831334963145495
# Current Step: 82
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0    -879.682562
# 1    1759.365124
# Name: 82, dtype: float64
# Portfolio Value: 879.6825619145503
# Reward: 0.0003144963491280602
#
# log_return: -0.020059812590135978
# Current Step: 83
# Current Position:
#  Stock: 1.5499999999999998
#  R_f: -0.5499999999999998
# env.money = 0    1390.801478
# 1    -493.510202
# Name: 83, dtype: float64
# Portfolio Value: 897.2912759972817
# Reward: 0.020017123045394426
#
# log_return: 0.0505052990117794
# Current Step: 84
# Current Position:
#  Stock: 0.050000000000000044
#  R_f: 0.95
# env.money = 0     48.464970
# 1    920.834429
# Name: 84, dtype: float64
# Portfolio Value: 969.2993992563074
# Reward: 0.08025055540520368
#
# log_return: 0.028513360207110504
# Current Step: 85
# Current Position:
#  Stock: 1.5499999999999998
#  R_f: -0.5499999999999998
# env.money = 0    1504.699006
# 1    -533.925454
# Name: 85, dtype: float64
# Portfolio Value: 970.7735520090084
# Reward: 0.0015208435637451567
#
# log_return: 0.004707104057138276
# Current Step: 86
# Current Position:
#  Stock: 0.7999999999999998
#  R_f: 0.20000000000000018
# env.money = 0    782.264851
# 1    195.566213
# Name: 86, dtype: float64
# Portfolio Value: 977.8310641674075
# Reward: 0.007269988087122463
#
# log_return: 0.015130835071172181
# Current Step: 87
# Current Position:
#  Stock: 0.7999999999999998
#  R_f: 0.20000000000000018
# env.money = 0    791.818203
# 1    197.954551
# Name: 87, dtype: float64
# Portfolio Value: 989.7727532330919
# Reward: 0.01221242554392804
#
# log_return: 0.033422922797145774
# Current Step: 88
# Current Position:
#  Stock: -0.10000000000000009
#  R_f: 1.1
# env.money = 0    -101.670042
# 1    1118.370466
# Name: 88, dtype: float64
# Portfolio Value: 1016.7004236632611
# Reward: 0.02720591200577101
#
# log_return: -0.004850109121915264
# Current Step: 89
# Current Position:
#  Stock: 1.85
#  R_f: -0.8500000000000001
# env.money = 0    1881.968421
# 1    -864.688194
# Name: 89, dtype: float64
# Portfolio Value: 1017.2802276517084
# Reward: 0.000570280069677018
#
# log_return: 0.005298950630888104
# Current Step: 90
# Current Position:
#  Stock: 1.6999999999999997
#  R_f: -0.6999999999999997
# env.money = 0    1746.259044
# 1    -719.047842
# Name: 90, dtype: float64
# Portfolio Value: 1027.2112024445585
# Reward: 0.00976228036573044
#
# log_return: -0.05732471796272072
# Current Step: 91
# Current Position:
#  Stock: -0.10000000000000009
#  R_f: 1.1
# env.money = 0     -92.986605
# 1    1022.852657
# Name: 91, dtype: float64
# Portfolio Value: 929.8660513897903
# Reward: -0.09476644221081902
#
# log_return: -0.008388046467911971
# Current Step: 92
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money = 0    325.753101
# 1    604.970045
# Name: 92, dtype: float64
# Portfolio Value: 930.7231460612254
# Reward: 0.0009217399324925148
#
# log_return: -0.006153004236019331
# Current Step: 93
# Current Position:
#  Stock: 0.7999999999999998
#  R_f: 0.20000000000000018
# env.money = 0    743.017985
# 1    185.754496
# Name: 93, dtype: float64
# Portfolio Value: 928.7724811765454
# Reward: -0.00209585943245865
#
# log_return: 0.031596133416031714
# Current Step: 94
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0    -952.638395
# 1    1905.276789
# Name: 94, dtype: float64
# Portfolio Value: 952.638394515364
# Reward: 0.02569618913405558
#
# log_return: -0.020309576864458338
# Current Step: 95
# Current Position:
#  Stock: 1.6999999999999997
#  R_f: -0.6999999999999997
# env.money = 0    1652.299114
# 1    -680.358459
# Name: 95, dtype: float64
# Portfolio Value: 971.9406550134505
# Reward: 0.02026189644382974
#
# log_return: 0.007011143688846597
# Current Step: 96
# Current Position:
#  Stock: 1.85
#  R_f: -0.8500000000000001
# env.money = 0    1819.497942
# 1    -835.985541
# Name: 96, dtype: float64
# Portfolio Value: 983.512400979997
# Reward: 0.011905815346705848
#
# log_return: 0.010206178837272038
# Current Step: 97
# Current Position:
#  Stock: 1.25
#  R_f: -0.25
# env.money = 0    1252.639893
# 1    -250.527979
# Name: 97, dtype: float64
# Portfolio Value: 1002.1119147033563
# Reward: 0.01891131591714177
#
# log_return: 0.0006464369851443746
# Current Step: 98
# Current Position:
#  Stock: 1.4
#  R_f: -0.3999999999999999
# env.money = 0    1404.063138
# 1    -401.160897
# Name: 98, dtype: float64
# Portfolio Value: 1002.9022415163051
# Reward: 0.0007886612277060602
#
# log_return: -0.000424373268459441
# Current Step: 99
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money = 0    -250.568749
# 1    1252.843745
# Name: 99, dtype: float64
# Portfolio Value: 1002.2749958603279
# Reward: -0.000625430505598365
#
# Episode: 1/10, Score: 98, Epsilon: 1.0
#
#
#
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Episode: 2/10
# log_return: -0.02726702906064705
# Current Step: 1
# Current Position:
#  Stock: 1.1
#  R_f: -0.10000000000000009
# env.money = 0    1098.407467
# 1     -99.855224
# Name: 1, dtype: float64
# Portfolio Value: 998.5522426216658
# Reward: -0.001447757378334245
#
# log_return: 0.025784759522181032
# Current Step: 2
# Current Position:
#  Stock: 0.95
#  R_f: 0.050000000000000044
# env.money = 0    946.990175
# 1     49.841588
# Name: 2, dtype: float64
# Portfolio Value: 996.8317627015191
# Reward: -0.0017229743690020621
#
# log_return: -0.005180939695375158
# Current Step: 3
# Current Position:
#  Stock: 0.7999999999999998
#  R_f: 0.20000000000000018
# env.money = 0    809.200358
# 1    202.300090
# Name: 3, dtype: float64
# Portfolio Value: 1011.5004479919162
# Reward: 0.014715306874495461
#
# log_return: 0.00989384236678835
# Current Step: 4
# Current Position:
#  Stock: 0.5
#  R_f: 0.5
# env.money = 0    502.336648
# 1    502.336648
# Name: 4, dtype: float64
# Portfolio Value: 1004.673295853502
# Reward: -0.0067495295251403555
#
# log_return: 0.011598077465477386
# Current Step: 5
# Current Position:
#  Stock: 1.5499999999999998
#  R_f: -0.5499999999999998
# env.money = 0    1514.906526
# 1    -537.547477
# Name: 5, dtype: float64
# Portfolio Value: 977.3590492072415
# Reward: -0.02718719285064331
#
# log_return: 0.0028903679497426127
# Current Step: 6
# Current Position:
#  Stock: 0.19999999999999996
#  R_f: 0.8
# env.money = 0    198.521484
# 1    794.085935
# Name: 6, dtype: float64
# Portfolio Value: 992.6074188936517
# Reward: 0.015601604854202285
#
# log_return: -0.014880220768184871
# Current Step: 7
# Current Position:
#  Stock: 1.5499999999999998
#  R_f: -0.5499999999999998
# env.money = 0    1519.488340
# 1    -539.173282
# Name: 7, dtype: float64
# Portfolio Value: 980.3150581635986
# Reward: -0.012383909787571456
#
# log_return: -0.01206251485268092
# Current Step: 8
# Current Position:
#  Stock: -0.10000000000000009
#  R_f: 1.1
# env.money = 0     -98.887094
# 1    1087.758038
# Name: 8, dtype: float64
# Portfolio Value: 988.8709436029923
# Reward: 0.00872768949955869
#
# log_return: 0.004686646548058867
# Current Step: 9
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money = 0    -531.909233
# 1    1499.016930
# Name: 9, dtype: float64
# Portfolio Value: 967.1076968080661
# Reward: -0.022008177038381684
#
# log_return: 0.0014682883206971838
# Current Step: 10
# Current Position:
#  Stock: 1.25
#  R_f: -0.25
# env.money = 0    1205.486974
# 1    -241.097395
# Name: 10, dtype: float64
# Portfolio Value: 964.3895792101066
# Reward: -0.002810563504902914
#
# log_return: -0.002335021960038524
# Current Step: 11
# Current Position:
#  Stock: 0.7999999999999998
#  R_f: 0.20000000000000018
# env.money = 0    780.399211
# 1    195.099803
# Name: 11, dtype: float64
# Portfolio Value: 975.499014233975
# Reward: 0.011519654777862386
#
# log_return: 0.012362940204766049
# Current Step: 12
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money = 0    -247.457976
# 1    1237.289878
# Name: 12, dtype: float64
# Portfolio Value: 989.8319023116314
# Reward: 0.01469287807421471
#
# log_return: -0.0028146544670556843
# Current Step: 13
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money = 0    -843.181466
# 1    1835.159662
# Name: 13, dtype: float64
# Portfolio Value: 991.9781955211014
# Reward: 0.00216834111373612
#
# log_return: 0.0007523797630968605
# Current Step: 14
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money = 0    -248.074984
# 1    1240.374920
# Name: 14, dtype: float64
# Portfolio Value: 992.2999360650462
# Reward: 0.0003243423549000036
#
# log_return: -0.004693272993468048
# Current Step: 15
# Current Position:
#  Stock: 1.85
#  R_f: -0.8500000000000001
# env.money = 0    1813.068808
# 1    -833.031614
# Name: 15, dtype: float64
# Portfolio Value: 980.0371933681595
# Reward: -0.0123578993116884
#
# log_return: -0.0003492579849602033
# Current Step: 16
# Current Position:
#  Stock: 0.95
#  R_f: 0.050000000000000044
# env.money = 0    919.817287
# 1     48.411436
# Name: 16, dtype: float64
# Portfolio Value: 968.2287228164189
# Reward: -0.012049002457914503
#
# log_return: -0.0033520377786300927
# Current Step: 17
# Current Position:
#  Stock: 1.85
#  R_f: -0.8500000000000001
# env.money = 0    1798.805857
# 1    -826.478367
# Name: 17, dtype: float64
# Portfolio Value: 972.3274904963243
# Reward: 0.004233263880029097
#
# log_return: 0.0017621334022821281
# Current Step: 18
# Current Position:
#  Stock: 0.6499999999999999
#  R_f: 0.3500000000000001
# env.money = 0    632.529224
# 1    340.592659
# Name: 18, dtype: float64
# Portfolio Value: 973.1218833659541
# Reward: 0.0008170013471739326
#
# log_return: 0.01997115309459619
# Current Step: 19
# Current Position:
#  Stock: 0.19999999999999996
#  R_f: 0.8
# env.money = 0    194.110009
# 1    776.440036
# Name: 19, dtype: float64
# Portfolio Value: 970.5500449478301
# Reward: -0.002642873890810276
#
# log_return: 0.001404732300631196
# Current Step: 20
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money = 0    -377.278285
# 1    1320.473997
# Name: 20, dtype: float64
# Portfolio Value: 943.1957123470038
# Reward: -0.028184360758333356
#
# log_return: 0.013897668728337361
# Current Step: 21
# Current Position:
#  Stock: -0.10000000000000009
#  R_f: 1.1
# env.money = 0     -94.203295
# 1    1036.236240
# Name: 21, dtype: float64
# Portfolio Value: 942.0329450433939
# Reward: -0.0012327953662093778
#
# log_return: -0.005952496465520062
# Current Step: 22
# Current Position:
#  Stock: 0.95
#  R_f: 0.050000000000000044
# env.money = 0    893.944923
# 1     47.049733
# Name: 22, dtype: float64
# Portfolio Value: 940.9946554112311
# Reward: -0.00110217974607561
#
# log_return: -0.02573730018877481
# Current Step: 23
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money = 0    -800.350938
# 1    1741.940276
# Name: 23, dtype: float64
# Portfolio Value: 941.5893382511892
# Reward: 0.0006319726010540358
#
# log_return: 0.002424433311071055
# Current Step: 24
# Current Position:
#  Stock: 0.5
#  R_f: 0.5
# env.money = 0    461.34784
# 1    461.34784
# Name: 24, dtype: float64
# Portfolio Value: 922.695680845235
# Reward: -0.020065708731415135
#
# log_return: 0.010147571609224658
# Current Step: 25
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0    -907.301349
# 1    1814.602698
# Name: 25, dtype: float64
# Portfolio Value: 907.3013490569106
# Reward: -0.016684083504349367
#
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# EXPLOITATION
# log_return: 0.010554544448103189
# Current Step: 26
# Current Position:
#  Stock: 0.050000000000000044
#  R_f: 0.95
# env.money = 0     45.065009
# 1    856.235170
# Name: 26, dtype: float64
# Portfolio Value: 901.3001794237672
# Reward: -0.00661430696579616
#
# log_return: -0.00060492364545548
# Current Step: 27
# Current Position:
#  Stock: 1.85
#  R_f: -0.8500000000000001
# env.money = 0    1623.117800
# 1    -745.756827
# Name: 27, dtype: float64
# Portfolio Value: 877.360972718277
# Reward: -0.026560747741995724
#
# log_return: -0.008374012302388212
# Current Step: 28
# Current Position:
#  Stock: 1.25
#  R_f: -0.25
# env.money = 0    1096.685234
# 1    -219.337047
# Name: 28, dtype: float64
# Portfolio Value: 877.3481875873366
# Reward: -1.4572258554883706e-05
#
# log_return: -0.005411150677541865
# Current Step: 29
# Current Position:
#  Stock: 1.1
#  R_f: -0.10000000000000009
# env.money = 0    957.099252
# 1    -87.009023
# Name: 29, dtype: float64
# Portfolio Value: 870.0902292179898
# Reward: -0.00827260883652803
#
# log_return: 0.007241182809279633
# Current Step: 30
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money = 0    -351.833936
# 1    1231.418778
# Name: 30, dtype: float64
# Portfolio Value: 879.5848412106068
# Reward: 0.010912215393052383
#
# log_return: 0.030422100849894256
# Current Step: 31
# Current Position:
#  Stock: 0.5
#  R_f: 0.5
# env.money = 0    440.084057
# 1    440.084057
# Name: 31, dtype: float64
# Portfolio Value: 880.1681135847664
# Reward: 0.0006631223582216641
#
# log_return: -0.008531864244715972
# Current Step: 32
# Current Position:
#  Stock: 1.1
#  R_f: -0.10000000000000009
# env.money = 0    922.257728
# 1    -83.841612
# Name: 32, dtype: float64
# Portfolio Value: 838.4161159159282
# Reward: -0.047436389735581064
#
# log_return: 0.0043169727095386055
# Current Step: 33
# Current Position:
#  Stock: 0.6499999999999999
#  R_f: 0.3500000000000001
# env.money = 0    542.953372
# 1    292.359508
# Name: 33, dtype: float64
# Portfolio Value: 835.312880035135
# Reward: -0.0037013075272332016
#
# log_return: 0.007531423501199264
# Current Step: 34
# Current Position:
#  Stock: 1.6999999999999997
#  R_f: -0.6999999999999997
# env.money = 0    1416.874823
# 1    -583.419045
# Name: 34, dtype: float64
# Portfolio Value: 833.4557779575027
# Reward: -0.0022232412812240305
#
# log_return: 0.004234957208144865
# Current Step: 35
# Current Position:
#  Stock: 0.19999999999999996
#  R_f: 0.8
# env.money = 0    165.675665
# 1    662.702659
# Name: 35, dtype: float64
# Portfolio Value: 828.3783235754304
# Reward: -0.006092050131940224
#
# log_return: 0.015140769202783752
# Current Step: 36
# Current Position:
#  Stock: 1.5499999999999998
#  R_f: -0.5499999999999998
# env.money = 0    1251.967605
# 1    -444.246570
# Name: 36, dtype: float64
# Portfolio Value: 807.7210358061673
# Reward: -0.024937021142830654
#
# log_return: -0.010014754406487957
# Current Step: 37
# Current Position:
#  Stock: 0.19999999999999996
#  R_f: 0.8
# env.money = 0    163.909608
# 1    655.638432
# Name: 37, dtype: float64
# Portfolio Value: 819.5480396509756
# Reward: 0.01464243633695154
#
# log_return: -0.006586135324522007
# Current Step: 38
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money = 0    -715.934032
# 1    1558.209363
# Name: 38, dtype: float64
# Portfolio Value: 842.2753316047667
# Reward: 0.02773149449966359
#
# log_return: -0.03334789410274688
# Current Step: 39
# Current Position:
#  Stock: 0.95
#  R_f: 0.050000000000000044
# env.money = 0    792.683794
# 1     41.720200
# Name: 39, dtype: float64
# Portfolio Value: 834.4039939692584
# Reward: -0.009345326094866458
#
# log_return: 0.003866748650186875
# Current Step: 40
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money = 0    291.284956
# 1    540.957776
# Name: 40, dtype: float64
# Portfolio Value: 832.2427327377658
# Reward: -0.0025901856260437043
#
# log_return: -0.009378050121851436
# Current Step: 41
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money = 0    -765.457374
# 1    1665.995462
# Name: 41, dtype: float64
# Portfolio Value: 900.538087451227
# Reward: 0.08206182166204712
#
# log_return: 0.006187037483945941
# Current Step: 42
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0    -910.76993
# 1    1821.53986
# Name: 42, dtype: float64
# Portfolio Value: 910.7699301288403
# Reward: 0.011361921078288
#
# log_return: -0.001593921828677105
# Current Step: 43
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money = 0    -503.711659
# 1    1419.551040
# Name: 43, dtype: float64
# Portfolio Value: 915.8393808676129
# Reward: 0.00556611562489275
#
# log_return: -0.018094480109360798
# Current Step: 44
# Current Position:
#  Stock: 0.7999999999999998
#  R_f: 0.20000000000000018
# env.money = 0    736.041038
# 1    184.010259
# Name: 44, dtype: float64
# Portfolio Value: 920.0512969547594
# Reward: 0.004598968088876438
#
# log_return: -0.02160014174088668
# Current Step: 45
# Current Position:
#  Stock: -0.7
#  R_f: 1.7
# env.money = 0    -664.574439
# 1    1613.966496
# Name: 45, dtype: float64
# Portfolio Value: 949.3920562744858
# Reward: 0.03189035156717904
#
# log_return: 0.003372969569748281
# Current Step: 46
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0    -941.19709
# 1    1882.39418
# Name: 46, dtype: float64
# Portfolio Value: 941.1970899008422
# Reward: -0.00863180423670431
#
# log_return: 0.01642928504592959
# Current Step: 47
# Current Position:
#  Stock: -0.10000000000000009
#  R_f: 1.1
# env.money = 0     -94.128820
# 1    1035.417017
# Name: 47, dtype: float64
# Portfolio Value: 941.2881974125081
# Reward: 9.679961045723228e-05
#
# log_return: 0.006754752747748882
# Current Step: 48
# Current Position:
#  Stock: 1.25
#  R_f: -0.25
# env.money = 0    1147.704067
# 1    -229.540813
# Name: 48, dtype: float64
# Portfolio Value: 918.1632532141614
# Reward: -0.024567336828310936
#
# log_return: 0.0006053832997425126
# Current Step: 49
# Current Position:
#  Stock: 1.5499999999999998
#  R_f: -0.5499999999999998
# env.money = 0    1374.687623
# 1    -487.792382
# Name: 49, dtype: float64
# Portfolio Value: 886.8952406959553
# Reward: -0.03405495962591397
#
# log_return: -0.010474124082101317
# Current Step: 50
# Current Position:
#  Stock: -0.7
#  R_f: 1.7
# env.money = 0    -620.613174
# 1    1507.203423
# Name: 50, dtype: float64
# Portfolio Value: 886.5902489652016
# Reward: -0.00034388698547350093
#
# log_return: -0.024044692787974473
# Current Step: 51
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money = 0    329.171722
# 1    611.318912
# Name: 51, dtype: float64
# Portfolio Value: 940.4906343395853
# Reward: 0.0607951479697577
#
# log_return: 0.006534396749763397
# Current Step: 52
# Current Position:
#  Stock: -0.10000000000000009
#  R_f: 1.1
# env.money = 0     -93.797007
# 1    1031.767078
# Name: 52, dtype: float64
# Portfolio Value: 937.9700710088025
# Reward: -0.002680051495199367
#
# log_return: -0.009296114870086922
# Current Step: 53
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money = 0    -234.430934
# 1    1172.154671
# Name: 53, dtype: float64
# Portfolio Value: 937.7237366651633
# Reward: -0.0002626249506812818
#
# log_return: 0.00803247272929101
# Current Step: 54
# Current Position:
#  Stock: 1.6999999999999997
#  R_f: -0.6999999999999997
# env.money = 0    1564.882101
# 1    -644.363218
# Name: 54, dtype: float64
# Portfolio Value: 920.5188826894201
# Reward: -0.018347465573313695
#
# log_return: -0.025241856705170814
# Current Step: 55
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money = 0    -363.795423
# 1    1273.283979
# Name: 55, dtype: float64
# Portfolio Value: 909.4885567476871
# Reward: -0.011982726426541591
#
# log_return: 0.014245243581997125
# Current Step: 56
# Current Position:
#  Stock: 0.19999999999999996
#  R_f: 0.8
# env.money = 0    181.902557
# 1    727.610226
# Name: 56, dtype: float64
# Portfolio Value: 909.5127830774383
# Reward: 2.663731123545473e-05
#
# log_return: 0.006431895713739304
# Current Step: 57
# Current Position:
#  Stock: 0.050000000000000044
#  R_f: 0.95
# env.money = 0     44.988256
# 1    854.776865
# Name: 57, dtype: float64
# Portfolio Value: 899.7651209330273
# Reward: -0.010717454801931005
#
# log_return: 0.008974997905307815
# Current Step: 58
# Current Position:
#  Stock: 1.6999999999999997
#  R_f: -0.6999999999999997
# env.money = 0    1502.091321
# 1    -618.508191
# Name: 58, dtype: float64
# Portfolio Value: 883.583130096718
# Reward: -0.017984683402185113
#
# log_return: -0.0026822448168825437
# Current Step: 59
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money = 0    314.224096
# 1    583.559035
# Name: 59, dtype: float64
# Portfolio Value: 897.7831313985905
# Reward: 0.016070928493528536
#
# log_return: -0.0006423188336569936
# Current Step: 60
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0    -894.338248
# 1    1788.676495
# Name: 60, dtype: float64
# Portfolio Value: 894.3382475386213
# Reward: -0.003837100229988353
#
# log_return: -0.009163935502388483
# Current Step: 61
# Current Position:
#  Stock: 0.19999999999999996
#  R_f: 0.8
# env.money = 0    177.819459
# 1    711.277836
# Name: 61, dtype: float64
# Portfolio Value: 889.0972954260831
# Reward: -0.005860145338704108
#
# log_return: -0.004248957856637775
# Current Step: 62
# Current Position:
#  Stock: 1.5499999999999998
#  R_f: -0.5499999999999998
# env.money = 0    1377.537668
# 1    -488.803689
# Name: 62, dtype: float64
# Portfolio Value: 888.7339796001137
# Reward: -0.00040863449685252706
#
# log_return: 0.0197585317796173
# Current Step: 63
# Current Position:
#  Stock: -0.7
#  R_f: 1.7
# env.money = 0    -633.200702
# 1    1537.773134
# Name: 63, dtype: float64
# Portfolio Value: 904.5724316992669
# Reward: 0.0178213643932909
#
# log_return: 0.007631832699280241
# Current Step: 64
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money = 0    -365.513380
# 1    1279.296828
# Name: 64, dtype: float64
# Portfolio Value: 913.7834487728483
# Reward: 0.010182730261056278
#
# log_return: 0.011823680622836421
# Current Step: 65
# Current Position:
#  Stock: 1.6999999999999997
#  R_f: -0.6999999999999997
# env.money = 0    1557.303814
# 1    -641.242747
# Name: 65, dtype: float64
# Portfolio Value: 916.061067155852
# Reward: 0.002492514376423045
#
# log_return: 0.01507780124067136
# Current Step: 66
# Current Position:
#  Stock: 1.6999999999999997
#  R_f: -0.6999999999999997
# env.money = 0    1555.570216
# 1    -640.528913
# Name: 66, dtype: float64
# Portfolio Value: 915.0413037986738
# Reward: -0.0011132045599802287
#
# log_return: 0.0033086465895425868
# Current Step: 67
# Current Position:
#  Stock: 1.1
#  R_f: -0.10000000000000009
# env.money = 0    1005.665149
# 1     -91.424104
# Name: 67, dtype: float64
# Portfolio Value: 914.2410441044583
# Reward: -0.000874561280341441
#
# log_return: 0.0014504359526300512
# Current Step: 68
# Current Position:
#  Stock: -0.10000000000000009
#  R_f: 1.1
# env.money = 0     -90.990651
# 1    1000.897165
# Name: 68, dtype: float64
# Portfolio Value: 909.906513417369
# Reward: -0.004741124580919702
#
# log_return: -0.005214946956836378
# Current Step: 69
# Current Position:
#  Stock: 0.050000000000000044
#  R_f: 0.95
# env.money = 0     45.372911
# 1    862.085300
# Name: 69, dtype: float64
# Portfolio Value: 907.4582100469829
# Reward: -0.002690719688543454
#
# log_return: -0.0003409400893259641
# Current Step: 70
# Current Position:
#  Stock: 1.6999999999999997
#  R_f: -0.6999999999999997
# env.money = 0    1551.085667
# 1    -638.682333
# Name: 70, dtype: float64
# Portfolio Value: 912.4033333308549
# Reward: 0.0054494226060459484
#
# log_return: 0.004476555596508444
# Current Step: 71
# Current Position:
#  Stock: 1.25
#  R_f: -0.25
# env.money = 0    1140.958687
# 1    -228.191737
# Name: 71, dtype: float64
# Portfolio Value: 912.7669496326449
# Reward: 0.0003985258366632191
#
# log_return: -0.0032218096779456406
# Current Step: 72
# Current Position:
#  Stock: 1.4
#  R_f: -0.3999999999999999
# env.money = 0    1295.717222
# 1    -370.204921
# Name: 72, dtype: float64
# Portfolio Value: 925.5123015943932
# Reward: 0.013963424033788476
#
# log_return: 0.02510970547481425
# Current Step: 73
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money = 0    -507.849312
# 1    1431.211697
# Name: 73, dtype: float64
# Portfolio Value: 923.3623849975411
# Reward: -0.0023229476184686215
#
# log_return: -0.018612342849132615
# Current Step: 74
# Current Position:
#  Stock: 1.1
#  R_f: -0.10000000000000009
# env.money = 0    1018.699559
# 1     -92.609051
# Name: 74, dtype: float64
# Portfolio Value: 926.0905084860789
# Reward: 0.002954553415715602
#
# log_return: -0.0056947665766909385
# Current Step: 75
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money = 0    -228.002734
# 1    1140.013671
# Name: 75, dtype: float64
# Portfolio Value: 912.0109370654222
# Reward: -0.015203234772023668
#
# log_return: 0.006980742630191478
# Current Step: 76
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0    -910.272975
# 1    1820.545950
# Name: 76, dtype: float64
# Portfolio Value: 910.2729748416175
# Reward: -0.0019056374799593793
#
# log_return: 0.009795072226326298
# Current Step: 77
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money = 0    -784.773122
# 1    1708.035618
# Name: 77, dtype: float64
# Portfolio Value: 923.2624962747367
# Reward: 0.014269918795929648
#
# log_return: -0.00342707360584901
# Current Step: 78
# Current Position:
#  Stock: 0.6499999999999999
#  R_f: 0.3500000000000001
# env.money = 0    577.664025
# 1    311.049860
# Name: 78, dtype: float64
# Portfolio Value: 888.7138850002425
# Reward: -0.0374201393578685
#
# log_return: 0.0035995662558879577
# Current Step: 79
# Current Position:
#  Stock: 0.7999999999999998
#  R_f: 0.20000000000000018
# env.money = 0    697.396003
# 1    174.349001
# Name: 79, dtype: float64
# Portfolio Value: 871.7450040677229
# Reward: -0.01909375021468801
#
# log_return: -0.005612096493577163
# Current Step: 80
# Current Position:
#  Stock: 1.85
#  R_f: -0.8500000000000001
# env.money = 0    1621.848715
# 1    -745.173734
# Name: 80, dtype: float64
# Portfolio Value: 876.6749810521645
# Reward: 0.005655297089673519
#
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# EXPLOITATION
# log_return: 0.002451432514282237
# Current Step: 81
# Current Position:
#  Stock: 0.050000000000000044
#  R_f: 0.95
# env.money = 0     43.970300
# 1    835.435692
# Name: 81, dtype: float64
# Portfolio Value: 879.4059919406836
# Reward: 0.003115192001078226
#
# log_return: -0.019738062790139472
# Current Step: 82
# Current Position:
#  Stock: 1.4
#  R_f: -0.3999999999999999
# env.money = 0    1231.555587
# 1    -351.873025
# Name: 82, dtype: float64
# Portfolio Value: 879.6825619145503
# Reward: 0.0003144963491280602
#
# log_return: -0.00033030494630385956
# Current Step: 83
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money = 0    -224.322819
# 1    1121.614095
# Name: 83, dtype: float64
# Portfolio Value: 897.2912759972817
# Reward: 0.020017123045394426
#
# log_return: 0.013946010341461732
# Current Step: 84
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money = 0    -823.904489
# 1    1793.203889
# Name: 84, dtype: float64
# Portfolio Value: 969.2993992563074
# Reward: 0.08025055540520368
#
# log_return: 6.620229383334561e-05
# Current Step: 85
# Current Position:
#  Stock: 0.7999999999999998
#  R_f: 0.20000000000000018
# env.money = 0    776.618842
# 1    194.154710
# Name: 85, dtype: float64
# Portfolio Value: 970.7735520090084
# Reward: 0.0015208435637451567
#
# log_return: 0.006752073824140523
# Current Step: 86
# Current Position:
#  Stock: 0.7999999999999998
#  R_f: 0.20000000000000018
# env.money = 0    782.264851
# 1    195.566213
# Name: 86, dtype: float64
# Portfolio Value: 977.8310641674075
# Reward: 0.007269988087122463
#
# log_return: 0.015971065201697634
# Current Step: 87
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money = 0    -395.909101
# 1    1385.681855
# Name: 87, dtype: float64
# Portfolio Value: 989.7727532330919
# Reward: 0.01221242554392804
#
# log_return: 0.027792904997420004
# Current Step: 88
# Current Position:
#  Stock: 1.6999999999999997
#  R_f: -0.6999999999999997
# env.money = 0    1728.390720
# ...
#
# log_return: 0.002463633882376239
# Current Step: 45
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money = 0    332.287220
# 1    617.104837
# Name: 45, dtype: float64
# Portfolio Value: 949.3920562744858
# Reward: 0.03189035156717904
#
# log_return: 0.0034686103579133374
# Current Step: 46
# Current Position:
#  Stock: 0.6499999999999999
#  R_f: 0.3500000000000001
# env.money = 0    611.778108
# 1    329.418981
# Name: 46, dtype: float64
# Portfolio Value: 941.1970899008422
# Reward: -0.00863180423670431
#
# log_return: -0.004349458014824431
# Current Step: 47
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money = 0    -517.708509
# 1    1458.996706
# Name: 47, dtype: float64
# Portfolio Value: 941.2881974125081
# Reward: 9.679961045723228e-05
#
# log_return: 0.0002210372514398454
# Current Step: 48
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money = 0    -780.438765
# 1    1698.602018
# Name: 48, dtype: float64
# Portfolio Value: 918.1632532141614
# Reward: -0.024567336828310936
#
# log_return: 0.002801192599795316
# Current Step: 49
# Current Position:
#  Stock: 1.85
#  R_f: -0.8500000000000001
# env.money = 0    1640.756195
# 1    -753.860955
# Name: 49, dtype: float64
# Portfolio Value: 886.8952406959553
# Reward: -0.03405495962591397
#
# log_return: -0.0020155264152617734
# Current Step: 50
# Current Position:
#  Stock: 0.050000000000000044
#  R_f: 0.95
# env.money = 0     44.329512
# 1    842.260737
# Name: 50, dtype: float64
# Portfolio Value: 886.5902489652016
# Reward: -0.00034388698547350093
#
# log_return: 0.004919990018142873
# Current Step: 51
# Current Position:
#  Stock: -0.85
#  R_f: 1.85
# env.money = 0    -799.417039
# 1    1739.907674
# Name: 51, dtype: float64
# Portfolio Value: 940.4906343395853
# Reward: 0.0607951479697577
#
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# EXPLOITATION
# log_return: 0.006074895921089511
# Current Step: 52
# Current Position:
#  Stock: 0.050000000000000044
#  R_f: 0.95
# env.money = 0     46.898504
# 1    891.071567
# Name: 52, dtype: float64
# Portfolio Value: 937.9700710088025
# Reward: -0.002680051495199367
#
# log_return: 0.0029769535605938336
# Current Step: 53
# Current Position:
#  Stock: 1.1
#  R_f: -0.10000000000000009
# env.money = 0    1031.496110
# 1     -93.772374
# Name: 53, dtype: float64
# Portfolio Value: 937.7237366651633
# Reward: -0.0002626249506812818
#
# log_return: -0.004884453417195062
# Current Step: 54
# Current Position:
#  Stock: 0.050000000000000044
#  R_f: 0.95
# env.money = 0     46.025944
# 1    874.492939
# Name: 54, dtype: float64
# Portfolio Value: 920.5188826894201
# Reward: -0.018347465573313695
#
# log_return: 0.0033776333195423384
# Current Step: 55
# Current Position:
#  Stock: 1.85
#  R_f: -0.8500000000000001
# env.money = 0    1682.553830
# 1    -773.065273
# Name: 55, dtype: float64
# Portfolio Value: 909.4885567476871
# Reward: -0.011982726426541591
#
# log_return: 0.0024321462795742735
# Current Step: 56
# Current Position:
#  Stock: 0.19999999999999996
#  R_f: 0.8
# env.money = 0    181.902557
# 1    727.610226
# Name: 56, dtype: float64
# Portfolio Value: 909.5127830774383
# Reward: 2.663731123545473e-05
#
# log_return: -0.000562959728261132
# Current Step: 57
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money = 0    -224.941280
# 1    1124.706401
# Name: 57, dtype: float64
# Portfolio Value: 899.7651209330273
# Reward: -0.010717454801931005
#
# log_return: -0.004944529337482787
# Current Step: 58
# Current Position:
#  Stock: 1.1
#  R_f: -0.10000000000000009
# env.money = 0    971.941443
# 1    -88.358313
# Name: 58, dtype: float64
# Portfolio Value: 883.583130096718
# Reward: -0.017984683402185113
#
# log_return: -0.0034369519822766057
# Current Step: 59
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money = 0    -224.445783
# 1    1122.228914
# Name: 59, dtype: float64
# Portfolio Value: 897.7831313985905
# Reward: 0.016070928493528536
#
# log_return: 0.02135958146381438
# Current Step: 60
# Current Position:
#  Stock: 0.5
#  R_f: 0.5
# env.money = 0    447.169124
# 1    447.169124
# Name: 60, dtype: float64
# Portfolio Value: 894.3382475386213
# Reward: -0.003837100229988353
#
# log_return: 0.0052049656162958405
# Current Step: 61
# Current Position:
#  Stock: 1.4
#  R_f: -0.3999999999999999
# env.money = 0    1244.736214
# 1    -355.638918
# Name: 61, dtype: float64
# Portfolio Value: 889.0972954260831
# Reward: -0.005860145338704108
#
# log_return: 0.00819032558280913
# Current Step: 62
# Current Position:
#  Stock: -0.7
#  R_f: 1.7
# env.money = 0    -622.113786
# 1    1510.847765
# Name: 62, dtype: float64
# Portfolio Value: 888.7339796001137
# Reward: -0.00040863449685252706
#
# log_return: -0.0008114812632025438
# Current Step: 63
# Current Position:
#  Stock: 0.050000000000000044
#  R_f: 0.95
# env.money = 0     45.228622
# 1    859.343810
# Name: 63, dtype: float64
# Portfolio Value: 904.5724316992669
# Reward: 0.0178213643932909
#
# log_return: 0.007309533140735888
# Current Step: 64
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money = 0    -228.445862
# 1    1142.229311
# Name: 64, dtype: float64
# Portfolio Value: 913.7834487728483
# Reward: 0.010182730261056278
#
# log_return: 0.01859080073471158
# Current Step: 65
# Current Position:
#  Stock: 0.5
#  R_f: 0.5
# env.money = 0    458.030534
# 1    458.030534
# Name: 65, dtype: float64
# Portfolio Value: 916.061067155852
# Reward: 0.002492514376423045
#
# log_return: -0.00242079697358866
# Current Step: 66
# Current Position:
#  Stock: 1.5499999999999998
#  R_f: -0.5499999999999998
# env.money = 0    1418.314021
# 1    -503.272717
# Name: 66, dtype: float64
# Portfolio Value: 915.0413037986738
# Reward: -0.0011132045599802287
#
# log_return: 0.008012254339787823
# Current Step: 67
# Current Position:
#  Stock: 1.25
#  R_f: -0.25
# env.money = 0    1142.801305
# 1    -228.560261
# Name: 67, dtype: float64
# Portfolio Value: 914.2410441044583
# Reward: -0.000874561280341441
#
# log_return: 0.003640541407281232
# Current Step: 68
# Current Position:
#  Stock: -0.10000000000000009
#  R_f: 1.1
# env.money = 0     -90.990651
# 1    1000.897165
# Name: 68, dtype: float64
# Portfolio Value: 909.906513417369
# Reward: -0.004741124580919702
#
# log_return: 0.008253033201151472
# Current Step: 69
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0    -907.45821
# 1    1814.91642
# Name: 69, dtype: float64
# Portfolio Value: 907.4582100469829
# Reward: -0.002690719688543454
#
# log_return: -0.022479681528869505
# Current Step: 70
# Current Position:
#  Stock: 1.6999999999999997
#  R_f: -0.6999999999999997
# env.money = 0    1551.085667
# 1    -638.682333
# Name: 70, dtype: float64
# Portfolio Value: 912.4033333308549
# Reward: 0.0054494226060459484
#
# log_return: -0.005274731311340397
# Current Step: 71
# Current Position:
#  Stock: 0.7999999999999998
#  R_f: 0.20000000000000018
# env.money = 0    730.21356
# 1    182.55339
# Name: 71, dtype: float64
# Portfolio Value: 912.7669496326449
# Reward: 0.0003985258366632191
#
# log_return: -0.018053789894271276
# Current Step: 72
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money = 0    -370.204921
# 1    1295.717222
# Name: 72, dtype: float64
# Portfolio Value: 925.5123015943932
# Reward: 0.013963424033788476
#
# log_return: -0.0179992222309408
# Current Step: 73
# Current Position:
#  Stock: -1.0
#  R_f: 2.0
# env.money = 0    -923.362385
# 1    1846.724770
# Name: 73, dtype: float64
# Portfolio Value: 923.3623849975411
# Reward: -0.0023229476184686215
#
# log_return: 0.0319657295522286
# Current Step: 74
# Current Position:
#  Stock: 0.95
#  R_f: 0.050000000000000044
# env.money = 0    879.785983
# 1     46.304525
# Name: 74, dtype: float64
# Portfolio Value: 926.0905084860789
# Reward: 0.002954553415715602
#
# log_return: 0.011365673123871142
# Current Step: 75
# Current Position:
#  Stock: 1.5499999999999998
#  R_f: -0.5499999999999998
# env.money = 0    1413.616952
# 1    -501.606015
# Name: 75, dtype: float64
# Portfolio Value: 912.0109370654222
# Reward: -0.015203234772023668
#
# log_return: 0.006976316237207875
# Current Step: 76
# Current Position:
#  Stock: 0.19999999999999996
#  R_f: 0.8
# env.money = 0    182.054595
# 1    728.218380
# Name: 76, dtype: float64
# Portfolio Value: 910.2729748416175
# Reward: -0.0019056374799593793
#
# log_return: -0.001841145047511534
# Current Step: 77
# Current Position:
#  Stock: 0.7999999999999998
#  R_f: 0.20000000000000018
# env.money = 0    738.609997
# 1    184.652499
# Name: 77, dtype: float64
# Portfolio Value: 923.2624962747367
# Reward: 0.014269918795929648
#
# log_return: -0.021428443292112895
# Current Step: 78
# Current Position:
#  Stock: 0.95
#  R_f: 0.050000000000000044
# env.money = 0    844.278191
# 1     44.435694
# Name: 78, dtype: float64
# Portfolio Value: 888.7138850002425
# Reward: -0.0374201393578685
#
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# EXPLOITATION
# log_return: 0.009584474519060304
# Current Step: 79
# Current Position:
#  Stock: 0.050000000000000044
#  R_f: 0.95
# env.money = 0     43.587250
# 1    828.157754
# Name: 79, dtype: float64
# Portfolio Value: 871.7450040677229
# Reward: -0.01909375021468801
#
# log_return: 0.016737037530522258
# Current Step: 80
# Current Position:
#  Stock: 1.6999999999999997
#  R_f: -0.6999999999999997
# env.money = 0    1490.347468
# 1    -613.672487
# Name: 80, dtype: float64
# Portfolio Value: 876.6749810521645
# Reward: 0.005655297089673519
#
# log_return: -0.0020836949029913085
# Current Step: 81
# Current Position:
#  Stock: 1.85
#  R_f: -0.8500000000000001
# env.money = 0    1626.901085
# 1    -747.495093
# Name: 81, dtype: float64
# Portfolio Value: 879.4059919406836
# Reward: 0.003115192001078226
#
# log_return: -0.0025506417027475357
# Current Step: 82
# Current Position:
#  Stock: 0.95
#  R_f: 0.050000000000000044
# env.money = 0    835.698434
# 1     43.984128
# Name: 82, dtype: float64
# Portfolio Value: 879.6825619145503
# Reward: 0.0003144963491280602
#
# log_return: 0.008714887423097095
# Current Step: 83
# Current Position:
#  Stock: 0.5
#  R_f: 0.5
# env.money = 0    448.645638
# 1    448.645638
# Name: 83, dtype: float64
# Portfolio Value: 897.2912759972817
# Reward: 0.020017123045394426
#
# log_return: 0.01570884037328297
# Current Step: 84
# Current Position:
#  Stock: 0.5
#  R_f: 0.5
# env.money = 0    484.6497
# 1    484.6497
# Name: 84, dtype: float64
# Portfolio Value: 969.2993992563074
# Reward: 0.08025055540520368
#
# log_return: 0.009436638048260844
# Current Step: 85
# Current Position:
#  Stock: 0.19999999999999996
#  R_f: 0.8
# env.money = 0    194.154710
# 1    776.618842
# Name: 85, dtype: float64
# Portfolio Value: 970.7735520090084
# Reward: 0.0015208435637451567
#
# log_return: 0.00814295886649106
# Current Step: 86
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money = 0    -537.807085
# 1    1515.638149
# Name: 86, dtype: float64
# Portfolio Value: 977.8310641674075
# Reward: 0.007269988087122463
#
# log_return: -0.009935015529728926
# Current Step: 87
# Current Position:
#  Stock: -0.25
#  R_f: 1.25
# env.money = 0    -247.443188
# 1    1237.215942
# Name: 87, dtype: float64
# Portfolio Value: 989.7727532330919
# Reward: 0.01221242554392804
#
# log_return: 0.006633303581624759
# Current Step: 88
# Current Position:
#  Stock: 0.34999999999999987
#  R_f: 0.6500000000000001
# env.money = 0    355.845148
# 1    660.855275
# Name: 88, dtype: float64
# Portfolio Value: 1016.7004236632611
# Reward: 0.02720591200577101
#
# log_return: 0.006601767671611363
# Current Step: 89
# Current Position:
#  Stock: 1.1
#  R_f: -0.10000000000000009
# env.money = 0    1119.008250
# 1    -101.728023
# Name: 89, dtype: float64
# Portfolio Value: 1017.2802276517084
# Reward: 0.000570280069677018
#
# log_return: 0.0020240951551545824
# Current Step: 90
# Current Position:
#  Stock: 0.19999999999999996
#  R_f: 0.8
# env.money = 0    205.442240
# 1    821.768962
# Name: 90, dtype: float64
# Portfolio Value: 1027.2112024445585
# Reward: 0.00976228036573044
#
# log_return: 0.00877246846092883
# Current Step: 91
# Current Position:
#  Stock: 1.25
#  R_f: -0.25
# env.money = 0    1162.332564
# 1    -232.466513
# Name: 91, dtype: float64
# Portfolio Value: 929.8660513897903
# Reward: -0.09476644221081902
#
# log_return: -0.013520968155520122
# Current Step: 92
# Current Position:
#  Stock: -0.7
#  R_f: 1.7
# env.money = 0    -651.506202
# 1    1582.229348
# Name: 92, dtype: float64
# Portfolio Value: 930.7231460612254
# Reward: 0.0009217399324925148
#
# log_return: -0.021873307111758736
# Current Step: 93
# Current Position:
#  Stock: 0.95
#  R_f: 0.050000000000000044
# env.money = 0    882.333857
# 1     46.438624
# Name: 93, dtype: float64
# Portfolio Value: 928.7724811765454
# Reward: -0.00209585943245865
#
# log_return: -0.03383585303961184
# Current Step: 94
# Current Position:
#  Stock: 0.7999999999999998
#  R_f: 0.20000000000000018
# env.money = 0    762.110716
# 1    190.527679
# Name: 94, dtype: float64
# Portfolio Value: 952.638394515364
# Reward: 0.02569618913405558
#
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# EXPLOITATION
# log_return: 0.011639430296134045
# Current Step: 95
# Current Position:
#  Stock: 0.050000000000000044
#  R_f: 0.95
# env.money = 0     48.597033
# 1    923.343622
# Name: 95, dtype: float64
# Portfolio Value: 971.9406550134505
# Reward: 0.02026189644382974
#
# log_return: 0.0007711005067207723
# Current Step: 96
# Current Position:
#  Stock: 0.95
#  R_f: 0.050000000000000044
# env.money = 0    934.336781
# 1     49.175620
# Name: 96, dtype: float64
# Portfolio Value: 983.512400979997
# Reward: 0.011905815346705848
#
# log_return: 0.015273516575068133
# Current Step: 97
# Current Position:
#  Stock: -0.55
#  R_f: 1.55
# env.money = 0    -551.161553
# 1    1553.273468
# Name: 97, dtype: float64
# Portfolio Value: 1002.1119147033563
# Reward: 0.01891131591714177
#
# log_return: 0.014175389716867224
# Current Step: 98
# Current Position:
#  Stock: -0.4
#  R_f: 1.4
# env.money = 0    -401.160897
# 1    1404.063138
# Name: 98, dtype: float64
# Portfolio Value: 1002.9022415163051
# Reward: 0.0007886612277060602
#
# log_return: -0.011170549128603057
# Current Step: 99
# Current Position:
#  Stock: 0.5
#  R_f: 0.5
# env.money = 0    501.137498
# 1    501.137498
# Name: 99, dtype: float64
# Portfolio Value: 1002.2749958603279
# Reward: -0.000625430505598365
#
# Episode: 10/10, Score: 98, Epsilon: 0.96
#
#
#
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 944us/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 812us/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 951us/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 760us/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 942us/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 635us/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 624us/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 540us/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 578us/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Annualized rewards predicted: 3.7185577101150313
